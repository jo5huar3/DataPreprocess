# %%
from pathlib import Path 
import os, dotenv, yaml

with open("config.yaml", "r") as f:
    config = yaml.safe_load(f)

dotenv.load_dotenv()
os.chdir(Path(config["pythonpath"]).expanduser())

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json

# %%
from pathlib import PurePosixPath

def prepend_parent_dir_to_filename(p: str) -> str:
    pp = PurePosixPath(p)
    if pp.parent == pp:  # defensive
        return p

    parent_name = pp.parent.name          # e.g., "HKDF256"
    grandparent = pp.parent.parent        # e.g., ".../KDF"
    new_name = f"{parent_name}_{pp.name}" # e.g., "HKDF256_002_HMAC.cry"
    return str(grandparent / new_name)

VERSION = config["version"]
sliced_df = pd.read_json(f"data/some_slices_raw_{VERSION}.jsonl", lines=True)
#sliced_df = sliced_df.iloc[ : 250].reset_index(drop=True)
#sliced_df["filename"] = sliced_df["filename"].str.replace(r"^cryptol_slices/", "", regex=True)
#sliced_df["filename"] = sliced_df["filename"].apply(lambda p: str(REPO_ROOT / p))
#sliced_df["filename"] = sliced_df["filename"].apply(prepend_parent_dir_to_filename)

# %%
import re
from typing import List, Tuple

_HEX_TOKEN_RE = re.compile(r"0x[0-9a-fA-F]+")
_BRACKET_BLOCK_RE = re.compile(r"\[[\s\S]*?\]")  # non-greedy across newlines


def _is_hex_only_list(inner: str) -> bool:
    """
    True iff inner content is only comma-separated hex tokens with whitespace/newlines.
    """
    s = inner.strip()
    if not s:
        return False
    parts = [p.strip() for p in s.split(",")]
    if parts and parts[-1] == "":  # allow trailing comma
        parts.pop()
    return bool(parts) and all(_HEX_TOKEN_RE.fullmatch(p) is not None for p in parts)


def format_hex_sequences_preserve_indent(content: str, width: int = 80, tab_width: int = 8) -> str:
    """
    Reformat ONLY bracketed lists whose elements are ONLY hex literals (0x..),
    wrapping to `width` while PRESERVING the indentation that already exists.

    Policy:
      - Try to append next hex token to current line (", <tok>") if line <= width.
      - If it would exceed width, start a new line using the original prefix
        (the characters before the first hex token on the next original token line).
      - Do not create new indentation styles.
    """
    out_parts: List[str] = []
    last = 0

    for m in _BRACKET_BLOCK_RE.finditer(content):
        block = m.group(0)
        start, end = m.span()

        out_parts.append(content[last:start])

        inner = block[1:-1]
        if not _is_hex_only_list(inner):
            out_parts.append(block)
            last = end
            continue

        # Work line-by-line so we can reuse *existing* indentation prefixes.
        orig_lines = block.splitlines()
        token_lines: List[Tuple[int, str]] = []  # (line_index, prefix_before_first_hex)
        close_line_prefix = None

        for i, ln in enumerate(orig_lines):
            mt = _HEX_TOKEN_RE.search(ln)
            if mt:
                token_lines.append((i, ln[:mt.start()]))
            if close_line_prefix is None and "]" in ln:
                # best-effort: indentation before the first ']' on that line
                close_line_prefix = ln[:ln.index("]")]

        if not token_lines:
            out_parts.append(block)
            last = end
            continue

        # All hex tokens in order
        hex_tokens = _HEX_TOKEN_RE.findall(block)

        first_line_idx, first_prefix = token_lines[0]

        # Keep any lines that come BEFORE the first token line (verbatim)
        new_lines: List[str] = orig_lines[:first_line_idx]

        # Build token content lines with greedy packing
        token_prefixes = [p for (_, p) in token_lines]
        prefix_idx = 0

        cur = first_prefix
        at_line_start = True

        for j, tok in enumerate(hex_tokens):
            piece = tok + ("," if j < len(hex_tokens) - 1 else "")
            sep = "" if at_line_start else " "
            candidate = cur + sep + piece

            # measure visual width with tabs expanded
            if len(candidate.expandtabs(tab_width)) <= width:
                cur = candidate
                at_line_start = False
            else:
                # flush current line and start a new one using the *next existing* prefix
                new_lines.append(cur)
                prefix_idx = min(prefix_idx + 1, len(token_prefixes) - 1)
                cur = token_prefixes[prefix_idx] + piece
                at_line_start = False

        # Try to keep closing bracket on same line if it fits
        close_prefix = close_line_prefix if close_line_prefix is not None else first_prefix
        inline_close = cur + "]"
        if len(inline_close.expandtabs(tab_width)) <= width:
            new_lines.append(inline_close)
        else:
            new_lines.append(cur)
            new_lines.append(close_prefix + "]")

        out_parts.append("\n".join(new_lines))
        last = end

    out_parts.append(content[last:])
    return "".join(out_parts)



sliced_df["content"] = sliced_df["content"].apply(
    lambda c: format_hex_sequences_preserve_indent(c, width=80)
)

# %%
from src.preprocessing.interpreter_process import process_sliced_df_to_df 


MOUNT_DIR = Path(config["mount_dir"]).expanduser()
MOUNT_DIR.mkdir(parents=True, exist_ok=True)
SERVER_URL = config["cryptol_server_url"]

df = process_sliced_df_to_df(
        df=sliced_df,
        host_mount_dir=MOUNT_DIR,
        server_url=SERVER_URL,
    )
# Out:
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/AES_GCM_SIV/010_blockify.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/AES_GCM_SIV/010_blockify.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/AES_GCM_SIV/001_aes_gcm_siv.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/AES_GCM_SIV/001_aes_gcm_siv.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/AES_GCM_SIV/011_unblockify.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/AES_GCM_SIV/011_unblockify.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/AES_GCM_SIV/004_derive_key.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/AES_GCM_SIV/004_derive_key.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/AES_GCM_SIV/003_expandKey.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/AES_GCM_SIV/003_expandKey.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/AES_GCM_SIV/012_byteSwap.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/AES_GCM_SIV/012_byteSwap.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/AES_GCM_SIV/005_gcm_siv_plus.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/AES_GCM_SIV/005_gcm_siv_plus.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/AES_GCM_SIV/009_mult.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/AES_GCM_SIV/009_mult.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/AES_GCM_SIV/008_dot.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/AES_GCM_SIV/008_dot.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/AES_GCM_SIV/007_polyvalFrom.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/AES_GCM_SIV/007_polyvalFrom.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/AES_GCM_SIV/006_counter_mode.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/AES_GCM_SIV/006_counter_mode.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/AES_GCM_SIV/002_aes.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/AES_GCM_SIV/002_aes.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/GCM/Specification/009_inc.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/GCM/Specification/009_inc.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/GCM/Specification/003_dotAndMultAreEquivalent.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/GCM/Specification/003_dotAndMultAreEquivalent.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/GCM/Specification/001_GCM_AE.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/GCM/Specification/001_GCM_AE.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/GCM/Specification/007_MSB.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/GCM/Specification/007_MSB.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/GCM/Specification/005_emptyInputProducesEmptyOutputGCTR.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/GCM/Specification/005_emptyInputProducesEmptyOutputGCTR.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/GCM/Specification/013_define_J0.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/GCM/Specification/013_define_J0.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/GCM/Specification/011_mult.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/GCM/Specification/011_mult.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/GCM/Specification/006_GCTR.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/GCM/Specification/006_GCTR.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/GCM/Specification/010_GHASH.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/GCM/Specification/010_GHASH.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/GCM/Specification/002_GCM_AD.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/GCM/Specification/002_GCM_AD.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/GCM/Specification/012_(•).cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/GCM/Specification/012_(•).cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/GCM/Specification/008_LSB.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/GCM/Specification/008_LSB.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/GCM/Specification/004_gcmIsSymmetric.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/GCM/Specification/004_gcmIsSymmetric.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/GCM/Tests/AES256_GCM/001_aes256_vector_0.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/GCM/Tests/AES256_GCM/001_aes256_vector_0.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/GCM/Tests/AES256_GCM/002_aes256_invalid_vector_1.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/GCM/Tests/AES256_GCM/002_aes256_invalid_vector_1.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/GCM/Tests/AES128_GCM/004_aes128_vector_3.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/GCM/Tests/AES128_GCM/004_aes128_vector_3.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/GCM/Tests/AES128_GCM/003_aes128_vector_2.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/GCM/Tests/AES128_GCM/003_aes128_vector_2.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/GCM/Tests/AES128_GCM/001_aes128_vector_0.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/GCM/Tests/AES128_GCM/001_aes128_vector_0.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/GCM/Tests/AES128_GCM/002_aes128_vector_1.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/GCM/Tests/AES128_GCM/002_aes128_vector_1.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/MEE_CBC/Specification/002_unpad.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/MEE_CBC/Specification/002_unpad.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/MEE_CBC/Specification/005_decrypt.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/MEE_CBC/Specification/005_decrypt.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/MEE_CBC/Specification/004_encrypt.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/MEE_CBC/Specification/004_encrypt.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/MEE_CBC/Specification/006_encryptInverts.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/MEE_CBC/Specification/006_encryptInverts.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/MEE_CBC/Specification/003_paddingInverts.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/MEE_CBC/Specification/003_paddingInverts.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/MEE_CBC/Specification/001_pad.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/MEE_CBC/Specification/001_pad.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/XTS/011_decryptBlock.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/XTS/011_decryptBlock.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/XTS/005_multAlphaLE.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/XTS/005_multAlphaLE.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/XTS/003_dataUnitSeqNoToIV.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/XTS/003_dataUnitSeqNoToIV.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/XTS/010_encrypt.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/XTS/010_encrypt.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/XTS/006_alpha.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/XTS/006_alpha.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/XTS/009_encryptBlock.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/XTS/009_encryptBlock.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/XTS/004_dataUnitSeqNoExample.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/XTS/004_dataUnitSeqNoExample.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/XTS/013_decryptInvertsEncrypt.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/XTS/013_decryptInvertsEncrypt.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/XTS/001_flipEndian.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/XTS/001_flipEndian.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/XTS/012_decrypt.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/XTS/012_decrypt.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/XTS/002_flipEndianInvolutive.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/XTS/002_flipEndianInvolutive.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/XTS/008_generateTweaks.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/XTS/008_generateTweaks.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/XTS/007_irreducible.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/XTS/007_irreducible.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/CTR/002_decrypt.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/CTR/002_decrypt.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/CTR/003_encryptCorrect.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/CTR/003_encryptCorrect.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/CTR/001_encrypt.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/CTR/001_encrypt.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/CBC/002_decrypt.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/CBC/002_decrypt.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/CBC/003_encryptCorrect.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/CBC/003_encryptCorrect.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/CBC/001_encrypt.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/CBC/001_encrypt.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/023_KWP_AE.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/023_KWP_AE.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/001_ICV1.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/001_ICV1.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/012_xorRepresentation.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/012_xorRepresentation.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/014_signficanceWorks.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/014_signficanceWorks.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/024_KWP_AE_Step5.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/024_KWP_AE_Step5.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/006_len.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/006_len.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/007_LSB.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/007_LSB.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/018_WInv.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/018_WInv.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/013_lenRepresentation.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/013_lenRepresentation.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/003_CIPHK.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/003_CIPHK.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/008_MSB.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/008_MSB.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/020_KW_AE.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/020_KW_AE.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/027_keyWrapPaddedInverts.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/027_keyWrapPaddedInverts.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/017_W.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/017_W.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/022_keyWrapInverts.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/022_keyWrapInverts.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/016_stringToInteger.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/016_stringToInteger.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/019_wrappingInverts.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/019_wrappingInverts.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/026_KWP_AD_Step3.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/026_KWP_AD_Step3.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/015_integerToString.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/015_integerToString.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/002_ICV2.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/002_ICV2.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/009_hexRepresentation.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/009_hexRepresentation.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/021_KW_AD.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/021_KW_AD.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/025_KWP_AD.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/025_KWP_AD.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/011_concatRepresentation.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/011_concatRepresentation.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/010_zeroRepresentation.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/010_zeroRepresentation.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/005_int.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/005_int.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/004_CIPHInvK.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AESKeyWrap/004_CIPHInvK.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/CFB/002_decrypt.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/CFB/002_decrypt.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/CFB/003_encryptCorrect.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/CFB/003_encryptCorrect.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/CFB/001_encrypt.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/CFB/001_encrypt.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Simon/Specification/021_c.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Simon/Specification/021_c.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Simon/Specification/034_RInvertible.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Simon/Specification/034_RInvertible.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Simon/Specification/043_decrypt'.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Simon/Specification/043_decrypt'.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Simon/Specification/016_keySchedulesEquivalent.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Simon/Specification/016_keySchedulesEquivalent.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Simon/Specification/040_S.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Simon/Specification/040_S.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Simon/Specification/020_IS_Inv.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Simon/Specification/020_IS_Inv.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Simon/Specification/039_S_Inv.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Simon/Specification/039_S_Inv.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Simon/Specification/042_encryptsEquivalent.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Simon/Specification/042_encryptsEquivalent.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Simon/Specification/019_keySchedule.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Simon/Specification/019_keySchedule.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Simon/Specification/038_SInvertible.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Simon/Specification/038_SInvertible.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Simon/Specification/045_decryptInvertsEncrypt.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Simon/Specification/045_decryptInvertsEncrypt.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Simon/Specification/035_R_Inv.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Simon/Specification/035_R_Inv.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Simon/Specification/041_decryptsEquivalent.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Simon/Specification/041_decryptsEquivalent.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Simon/Specification/017_keyScheduleInjective.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Simon/Specification/017_keyScheduleInjective.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Simon/Specification/018_keySchedule'.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Simon/Specification/018_keySchedule'.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Simon/Specification/022_zj.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Simon/Specification/022_zj.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Simon/Specification/037_f.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Simon/Specification/037_f.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Simon/Specification/044_encrypt'.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Simon/Specification/044_encrypt'.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Simon/Specification/023_zjs.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Simon/Specification/023_zjs.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Simon/Specification/014_composeMany.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Simon/Specification/014_composeMany.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Simon/Specification/002_decrypt.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Simon/Specification/002_decrypt.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Simon/Specification/001_encrypt.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Simon/Specification/001_encrypt.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Simon/Specification/036_R.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Simon/Specification/036_R.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Simon/Specification/024_extend.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Simon/Specification/024_extend.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Specification/006_keySchedule.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Specification/006_keySchedule.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Specification/008_Rf.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Specification/008_Rf.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Specification/018_S_Inv.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Specification/018_S_Inv.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Specification/007_REquivalent.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Specification/007_REquivalent.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Specification/016_Sβ.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Specification/016_Sβ.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Specification/005_keyScheduleInjective.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Specification/005_keyScheduleInjective.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Specification/019_S.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Specification/019_S.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Specification/015_Sα_Inv.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Specification/015_Sα_Inv.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Specification/020_decryptInvertsEncrypt.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Specification/020_decryptInvertsEncrypt.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Specification/012_R_Inv.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Specification/012_R_Inv.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Specification/011_RInvertible.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Specification/011_RInvertible.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Specification/003_keySchedulesEquivalent.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Specification/003_keySchedulesEquivalent.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Specification/014_Sβ_Inv.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Specification/014_Sβ_Inv.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Specification/002_decrypt.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Specification/002_decrypt.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Specification/013_R.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Specification/013_R.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Specification/004_keySchedule'.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Specification/004_keySchedule'.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Specification/010_Rf1.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Specification/010_Rf1.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Specification/009_Rf2.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Specification/009_Rf2.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Specification/017_Sα.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Specification/017_Sα.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Specification/001_encrypt.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Specification/001_encrypt.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/Specification/022_keyExpansion.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/Specification/022_keyExpansion.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/Specification/002_decrypt.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/Specification/002_decrypt.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/Specification/023_invCipher.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/Specification/023_invCipher.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/Specification/001_encrypt.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/Specification/001_encrypt.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/Specification/003_aesIsCorrect.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/Specification/003_aesIsCorrect.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/Specification/013_cipher.cry load_as=cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/Specification/013_cipher.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/MAC/HMAC/Specification/003_expand_key.cry load_as=cryptol-specs/Primitive/Symmetric/MAC/HMAC/Specification/003_expand_key.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/MAC/HMAC/Specification/004_opad.cry load_as=cryptol-specs/Primitive/Symmetric/MAC/HMAC/Specification/004_opad.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/MAC/HMAC/Specification/001_hmac.cry load_as=cryptol-specs/Primitive/Symmetric/MAC/HMAC/Specification/001_hmac.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/MAC/HMAC/Specification/005_ipad.cry load_as=cryptol-specs/Primitive/Symmetric/MAC/HMAC/Specification/005_ipad.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/MAC/HMAC/Specification/002_hmac_truncate.cry load_as=cryptol-specs/Primitive/Symmetric/MAC/HMAC/Specification/002_hmac_truncate.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/MAC/HMAC/Instantiations/HMAC_SHA1/001_H.cry load_as=cryptol-specs/Primitive/Symmetric/MAC/HMAC/Instantiations/HMAC_SHA1/001_H.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/MAC/HMAC/Instantiations/HMAC_SHA512/001_H.cry load_as=cryptol-specs/Primitive/Symmetric/MAC/HMAC/Instantiations/HMAC_SHA512/001_H.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/MAC/HMAC/Instantiations/HMAC_SHA256/001_H.cry load_as=cryptol-specs/Primitive/Symmetric/MAC/HMAC/Instantiations/HMAC_SHA256/001_H.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Symmetric/MAC/HMAC/Instantiations/HMAC_SHA384/001_H.cry load_as=cryptol-specs/Primitive/Symmetric/MAC/HMAC/Instantiations/HMAC_SHA384/001_H.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA2/Instantiations/SHA512/001_H0.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA2/Instantiations/SHA512/001_H0.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA2/Instantiations/SHA256_FFI/001_hashBytes.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA2/Instantiations/SHA256_FFI/001_hashBytes.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA2/Instantiations/SHA512_256/001_H0.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA2/Instantiations/SHA512_256/001_H0.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA2/Instantiations/SHA512_224/001_H0.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA2/Instantiations/SHA512_224/001_H0.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA2/Instantiations/SHA384/001_H0.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA2/Instantiations/SHA384/001_H0.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA3/SHA3/003_hashBytes.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA3/SHA3/003_hashBytes.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA3/SHA3/002_hash.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA3/SHA3/002_hash.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA3/SHA3/001_sha3.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA3/SHA3/001_sha3.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA3/KeccakBitOrdering/008_reverseMatchesb2h.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA3/KeccakBitOrdering/008_reverseMatchesb2h.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA3/KeccakBitOrdering/009_reverseAndTruncateMatchesb2h.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA3/KeccakBitOrdering/009_reverseAndTruncateMatchesb2h.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA3/KeccakBitOrdering/005_truncate.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA3/KeccakBitOrdering/005_truncate.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA3/KeccakBitOrdering/006_reverseMatchesh2b.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA3/KeccakBitOrdering/006_reverseMatchesh2b.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA3/KeccakBitOrdering/007_truncateAndReverseMatchesh2b.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA3/KeccakBitOrdering/007_truncateAndReverseMatchesh2b.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA3/KeccakBitOrdering/004_reverseBitOrderingInvolutes.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA3/KeccakBitOrdering/004_reverseBitOrderingInvolutes.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA3/KeccakBitOrdering/003_reverseBitOrdering.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA3/KeccakBitOrdering/003_reverseBitOrdering.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA3/KeccakBitOrdering/015_h2bAndb2hInvertForShortStrings.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA3/KeccakBitOrdering/015_h2bAndb2hInvertForShortStrings.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA3/Specification/018_flattens_match.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA3/Specification/018_flattens_match.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA3/Specification/024_unflatten_correct.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA3/Specification/024_unflatten_correct.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA3/Specification/023_unflatten.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA3/Specification/023_unflatten.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA3/Specification/003_Keccak_p.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA3/Specification/003_Keccak_p.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA3/Specification/015_ρ_hardcoded.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA3/Specification/015_ρ_hardcoded.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA3/Specification/002_Keccak_f.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA3/Specification/002_Keccak_f.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA3/Specification/017_θ.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA3/Specification/017_θ.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA3/Specification/001_Keccak.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA3/Specification/001_Keccak.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA3/Specification/021_unflattens_match.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA3/Specification/021_unflattens_match.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA3/Specification/022_unflatten_noindex.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA3/Specification/022_unflatten_noindex.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA3/Specification/025_flatten_correct.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA3/Specification/025_flatten_correct.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA3/Specification/014_hardcoded_rho_is_correct.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA3/Specification/014_hardcoded_rho_is_correct.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA3/Specification/012_χ.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA3/Specification/012_χ.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA3/Specification/016_ρ.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA3/Specification/016_ρ.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA3/Specification/013_π.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA3/Specification/013_π.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA3/Specification/005_ι.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA3/Specification/005_ι.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA3/Specification/019_flatten_noindex.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA3/Specification/019_flatten_noindex.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA3/Specification/020_flatten.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA3/Specification/020_flatten.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA3/Instantiations/SHAKE128/001_shake128.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA3/Instantiations/SHAKE128/001_shake128.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA3/Instantiations/SHAKE128/002_xof.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA3/Instantiations/SHAKE128/002_xof.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA3/Instantiations/SHAKE128/003_xofBytes.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA3/Instantiations/SHAKE128/003_xofBytes.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA1/Specification/007_sha1.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA1/Specification/007_sha1.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA1/Specification/005_mixOne.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA1/Specification/005_mixOne.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA1/Specification/003_sha1Block.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA1/Specification/003_sha1Block.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA1/Specification/011_K.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA1/Specification/011_K.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA1/Specification/004_mix.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA1/Specification/004_mix.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA1/Specification/002_hashBytes.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA1/Specification/002_hashBytes.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA1/Specification/010_pad.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA1/Specification/010_pad.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA1/Specification/012_f.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA1/Specification/012_f.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA1/Specification/001_hash.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA1/Specification/001_hash.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA1/Tests/SHA1/004_interfaceEquivalence.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA1/Tests/SHA1/004_interfaceEquivalence.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/014_pad.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/014_pad.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/016_SHAUpdate.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/016_SHAUpdate.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/012_messageSchedule_Common.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/012_messageSchedule_Common.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/004_S1.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/004_S1.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/009_processBlock_Common.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/009_processBlock_Common.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/019_SHAUpdate1.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/019_SHAUpdate1.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/008_Maj.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/008_Maj.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/006_s1.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/006_s1.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/025_processBlock.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/025_processBlock.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/001_sha.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/001_sha.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/026_processBlocksLoop.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/026_processBlocksLoop.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/024_processBlocks.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/024_processBlocks.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/010_SHA_2_Common'.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/010_SHA_2_Common'.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/020_SHAInit_Array.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/020_SHAInit_Array.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/023_SHAImp_Array.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/023_SHAImp_Array.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/002_SHAH0.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/002_SHAH0.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/005_s0.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/005_s0.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/022_SHAFinal_Array.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/022_SHAFinal_Array.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/015_SHAInit.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/015_SHAInit.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/011_compress_Common.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/011_compress_Common.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/003_S0.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/003_S0.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/013_parse.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/013_parse.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/007_Ch.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/007_Ch.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/018_SHAImp.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/018_SHAImp.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/017_SHAFinal.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/017_SHAFinal.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/021_SHAUpdate_Array.cry load_as=cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA/021_SHAUpdate_Array.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Generator/DRBG/010_testInstantiate0Pass.cry load_as=cryptol-specs/Primitive/Keyless/Generator/DRBG/010_testInstantiate0Pass.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Generator/DRBG/002_drbg_generate_internal.cry load_as=cryptol-specs/Primitive/Keyless/Generator/DRBG/002_drbg_generate_internal.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Generator/DRBG/009_testInstantiatedrbg0.cry load_as=cryptol-specs/Primitive/Keyless/Generator/DRBG/009_testInstantiatedrbg0.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Generator/DRBG/012_testReseed0Pass.cry load_as=cryptol-specs/Primitive/Keyless/Generator/DRBG/012_testReseed0Pass.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Generator/DRBG/004_drbg_reseed.cry load_as=cryptol-specs/Primitive/Keyless/Generator/DRBG/004_drbg_reseed.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Generator/DRBG/017_testGenerateSnd0Pass.cry load_as=cryptol-specs/Primitive/Keyless/Generator/DRBG/017_testGenerateSnd0Pass.cry
# File failed to load: stored=cryptol_slices/cryptol-specs/Primitive/Keyless/Generator/DRBG/005_drbg_uninstantiate.cry load_as=cryptol-specs/Primitive/Keyless/Generator/DRBG/005_drbg_uninstantiate.cry
# ...
# File failed to load: stored=cryptol_slices/aws-lc-verification/NSym/spec/SHA384rec/018_processBlock_Common_rec.cry load_as=aws-lc-verification/NSym/spec/SHA384rec/018_processBlock_Common_rec.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/NSym/spec/SHA384rec/019_processBlocks_rec.cry load_as=aws-lc-verification/NSym/spec/SHA384rec/019_processBlocks_rec.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/NSym/spec/SHA384rec/012_compress_Common_rec.cry load_as=aws-lc-verification/NSym/spec/SHA384rec/012_compress_Common_rec.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/NSym/spec/SHA384rec/013_compress_Common_helper.cry load_as=aws-lc-verification/NSym/spec/SHA384rec/013_compress_Common_helper.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/NSym/spec/SHA384rec/001_H0.cry load_as=aws-lc-verification/NSym/spec/SHA384rec/001_H0.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/NSym/spec/SHA384rec/002_K.cry load_as=aws-lc-verification/NSym/spec/SHA384rec/002_K.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/NSym/spec/SHA512recEquiv/001_processBlock_Common_equiv.cry load_as=aws-lc-verification/NSym/spec/SHA512recEquiv/001_processBlock_Common_equiv.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/NSym/spec/SHA512recEquiv/002_processBlocks_equiv.cry load_as=aws-lc-verification/NSym/spec/SHA512recEquiv/002_processBlocks_equiv.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Primitive/Keyless/Hash/SHA3/SHA3/001_sha3.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/Primitive/Keyless/Hash/SHA3/SHA3/001_sha3.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Primitive/Asymmetric/Scheme/RSAES_OAEP/004_EME_OAEP_encode.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/Primitive/Asymmetric/Scheme/RSAES_OAEP/004_EME_OAEP_encode.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Primitive/Asymmetric/Scheme/RSAES_OAEP/003_RSAES_OAEP_Correct.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/Primitive/Asymmetric/Scheme/RSAES_OAEP/003_RSAES_OAEP_Correct.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Primitive/Asymmetric/Scheme/RSAES_OAEP/005_EME_OAEP_decode.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/Primitive/Asymmetric/Scheme/RSAES_OAEP/005_EME_OAEP_decode.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Primitive/Asymmetric/Scheme/RSAES_OAEP/007_MGF1.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/Primitive/Asymmetric/Scheme/RSAES_OAEP/007_MGF1.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Primitive/Asymmetric/Scheme/RSAES_OAEP/001_RSAES_OAEP_ENCRYPT.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/Primitive/Asymmetric/Scheme/RSAES_OAEP/001_RSAES_OAEP_ENCRYPT.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Primitive/Asymmetric/Scheme/RSAES_OAEP/002_RSAES_OAEP_DECRYPT.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/Primitive/Asymmetric/Scheme/RSAES_OAEP/002_RSAES_OAEP_DECRYPT.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Primitive/Asymmetric/Signature/Dilithium/Constants/006_ROOTOFUNITY.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/Primitive/Asymmetric/Signature/Dilithium/Constants/006_ROOTOFUNITY.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Primitive/Asymmetric/Signature/Dilithium/Constants/002_GAMMA1.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/Primitive/Asymmetric/Signature/Dilithium/Constants/002_GAMMA1.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Primitive/Asymmetric/Signature/Dilithium/Constants/003_GAMMA2.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/Primitive/Asymmetric/Signature/Dilithium/Constants/003_GAMMA2.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Primitive/Asymmetric/Signature/Dilithium/Constants/004_ALPHA.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/Primitive/Asymmetric/Signature/Dilithium/Constants/004_ALPHA.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Primitive/Asymmetric/Signature/Dilithium/Constants/008_NINV.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/Primitive/Asymmetric/Signature/Dilithium/Constants/008_NINV.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Primitive/Asymmetric/Signature/Dilithium/Constants/007_ROOTOFUNITYINV.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/Primitive/Asymmetric/Signature/Dilithium/Constants/007_ROOTOFUNITYINV.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Common/ntt/008_naive_ivntt.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/Common/ntt/008_naive_ivntt.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Common/ntt/006_ivn.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/Common/ntt/006_ivn.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Common/LUP/005_vecAdd.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/Common/LUP/005_vecAdd.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Common/LUP/016_LUPSolve.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/Common/LUP/016_LUPSolve.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Common/LUP/006_scalMul.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/Common/LUP/006_scalMul.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Common/LUP/004_dot.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/Common/LUP/004_dot.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Common/LUP/017_LUPInvert.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/Common/LUP/017_LUPInvert.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Common/LUP/012_LUPDecompose.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/Common/LUP/012_LUPDecompose.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Common/LUP/014_pivot.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/Common/LUP/014_pivot.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Common/LUP/009_matMul.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/Common/LUP/009_matMul.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Common/LUP/007_idMat.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/Common/LUP/007_idMat.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Common/LUP/001_fdiv.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/Common/LUP/001_fdiv.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Common/LUP/013_elim.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/Common/LUP/013_elim.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Common/LUP/015_row.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/Common/LUP/015_row.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Common/LUP/008_unitVec.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/Common/LUP/008_unitVec.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Common/LUP/010_matVec.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/Common/LUP/010_matVec.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Common/EC/PrimeField/PFEC/007_(~*).cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/Common/EC/PrimeField/PFEC/007_(~*).cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Common/EC/PrimeField/PFEC/001_G.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/Common/EC/PrimeField/PFEC/001_G.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Common/EC/PrimeField/PFEC/010_scmul_commutes.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/Common/EC/PrimeField/PFEC/010_scmul_commutes.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Common/EC/PrimeField/PFEC/009_valid_scmul.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/Common/EC/PrimeField/PFEC/009_valid_scmul.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Common/EC/PrimeField/PFEC/006_scmul.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/Common/EC/PrimeField/PFEC/006_scmul.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Common/EC/PrimeField/PFEC/002_a.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/Common/EC/PrimeField/PFEC/002_a.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Common/EC/PrimeField/PFEC/008_valid_n.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/Common/EC/PrimeField/PFEC/008_valid_n.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Common/EC/PrimeField/PFEC/003_oo.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/Common/EC/PrimeField/PFEC/003_oo.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Common/EC/PrimeField/PFEC/004_valid_point.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/Common/EC/PrimeField/PFEC/004_valid_point.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Common/EC/PrimeField/PFEC/005_ec_add.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/Common/EC/PrimeField/PFEC/005_ec_add.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/McEliece_KEM/high-level/Key_Generation/001_compute_H_tilde.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/McEliece_KEM/high-level/Key_Generation/001_compute_H_tilde.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/McEliece_KEM/high-level/Key_Generation/003_key_generation.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/McEliece_KEM/high-level/Key_Generation/003_key_generation.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/McEliece_KEM/high-level/Key_Generation/002_mk_gamma.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/McEliece_KEM/high-level/Key_Generation/002_mk_gamma.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/McEliece_KEM/high-level/Encapsulation/002_encapsulation.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/McEliece_KEM/high-level/Encapsulation/002_encapsulation.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/McEliece_KEM/high-level/Encapsulation/001_encoding_subroutine.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/McEliece_KEM/high-level/Encapsulation/001_encoding_subroutine.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/McEliece_KEM/high-level/Decapsulation/003_decrypt.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/McEliece_KEM/high-level/Decapsulation/003_decrypt.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/McEliece_KEM/high-level/Decapsulation/001_get_weight.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/McEliece_KEM/high-level/Decapsulation/001_get_weight.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/McEliece_KEM/high-level/Decapsulation/002_check_e.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/McEliece_KEM/high-level/Decapsulation/002_check_e.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/McEliece_KEM/high-level/Decapsulation/004_decapsulation.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/McEliece_KEM/high-level/Decapsulation/004_decapsulation.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/McEliece_KEM/high-level/Shared/002_cvt_int_bit.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/McEliece_KEM/high-level/Shared/002_cvt_int_bit.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/McEliece_KEM/high-level/Shared/001_cvt_bit_int.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/McEliece_KEM/high-level/Shared/001_cvt_bit_int.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/McEliece_KEM/high-level/Shared/004_compute_H.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/McEliece_KEM/high-level/Shared/004_compute_H.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/McEliece_KEM/high-level/Shared/006_compute_hash_eC.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/McEliece_KEM/high-level/Shared/006_compute_hash_eC.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/McEliece_KEM/high-level/Shared/005_compute_hash_e.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/McEliece_KEM/high-level/Shared/005_compute_hash_e.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/McEliece_KEM/high-level/Shared/003_compute_He.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/McEliece_KEM/high-level/Shared/003_compute_He.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/McEliece_KEM/high-level/Gauss/008_guassian.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/McEliece_KEM/high-level/Gauss/008_guassian.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/McEliece_KEM/high-level/Gauss/005_loop_3.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/McEliece_KEM/high-level/Gauss/005_loop_3.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/McEliece_KEM/high-level/Gauss/003_index.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/McEliece_KEM/high-level/Gauss/003_index.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/McEliece_KEM/high-level/Gauss/004_update_M.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/McEliece_KEM/high-level/Gauss/004_update_M.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/McEliece_KEM/high-level/Gauss/001_glob_M_len1.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/McEliece_KEM/high-level/Gauss/001_glob_M_len1.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/McEliece_KEM/high-level/Gauss/002_glob_b_len2.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/McEliece_KEM/high-level/Gauss/002_glob_b_len2.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/McEliece_KEM/high-level/Gauss/007_big_loop_2.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/McEliece_KEM/high-level/Gauss/007_big_loop_2.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/McEliece_KEM/high-level/Gauss/006_big_loop_1.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/McEliece_KEM/high-level/Gauss/006_big_loop_1.cry
# File failed to load: stored=cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/McEliece_KEM/high-level/Decrypt/001_decrypt_1.cry load_as=aws-lc-verification/cryptol-specs-aes-gcm/McEliece_KEM/high-level/Decrypt/001_decrypt_1.cry
# Processed 2711 files: 1641 passed, 1070 failed.

# %%
filter = df[df["n_imports_original"] != df["n_imports_final"]]

filter.head()
# Out:
#                                               filename filetype  \
# 131  cryptol_slices/cryptol-specs/Primitive/Symmetr...      cry
# 132  cryptol_slices/cryptol-specs/Primitive/Symmetr...      cry
# 133  cryptol_slices/cryptol-specs/Primitive/Symmetr...      cry
# 134  cryptol_slices/cryptol-specs/Primitive/Symmetr...      cry
# 135  cryptol_slices/cryptol-specs/Primitive/Symmetr...      cry
#
#                                                content  n_imports_original  \
# 131  \n\nKs : [80][32]\nKs =\n  [0x5a827999 | t <- ...                   1
# 132  \n\n\n\n\n\ntype shacal1Block = 160\ntype shac...                   1
# 133  \n\n\n\n\n\n\ntype shacal1Block = 160\ntype sh...                   1
# 134  \n\nf : ([8], [32], [32], [32]) -> [32]\nf (t,...                   1
# 135  \n\n\n\n\n\n\ntype shacal1Block = 160\ntype sh...                   1
#
#      n_imports_final
# 131                0
# 132                0
# 133                0
# 134                0
# 135                0

# %%
'''for idx, row in df.iterrows():
    
    print(f"--- ROW {idx} ---")
    print("Filename:", row['filename'])
    print(f"Number of Original Imports: {row['n_imports_original']}, Final Imports: {row['n_imports_final']}")
    print("Content:\n", row['content'], sep='')
    print("*" * 100)
'''
# Out:
# 'for idx, row in df.iterrows():\n\n    print(f"--- ROW {idx} ---")\n    print("Filename:", row[\'filename\'])\n    print(f"Number of Original Imports: {row[\'n_imports_original\']}, Final Imports: {row[\'n_imports_final\']}")\n    print("Content:\n", row[\'content\'], sep=\'\')\n    print("*" * 100)\n'

# %%
df.to_json(f"data/some_slices_verified_{VERSION}.jsonl", lines=True, orient="records")
