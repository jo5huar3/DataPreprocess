# %% [markdown]
# # Cryptol slicer notebook
#
# This notebook calls the Haskell `toy-cryptol-ast` executable to slice Cryptol modules
# into per-definition files. It assumes:
#
# 1. You have the `toy-cryptol-ast` repo checked out.
# 2. You can run `cabal build` or `cabal run toy-cryptol-ast` successfully from that repo.
# 3. You have a local checkout of `cryptol-specs` (or any directory tree of `.cry` files).

# %%
from pathlib import Path
import subprocess

# --- CONFIG: EDIT THESE FOR YOUR MACHINE ---

# Root of your repo/workspace that contains both the Cryptol specs and the file list
BASE_REPO = Path("/Users/josh/SecurityAnalytics")   # <-- adjust if needed

# Path to the file listing all .cry files (e.g., 0_long_files.txt)
FILE_LIST = Path("/Users/josh/SecurityAnalytics/DataPreprocess/syntax_verification_failures.txt")          # <-- adjust if needed

# Root directory where all slice directories will be created
OUTPUT_ROOT = BASE_REPO / "cryptol_slices"

# Directory containing the cabal project for toy-cryptol-ast
CABAL_PROJECT_ROOT = BASE_REPO / "toy-cryptol-ast"  # directory with toy-cryptol-ast.cabal

# %%
def run_haskell_slicer(cry_path: Path, out_dir: Path):
    """
    Call: cabal run toy-cryptol-ast -- <file> <OUTDIR>
    from within CABAL_PROJECT_ROOT.
    """
    out_dir.mkdir(parents=True, exist_ok=True)

    cmd = [
        "cabal",
        "run",
        "toy-cryptol-ast",
        "--",
        str(cry_path),
        str(out_dir),
    ]

    print("Running:", " ".join(cmd))
    result = subprocess.run(
        cmd,
        cwd=str(CABAL_PROJECT_ROOT),  # run inside the cabal project
        capture_output=True,
        text=True,
    )

    if result.returncode != 0:
        print(f"❌ Error ({result.returncode}) on {cry_path}")
        if result.stdout.strip():
            print("STDOUT:\n", result.stdout)
        if result.stderr.strip():
            print("STDERR:\n", result.stderr)
    else:
        print(f"✅ OK: {cry_path}")
        if result.stdout.strip():
            print("STDOUT:\n", result.stdout)

# %%
def iter_file_list(file_list: Path):
    """
    Yield each non-empty, non-comment line from FILE_LIST.
    Lines should be repo-relative paths like:
      cryptol-specs/Primitive/Symmetric/Cipher/Block/KATAN.cry
    """
    with file_list.open() as f:
        for raw in f:
            line = raw.strip()
            if not line:
                continue
            if line.startswith("#"):
                continue
            yield line


def cry_rel_to_paths(rel: str):
    """
    Given a relative .cry path from FILE_LIST, return:
      (absolute_input_path, absolute_output_dir_path)
    Output dir is:
      OUTPUT_ROOT / relative_path_without_.cry_suffix
    """
    cry_rel = Path(rel)
    cry_abs = BASE_REPO / cry_rel

    # Example:
    #   rel: cryptol-specs/Primitive/Symmetric/Cipher/Block/KATAN.cry
    #   out: OUTPUT_ROOT/cryptol-specs/Primitive/Symmetric/Cipher/Block/KATAN/
    out_dir = OUTPUT_ROOT / cry_rel.with_suffix("")

    return cry_abs, out_dir


print(f"Reading list from: {FILE_LIST}")
print(f"Output root:       {OUTPUT_ROOT}")
OUTPUT_ROOT.mkdir(parents=True, exist_ok=True)

for rel in iter_file_list(FILE_LIST):
    cry_path, out_dir = cry_rel_to_paths(rel)

    if not cry_path.is_file():
        print(f"⚠️  Skipping {cry_path} (file not found)")
        continue

    print("\n=== Slicing:", cry_path, "===")
    print("  → output dir:", out_dir)
    run_haskell_slicer(cry_path, out_dir)
# Out:
# Reading list from: /Users/josh/SecurityAnalytics/DataPreprocess/syntax_verification_failures.txt
# Output root:       /Users/josh/SecurityAnalytics/cryptol_slices
#
# === Slicing: /Users/josh/SecurityAnalytics/AES-GCM-SIV-proof/proof/cryptol-specs/intrinsics.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/AES-GCM-SIV-proof/proof/cryptol-specs/intrinsics
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/AES-GCM-SIV-proof/proof/cryptol-specs/intrinsics.cry /Users/josh/SecurityAnalytics/cryptol_slices/AES-GCM-SIV-proof/proof/cryptol-specs/intrinsics
# ✅ OK: /Users/josh/SecurityAnalytics/AES-GCM-SIV-proof/proof/cryptol-specs/intrinsics.cry
# STDOUT:
#  Parse error:
# HappyErrorMsg (Range {from = Position {pLine = 19, pCol = 30, pColOffset = 29}, to = Position {pLine = 19, pCol = 51, pColOffset = 50}, source = "/Users/josh/SecurityAnalytics/AES-GCM-SIV-proof/proof/cryptol-specs/intrinsics.cry"}) ["Explicit type applications can only be applied to named values.","Unexpected: AES_GCM_SIV::mult`{0}"]
#
#
# === Slicing: /Users/josh/SecurityAnalytics/AES-GCM-SIV-proof/proof/asm/cryptol/Asm128.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/AES-GCM-SIV-proof/proof/asm/cryptol/Asm128
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/AES-GCM-SIV-proof/proof/asm/cryptol/Asm128.cry /Users/josh/SecurityAnalytics/cryptol_slices/AES-GCM-SIV-proof/proof/asm/cryptol/Asm128
# ✅ OK: /Users/josh/SecurityAnalytics/AES-GCM-SIV-proof/proof/asm/cryptol/Asm128.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/AES-GCM-SIV-proof/proof/asm/cryptol/AES128_GCM_SIV.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/AES-GCM-SIV-proof/proof/asm/cryptol/AES128_GCM_SIV
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/AES-GCM-SIV-proof/proof/asm/cryptol/AES128_GCM_SIV.cry /Users/josh/SecurityAnalytics/cryptol_slices/AES-GCM-SIV-proof/proof/asm/cryptol/AES128_GCM_SIV
# ✅ OK: /Users/josh/SecurityAnalytics/AES-GCM-SIV-proof/proof/asm/cryptol/AES128_GCM_SIV.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/AES-GCM-SIV-proof/proof/asm/cryptol/X86.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/AES-GCM-SIV-proof/proof/asm/cryptol/X86
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/AES-GCM-SIV-proof/proof/asm/cryptol/X86.cry /Users/josh/SecurityAnalytics/cryptol_slices/AES-GCM-SIV-proof/proof/asm/cryptol/X86
# ✅ OK: /Users/josh/SecurityAnalytics/AES-GCM-SIV-proof/proof/asm/cryptol/X86.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/AES-GCM-SIV-proof/proof/asm/deps/saw-script/doc/tutorial/code/dotprod.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/AES-GCM-SIV-proof/proof/asm/deps/saw-script/doc/tutorial/code/dotprod
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/AES-GCM-SIV-proof/proof/asm/deps/saw-script/doc/tutorial/code/dotprod.cry /Users/josh/SecurityAnalytics/cryptol_slices/AES-GCM-SIV-proof/proof/asm/deps/saw-script/doc/tutorial/code/dotprod
# ✅ OK: /Users/josh/SecurityAnalytics/AES-GCM-SIV-proof/proof/asm/deps/saw-script/doc/tutorial/code/dotprod.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/AES-GCM-SIV-proof/proof/asm/deps/saw-script/examples/sequential_aigs/fib.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/AES-GCM-SIV-proof/proof/asm/deps/saw-script/examples/sequential_aigs/fib
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/AES-GCM-SIV-proof/proof/asm/deps/saw-script/examples/sequential_aigs/fib.cry /Users/josh/SecurityAnalytics/cryptol_slices/AES-GCM-SIV-proof/proof/asm/deps/saw-script/examples/sequential_aigs/fib
# ✅ OK: /Users/josh/SecurityAnalytics/AES-GCM-SIV-proof/proof/asm/deps/saw-script/examples/sequential_aigs/fib.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/AES-GCM-SIV-proof/proof/asm/deps/saw-script/examples/sequential_aigs/CipherMode.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/AES-GCM-SIV-proof/proof/asm/deps/saw-script/examples/sequential_aigs/CipherMode
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/AES-GCM-SIV-proof/proof/asm/deps/saw-script/examples/sequential_aigs/CipherMode.cry /Users/josh/SecurityAnalytics/cryptol_slices/AES-GCM-SIV-proof/proof/asm/deps/saw-script/examples/sequential_aigs/CipherMode
# ✅ OK: /Users/josh/SecurityAnalytics/AES-GCM-SIV-proof/proof/asm/deps/saw-script/examples/sequential_aigs/CipherMode.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/AES-GCM-SIV-proof/proof/asm/deps/saw-script/examples/sequential_aigs/exp.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/AES-GCM-SIV-proof/proof/asm/deps/saw-script/examples/sequential_aigs/exp
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/AES-GCM-SIV-proof/proof/asm/deps/saw-script/examples/sequential_aigs/exp.cry /Users/josh/SecurityAnalytics/cryptol_slices/AES-GCM-SIV-proof/proof/asm/deps/saw-script/examples/sequential_aigs/exp
# ✅ OK: /Users/josh/SecurityAnalytics/AES-GCM-SIV-proof/proof/asm/deps/saw-script/examples/sequential_aigs/exp.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/SAW/spec/AES/AES-GCM-implementation.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/SAW/spec/AES/AES-GCM-implementation
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/SAW/spec/AES/AES-GCM-implementation.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/SAW/spec/AES/AES-GCM-implementation
# ✅ OK: /Users/josh/SecurityAnalytics/aws-lc-verification/SAW/spec/AES/AES-GCM-implementation.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/SAW/spec/AES/AES-GCM.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/SAW/spec/AES/AES-GCM
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/SAW/spec/AES/AES-GCM.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/SAW/spec/AES/AES-GCM
# ✅ OK: /Users/josh/SecurityAnalytics/aws-lc-verification/SAW/spec/AES/AES-GCM.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Common/ModDivZ.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Common/ModDivZ
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Common/ModDivZ.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Common/ModDivZ
# ❌ Error (1) on /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Common/ModDivZ.cry
# STDOUT:
#  Parsed 1 module(s).
#
# STDERR:
#  toy-cryptol-ast: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Common/ModDivZ/004_(%/).cry: withFile: does not exist (No such file or directory)
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/low-level/gf.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/low-level/gf
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/low-level/gf.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/low-level/gf
# ✅ OK: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/low-level/gf.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/low-level/operations.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/low-level/operations
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/low-level/operations.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/low-level/operations
# ✅ OK: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/low-level/operations.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/low-level/benes.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/low-level/benes
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/low-level/benes.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/low-level/benes
# ✅ OK: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/low-level/benes.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/low-level/decrypt.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/low-level/decrypt
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/low-level/decrypt.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/low-level/decrypt
# ✅ OK: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/low-level/decrypt.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/low-level/decrypt_helpers.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/low-level/decrypt_helpers
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/low-level/decrypt_helpers.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/low-level/decrypt_helpers
# ✅ OK: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/low-level/decrypt_helpers.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/low-level/types.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/low-level/types
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/low-level/types.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/low-level/types
# ✅ OK: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/low-level/types.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/low-level/encrypt.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/low-level/encrypt
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/low-level/encrypt.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/low-level/encrypt
# ✅ OK: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/low-level/encrypt.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/CM_696.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/CM_696
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/CM_696.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/CM_696
# ✅ OK: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/CM_696.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/Encapsulation.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/Encapsulation
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/Encapsulation.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/Encapsulation
# ✅ OK: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/Encapsulation.cry
# STDOUT:
#  Parsed 2 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/CM_819.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/CM_819
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/CM_819.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/CM_819
# ✅ OK: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/CM_819.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/Key_Generation.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/Key_Generation
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/Key_Generation.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/Key_Generation
# ✅ OK: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/Key_Generation.cry
# STDOUT:
#  Parsed 2 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/Types.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/Types
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/Types.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/Types
# ✅ OK: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/Types.cry
# STDOUT:
#  Parse error:
# HappyUnexpected "/Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/Types.cry" (Just (Located {srcRange = Range {from = Position {pLine = 48, pCol = 1, pColOffset = 0}, to = Position {pLine = 48, pCol = 14, pColOffset = 13}, source = "/Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/Types.cry"}, thing = Token {tokenType = Op (Other [] "-------------"), tokenText = "-------------"}})) "a declaration"
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/Shared.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/Shared
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/Shared.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/Shared
# ✅ OK: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/Shared.cry
# STDOUT:
#  Parse error:
# HappyErrorMsg (Range {from = Position {pLine = 15, pCol = 13, pColOffset = 12}, to = Position {pLine = 15, pCol = 13, pColOffset = 12}, source = "/Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/Shared.cry"}) ["invalid indentation, unmatched [ ... ]"]
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/Decapsulation.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/Decapsulation
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/Decapsulation.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/Decapsulation
# ✅ OK: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/Decapsulation.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/Encapsulation.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/Encapsulation
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/Encapsulation.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/Encapsulation
# ✅ OK: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/Encapsulation.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/decrypt.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/decrypt
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/decrypt.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/decrypt
# ✅ OK: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/decrypt.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/Gauss.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/Gauss
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/Gauss.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/Gauss
# ✅ OK: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/Gauss.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/Key_Generation.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/Key_Generation
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/Key_Generation.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/Key_Generation
# ✅ OK: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/Key_Generation.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/Types.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/Types
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/Types.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/Types
# ✅ OK: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/Types.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/util.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/util
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/util.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/util
# ✅ OK: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/util.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Common/EC/ref_ec_mul.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Common/EC/ref_ec_mul
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Common/EC/ref_ec_mul.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Common/EC/ref_ec_mul
# ✅ OK: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Common/EC/ref_ec_mul.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Common/EC/p384_ec_point_ops.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Common/EC/p384_ec_point_ops
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Common/EC/p384_ec_point_ops.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Common/EC/p384_ec_point_ops
# ✅ OK: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Common/EC/p384_ec_point_ops.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Common/EC/p384_ec_mul.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Common/EC/p384_ec_mul
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Common/EC/p384_ec_mul.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Common/EC/p384_ec_mul
# ✅ OK: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Common/EC/p384_ec_mul.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Common/EC/PrimeField/PFEC.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Common/EC/PrimeField/PFEC
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Common/EC/PrimeField/PFEC.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Common/EC/PrimeField/PFEC
# ✅ OK: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Common/EC/PrimeField/PFEC.cry
# STDOUT:
#  Parsed 2 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/DilithiumR1BV.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/DilithiumR1BV
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/DilithiumR1BV.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/DilithiumR1BV
# ✅ OK: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/DilithiumR1BV.cry
# STDOUT:
#  Parsed 2 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/DilithiumR1Int.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/DilithiumR1Int
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/DilithiumR1Int.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/DilithiumR1Int
# ✅ OK: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/DilithiumR1Int.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/ECDSA/ECDSA.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/ECDSA/ECDSA
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/ECDSA/ECDSA.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/ECDSA/ECDSA
# ✅ OK: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/ECDSA/ECDSA.cry
# STDOUT:
#  Parsed 2 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/ECDSA/p256.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/ECDSA/p256
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/ECDSA/p256.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/ECDSA/p256
# ✅ OK: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/ECDSA/p256.cry
# STDOUT:
#  Parsed 2 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/ECDSA/ECDSA_tests.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/ECDSA/ECDSA_tests
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/ECDSA/ECDSA_tests.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/ECDSA/ECDSA_tests
# ✅ OK: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/ECDSA/ECDSA_tests.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/ECDSA/ECDSA_sign_tests.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/ECDSA/ECDSA_sign_tests
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/ECDSA/ECDSA_sign_tests.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/ECDSA/ECDSA_sign_tests
# ✅ OK: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/ECDSA/ECDSA_sign_tests.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/ECDSA/p384.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/ECDSA/p384
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/ECDSA/p384.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/ECDSA/p384
# ✅ OK: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/ECDSA/p384.cry
# STDOUT:
#  Parsed 2 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/ECDSA/p192.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/ECDSA/p192
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/ECDSA/p192.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/ECDSA/p192
# ✅ OK: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/ECDSA/p192.cry
# STDOUT:
#  Parsed 2 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/ECDSA/p224.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/ECDSA/p224
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/ECDSA/p224.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/ECDSA/p224
# ✅ OK: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/ECDSA/p224.cry
# STDOUT:
#  Parsed 2 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/DSA/DSA.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/DSA/DSA
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/DSA/DSA.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/DSA/DSA
# ✅ OK: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/DSA/DSA.cry
# STDOUT:
#  Parsed 2 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/trash/DilithiumBv.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/trash/DilithiumBv
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/trash/DilithiumBv.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/trash/DilithiumBv
# ✅ OK: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Asymmetric/Signature/trash/DilithiumBv.cry
# STDOUT:
#  Parsed 2 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Keyless/Hash/HMAC.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Keyless/Hash/HMAC
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Keyless/Hash/HMAC.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Keyless/Hash/HMAC
# ✅ OK: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Keyless/Hash/HMAC.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Keyless/Generator/DRBG.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Keyless/Generator/DRBG
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Keyless/Generator/DRBG.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Keyless/Generator/DRBG
# ✅ OK: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Keyless/Generator/DRBG.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Symmetric/MAC/HMAC.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/MAC/HMAC
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Symmetric/MAC/HMAC.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/MAC/HMAC
# ✅ OK: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Symmetric/MAC/HMAC.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/AES_256_GCM.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/AES_256_GCM
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/AES_256_GCM.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/AES_256_GCM
# ✅ OK: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/AES_256_GCM.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Stream/chacha20.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Stream/chacha20
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Stream/chacha20.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Stream/chacha20
# ✅ OK: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Stream/chacha20.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Stream/ZUC.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Stream/ZUC
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Stream/ZUC.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Stream/ZUC
# ✅ OK: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Stream/ZUC.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AESKeyWrapPadded.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AESKeyWrapPadded
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AESKeyWrapPadded.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AESKeyWrapPadded
# ✅ OK: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AESKeyWrapPadded.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/SHACAL.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/SHACAL
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/SHACAL.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/SHACAL
# ✅ OK: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/SHACAL.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AESKeyWrap.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AESKeyWrap
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AESKeyWrap.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AESKeyWrap
# ✅ OK: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AESKeyWrap.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AES_CBC.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AES_CBC
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AES_CBC.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AES_CBC
# ✅ OK: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AES_CBC.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AES_CTR.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AES_CTR
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AES_CTR.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AES_CTR
# ✅ OK: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AES_CTR.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AES_CFB.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AES_CFB
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AES_CFB.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AES_CFB
# ✅ OK: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/AES_CFB.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Tests/TestAESKeyWrap.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Tests/TestAESKeyWrap
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Tests/TestAESKeyWrap.cry /Users/josh/SecurityAnalytics/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Tests/TestAESKeyWrap
# ✅ OK: /Users/josh/SecurityAnalytics/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Tests/TestAESKeyWrap.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/BLST-Verification/tests/Fp12_tests.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/BLST-Verification/tests/Fp12_tests
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/BLST-Verification/tests/Fp12_tests.cry /Users/josh/SecurityAnalytics/cryptol_slices/BLST-Verification/tests/Fp12_tests
# ✅ OK: /Users/josh/SecurityAnalytics/BLST-Verification/tests/Fp12_tests.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/BLST-Verification/tests/ParameterTests.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/BLST-Verification/tests/ParameterTests
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/BLST-Verification/tests/ParameterTests.cry /Users/josh/SecurityAnalytics/cryptol_slices/BLST-Verification/tests/ParameterTests
# ✅ OK: /Users/josh/SecurityAnalytics/BLST-Verification/tests/ParameterTests.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/BLST-Verification/tests/G2SubGroupCheckTests.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/BLST-Verification/tests/G2SubGroupCheckTests
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/BLST-Verification/tests/G2SubGroupCheckTests.cry /Users/josh/SecurityAnalytics/cryptol_slices/BLST-Verification/tests/G2SubGroupCheckTests
# ✅ OK: /Users/josh/SecurityAnalytics/BLST-Verification/tests/G2SubGroupCheckTests.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/BLST-Verification/tests/ShortWeierstrassCurveTests.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/BLST-Verification/tests/ShortWeierstrassCurveTests
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/BLST-Verification/tests/ShortWeierstrassCurveTests.cry /Users/josh/SecurityAnalytics/cryptol_slices/BLST-Verification/tests/ShortWeierstrassCurveTests
# ✅ OK: /Users/josh/SecurityAnalytics/BLST-Verification/tests/ShortWeierstrassCurveTests.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/BLST-Verification/tests/FrobeniusTests.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/BLST-Verification/tests/FrobeniusTests
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/BLST-Verification/tests/FrobeniusTests.cry /Users/josh/SecurityAnalytics/cryptol_slices/BLST-Verification/tests/FrobeniusTests
# ✅ OK: /Users/josh/SecurityAnalytics/BLST-Verification/tests/FrobeniusTests.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/BLST-Verification/tests/ProjectiveCurveOperationsTests.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/BLST-Verification/tests/ProjectiveCurveOperationsTests
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/BLST-Verification/tests/ProjectiveCurveOperationsTests.cry /Users/josh/SecurityAnalytics/cryptol_slices/BLST-Verification/tests/ProjectiveCurveOperationsTests
# ✅ OK: /Users/josh/SecurityAnalytics/BLST-Verification/tests/ProjectiveCurveOperationsTests.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/BLST-Verification/tests/SerializationTests.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/BLST-Verification/tests/SerializationTests
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/BLST-Verification/tests/SerializationTests.cry /Users/josh/SecurityAnalytics/cryptol_slices/BLST-Verification/tests/SerializationTests
# ✅ OK: /Users/josh/SecurityAnalytics/BLST-Verification/tests/SerializationTests.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/BLST-Verification/tests/PolynomialTest.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/BLST-Verification/tests/PolynomialTest
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/BLST-Verification/tests/PolynomialTest.cry /Users/josh/SecurityAnalytics/cryptol_slices/BLST-Verification/tests/PolynomialTest
# ✅ OK: /Users/josh/SecurityAnalytics/BLST-Verification/tests/PolynomialTest.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/BLST-Verification/tests/ClearCofactorTests.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/BLST-Verification/tests/ClearCofactorTests
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/BLST-Verification/tests/ClearCofactorTests.cry /Users/josh/SecurityAnalytics/cryptol_slices/BLST-Verification/tests/ClearCofactorTests
# ✅ OK: /Users/josh/SecurityAnalytics/BLST-Verification/tests/ClearCofactorTests.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/BLST-Verification/tests/HashToG2Tests.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/BLST-Verification/tests/HashToG2Tests
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/BLST-Verification/tests/HashToG2Tests.cry /Users/josh/SecurityAnalytics/cryptol_slices/BLST-Verification/tests/HashToG2Tests
# ✅ OK: /Users/josh/SecurityAnalytics/BLST-Verification/tests/HashToG2Tests.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/BLST-Verification/tests/HashToCurveE1Tests.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/BLST-Verification/tests/HashToCurveE1Tests
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/BLST-Verification/tests/HashToCurveE1Tests.cry /Users/josh/SecurityAnalytics/cryptol_slices/BLST-Verification/tests/HashToCurveE1Tests
# ✅ OK: /Users/josh/SecurityAnalytics/BLST-Verification/tests/HashToCurveE1Tests.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/BLST-Verification/spec/ProjectiveCurveOperationsA0.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/BLST-Verification/spec/ProjectiveCurveOperationsA0
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/BLST-Verification/spec/ProjectiveCurveOperationsA0.cry /Users/josh/SecurityAnalytics/cryptol_slices/BLST-Verification/spec/ProjectiveCurveOperationsA0
# ✅ OK: /Users/josh/SecurityAnalytics/BLST-Verification/spec/ProjectiveCurveOperationsA0.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/BLST-Verification/spec/Polynomial.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/BLST-Verification/spec/Polynomial
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/BLST-Verification/spec/Polynomial.cry /Users/josh/SecurityAnalytics/cryptol_slices/BLST-Verification/spec/Polynomial
# ✅ OK: /Users/josh/SecurityAnalytics/BLST-Verification/spec/Polynomial.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/BLST-Verification/spec/BLSMinimalPublicKeySize.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/BLST-Verification/spec/BLSMinimalPublicKeySize
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/BLST-Verification/spec/BLSMinimalPublicKeySize.cry /Users/josh/SecurityAnalytics/cryptol_slices/BLST-Verification/spec/BLSMinimalPublicKeySize
# ✅ OK: /Users/josh/SecurityAnalytics/BLST-Verification/spec/BLSMinimalPublicKeySize.cry
# STDOUT:
#  Parsed 2 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/BLST-Verification/spec/CoreVerifyPKInG1.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/BLST-Verification/spec/CoreVerifyPKInG1
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/BLST-Verification/spec/CoreVerifyPKInG1.cry /Users/josh/SecurityAnalytics/cryptol_slices/BLST-Verification/spec/CoreVerifyPKInG1
# ✅ OK: /Users/josh/SecurityAnalytics/BLST-Verification/spec/CoreVerifyPKInG1.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/BLST-Verification/spec/ExtensionField.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/BLST-Verification/spec/ExtensionField
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/BLST-Verification/spec/ExtensionField.cry /Users/josh/SecurityAnalytics/cryptol_slices/BLST-Verification/spec/ExtensionField
# ✅ OK: /Users/josh/SecurityAnalytics/BLST-Verification/spec/ExtensionField.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/BLST-Verification/spec/HashToCurveGeneric.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/BLST-Verification/spec/HashToCurveGeneric
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/BLST-Verification/spec/HashToCurveGeneric.cry /Users/josh/SecurityAnalytics/cryptol_slices/BLST-Verification/spec/HashToCurveGeneric
# ✅ OK: /Users/josh/SecurityAnalytics/BLST-Verification/spec/HashToCurveGeneric.cry
# STDOUT:
#  Parsed 2 module(s).
#
#
# ...
# ✅ OK: /Users/josh/SecurityAnalytics/BLST-Verification/spec/implementation/x86/inverse.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/ckzg-eip-4844-verification/spec/Spec/BlsEC/FQP.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/ckzg-eip-4844-verification/spec/Spec/BlsEC/FQP
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/ckzg-eip-4844-verification/spec/Spec/BlsEC/FQP.cry /Users/josh/SecurityAnalytics/cryptol_slices/ckzg-eip-4844-verification/spec/Spec/BlsEC/FQP
# ❌ Error (1) on /Users/josh/SecurityAnalytics/ckzg-eip-4844-verification/spec/Spec/BlsEC/FQP.cry
# STDOUT:
#  Parsed 1 module(s).
#
# STDERR:
#  toy-cryptol-ast: /Users/josh/SecurityAnalytics/cryptol_slices/ckzg-eip-4844-verification/spec/Spec/BlsEC/FQP/022_(~/~).cry: withFile: does not exist (No such file or directory)
#
#
# === Slicing: /Users/josh/SecurityAnalytics/ckzg-eip-4844-verification/spec/Spec/BlsEC/GP.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/ckzg-eip-4844-verification/spec/Spec/BlsEC/GP
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/ckzg-eip-4844-verification/spec/Spec/BlsEC/GP.cry /Users/josh/SecurityAnalytics/cryptol_slices/ckzg-eip-4844-verification/spec/Spec/BlsEC/GP
# ✅ OK: /Users/josh/SecurityAnalytics/ckzg-eip-4844-verification/spec/Spec/BlsEC/GP.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/ckzg-eip-4844-verification/spec/Spec/BlsEC/Pairing.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/ckzg-eip-4844-verification/spec/Spec/BlsEC/Pairing
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/ckzg-eip-4844-verification/spec/Spec/BlsEC/Pairing.cry /Users/josh/SecurityAnalytics/cryptol_slices/ckzg-eip-4844-verification/spec/Spec/BlsEC/Pairing
# ✅ OK: /Users/josh/SecurityAnalytics/ckzg-eip-4844-verification/spec/Spec/BlsEC/Pairing.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/cryptol/lib/Cryptol.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/cryptol/lib/Cryptol
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/cryptol/lib/Cryptol.cry /Users/josh/SecurityAnalytics/cryptol_slices/cryptol/lib/Cryptol
# ❌ Error (1) on /Users/josh/SecurityAnalytics/cryptol/lib/Cryptol.cry
# STDOUT:
#  Parsed 1 module(s).
#
# STDERR:
#  toy-cryptol-ast: /Users/josh/SecurityAnalytics/cryptol_slices/cryptol/lib/Cryptol/048_(/).cry: withFile: does not exist (No such file or directory)
#
#
# === Slicing: /Users/josh/SecurityAnalytics/cryptol/tests/suiteb/aes-mct-ecb.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/cryptol/tests/suiteb/aes-mct-ecb
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/cryptol/tests/suiteb/aes-mct-ecb.cry /Users/josh/SecurityAnalytics/cryptol_slices/cryptol/tests/suiteb/aes-mct-ecb
# ✅ OK: /Users/josh/SecurityAnalytics/cryptol/tests/suiteb/aes-mct-ecb.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/cryptol/examples/contrib/MISTY1.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/cryptol/examples/contrib/MISTY1
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/cryptol/examples/contrib/MISTY1.cry /Users/josh/SecurityAnalytics/cryptol_slices/cryptol/examples/contrib/MISTY1
# ✅ OK: /Users/josh/SecurityAnalytics/cryptol/examples/contrib/MISTY1.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/cryptol/examples/param_modules/AES_GCM_SIV_Test.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/cryptol/examples/param_modules/AES_GCM_SIV_Test
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/cryptol/examples/param_modules/AES_GCM_SIV_Test.cry /Users/josh/SecurityAnalytics/cryptol_slices/cryptol/examples/param_modules/AES_GCM_SIV_Test
# ✅ OK: /Users/josh/SecurityAnalytics/cryptol/examples/param_modules/AES_GCM_SIV_Test.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/cryptol/examples/param_modules/GCM_AES_Tests.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/cryptol/examples/param_modules/GCM_AES_Tests
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/cryptol/examples/param_modules/GCM_AES_Tests.cry /Users/josh/SecurityAnalytics/cryptol_slices/cryptol/examples/param_modules/GCM_AES_Tests
# ✅ OK: /Users/josh/SecurityAnalytics/cryptol/examples/param_modules/GCM_AES_Tests.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/cryptol/examples/MiniLock/prim/Blake2s.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/cryptol/examples/MiniLock/prim/Blake2s
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/cryptol/examples/MiniLock/prim/Blake2s.cry /Users/josh/SecurityAnalytics/cryptol_slices/cryptol/examples/MiniLock/prim/Blake2s
# ✅ OK: /Users/josh/SecurityAnalytics/cryptol/examples/MiniLock/prim/Blake2s.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/cryptol/examples/MiniLock/prim/Salsa20.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/cryptol/examples/MiniLock/prim/Salsa20
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/cryptol/examples/MiniLock/prim/Salsa20.cry /Users/josh/SecurityAnalytics/cryptol_slices/cryptol/examples/MiniLock/prim/Salsa20
# ✅ OK: /Users/josh/SecurityAnalytics/cryptol/examples/MiniLock/prim/Salsa20.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/cryptol-specs/Primitive/Symmetric/Cipher/Block/Threefish.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Threefish
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/cryptol-specs/Primitive/Symmetric/Cipher/Block/Threefish.cry /Users/josh/SecurityAnalytics/cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Threefish
# ✅ OK: /Users/josh/SecurityAnalytics/cryptol-specs/Primitive/Symmetric/Cipher/Block/Threefish.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/cryptol-specs/Primitive/Symmetric/Cipher/Block/KATAN.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/KATAN
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/cryptol-specs/Primitive/Symmetric/Cipher/Block/KATAN.cry /Users/josh/SecurityAnalytics/cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/KATAN
# ✅ OK: /Users/josh/SecurityAnalytics/cryptol-specs/Primitive/Symmetric/Cipher/Block/KATAN.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/Tests/AES256_KeyWrapPadded_AE.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/Tests/AES256_KeyWrapPadded_AE
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/Tests/AES256_KeyWrapPadded_AE.cry /Users/josh/SecurityAnalytics/cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/Tests/AES256_KeyWrapPadded_AE
# ✅ OK: /Users/josh/SecurityAnalytics/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/Tests/AES256_KeyWrapPadded_AE.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/Tests/AES256_KeyWrapPadded_AD.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/Tests/AES256_KeyWrapPadded_AD
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/Tests/AES256_KeyWrapPadded_AD.cry /Users/josh/SecurityAnalytics/cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/Tests/AES256_KeyWrapPadded_AD
# ✅ OK: /Users/josh/SecurityAnalytics/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/Tests/AES256_KeyWrapPadded_AD.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/cryptol-specs/Primitive/Keyless/Hash/SHA1/Tests/CAVPShortByte.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA1/Tests/CAVPShortByte
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/cryptol-specs/Primitive/Keyless/Hash/SHA1/Tests/CAVPShortByte.cry /Users/josh/SecurityAnalytics/cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA1/Tests/CAVPShortByte
# ✅ OK: /Users/josh/SecurityAnalytics/cryptol-specs/Primitive/Keyless/Hash/SHA1/Tests/CAVPShortByte.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/cryptol-specs/Primitive/Asymmetric/Signature/ML_DSA/Specification.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/cryptol-specs/Primitive/Asymmetric/Signature/ML_DSA/Specification
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/cryptol-specs/Primitive/Asymmetric/Signature/ML_DSA/Specification.cry /Users/josh/SecurityAnalytics/cryptol_slices/cryptol-specs/Primitive/Asymmetric/Signature/ML_DSA/Specification
# ✅ OK: /Users/josh/SecurityAnalytics/cryptol-specs/Primitive/Asymmetric/Signature/ML_DSA/Specification.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/cryptol-specs/Primitive/Asymmetric/Signature/XMSS/Specification.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/cryptol-specs/Primitive/Asymmetric/Signature/XMSS/Specification
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/cryptol-specs/Primitive/Asymmetric/Signature/XMSS/Specification.cry /Users/josh/SecurityAnalytics/cryptol_slices/cryptol-specs/Primitive/Asymmetric/Signature/XMSS/Specification
# ✅ OK: /Users/josh/SecurityAnalytics/cryptol-specs/Primitive/Asymmetric/Signature/XMSS/Specification.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/cryptol-specs/Primitive/Asymmetric/Signature/ECDSA/Tests/ECDSA_P224_SHA3_224.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/cryptol-specs/Primitive/Asymmetric/Signature/ECDSA/Tests/ECDSA_P224_SHA3_224
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/cryptol-specs/Primitive/Asymmetric/Signature/ECDSA/Tests/ECDSA_P224_SHA3_224.cry /Users/josh/SecurityAnalytics/cryptol_slices/cryptol-specs/Primitive/Asymmetric/Signature/ECDSA/Tests/ECDSA_P224_SHA3_224
# ✅ OK: /Users/josh/SecurityAnalytics/cryptol-specs/Primitive/Asymmetric/Signature/ECDSA/Tests/ECDSA_P224_SHA3_224.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/cryptol-specs/Primitive/Asymmetric/Signature/FALCON/1.2/falcon_parameterized.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/cryptol-specs/Primitive/Asymmetric/Signature/FALCON/1.2/falcon_parameterized
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/cryptol-specs/Primitive/Asymmetric/Signature/FALCON/1.2/falcon_parameterized.cry /Users/josh/SecurityAnalytics/cryptol_slices/cryptol-specs/Primitive/Asymmetric/Signature/FALCON/1.2/falcon_parameterized
# ✅ OK: /Users/josh/SecurityAnalytics/cryptol-specs/Primitive/Asymmetric/Signature/FALCON/1.2/falcon_parameterized.cry
# STDOUT:
#  Parsed 2 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/cryptol-specs/Primitive/Asymmetric/Signature/FALCON/1.2/falcon_512.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/cryptol-specs/Primitive/Asymmetric/Signature/FALCON/1.2/falcon_512
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/cryptol-specs/Primitive/Asymmetric/Signature/FALCON/1.2/falcon_512.cry /Users/josh/SecurityAnalytics/cryptol_slices/cryptol-specs/Primitive/Asymmetric/Signature/FALCON/1.2/falcon_512
# ✅ OK: /Users/josh/SecurityAnalytics/cryptol-specs/Primitive/Asymmetric/Signature/FALCON/1.2/falcon_512.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/cryptol-specs/Primitive/Asymmetric/KEM/ML_KEM/Specification.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/cryptol-specs/Primitive/Asymmetric/KEM/ML_KEM/Specification
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/cryptol-specs/Primitive/Asymmetric/KEM/ML_KEM/Specification.cry /Users/josh/SecurityAnalytics/cryptol_slices/cryptol-specs/Primitive/Asymmetric/KEM/ML_KEM/Specification
# ✅ OK: /Users/josh/SecurityAnalytics/cryptol-specs/Primitive/Asymmetric/KEM/ML_KEM/Specification.cry
# STDOUT:
#  Parsed 2 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/cryptol-specs/Common/EC/PrimeField/PFEC.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/cryptol-specs/Common/EC/PrimeField/PFEC
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/cryptol-specs/Common/EC/PrimeField/PFEC.cry /Users/josh/SecurityAnalytics/cryptol_slices/cryptol-specs/Common/EC/PrimeField/PFEC
# ❌ Error (1) on /Users/josh/SecurityAnalytics/cryptol-specs/Common/EC/PrimeField/PFEC.cry
# STDOUT:
#  Parsed 2 module(s).
#
# STDERR:
#  toy-cryptol-ast: /Users/josh/SecurityAnalytics/cryptol_slices/cryptol-specs/Common/EC/PrimeField/PFEC/034_(%/).cry: withFile: does not exist (No such file or directory)
#
#
# === Slicing: /Users/josh/SecurityAnalytics/formal-verso/lib/Values.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/formal-verso/lib/Values
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/formal-verso/lib/Values.cry /Users/josh/SecurityAnalytics/cryptol_slices/formal-verso/lib/Values
# ✅ OK: /Users/josh/SecurityAnalytics/formal-verso/lib/Values.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/saw-demos/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/saw-demos/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/saw-demos/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES.cry /Users/josh/SecurityAnalytics/cryptol_slices/saw-demos/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES
# ✅ OK: /Users/josh/SecurityAnalytics/saw-demos/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/saw-demos/cryptol-specs/Primitive/Asymmetric/Signature/ecdsa.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/saw-demos/cryptol-specs/Primitive/Asymmetric/Signature/ecdsa
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/saw-demos/cryptol-specs/Primitive/Asymmetric/Signature/ecdsa.cry /Users/josh/SecurityAnalytics/cryptol_slices/saw-demos/cryptol-specs/Primitive/Asymmetric/Signature/ecdsa
# ✅ OK: /Users/josh/SecurityAnalytics/saw-demos/cryptol-specs/Primitive/Asymmetric/Signature/ecdsa.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/saw-script/deps/what4/what4/doc/arithdomain.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/saw-script/deps/what4/what4/doc/arithdomain
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/saw-script/deps/what4/what4/doc/arithdomain.cry /Users/josh/SecurityAnalytics/cryptol_slices/saw-script/deps/what4/what4/doc/arithdomain
# ✅ OK: /Users/josh/SecurityAnalytics/saw-script/deps/what4/what4/doc/arithdomain.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/SecurityAnalytics/saw-script/doc/rust-verification-with-saw/code/salsa20/Salsa20.cry ===
#   → output dir: /Users/josh/SecurityAnalytics/cryptol_slices/saw-script/doc/rust-verification-with-saw/code/salsa20/Salsa20
# Running: cabal run toy-cryptol-ast -- /Users/josh/SecurityAnalytics/saw-script/doc/rust-verification-with-saw/code/salsa20/Salsa20.cry /Users/josh/SecurityAnalytics/cryptol_slices/saw-script/doc/rust-verification-with-saw/code/salsa20/Salsa20
# ✅ OK: /Users/josh/SecurityAnalytics/saw-script/doc/rust-verification-with-saw/code/salsa20/Salsa20.cry
# STDOUT:
#  Parsed 1 module(s).
