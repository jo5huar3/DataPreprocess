# %%
from pathlib import Path 
import os, dotenv
dotenv.load_dotenv()
os.chdir(Path(os.getenv("PYTHONPATH")).expanduser())

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json
from src.preprocessing.comment_process import normalize_blanklines, strip_cryptol_comments_all

# %%
jsonl_path = "data/training_datasets/verified_nomods.jsonl"

nomod_df = pd.read_json(jsonl_path, lines=True)

# %%
nomod_df.head()
# Out:
#                                             filename filetype  \
# 0  AES-GCM-SIV-proof/proof/ref-128/clmul_emulator...      saw
# 1         AES-GCM-SIV-proof/proof/ref-128/common.saw      saw
# 2  AES-GCM-SIV-proof/proof/ref-128/aes_emulation.saw      saw
# 3          AES-GCM-SIV-proof/proof/ref-128/proof.saw      saw
# 4      AES-GCM-SIV-proof/proof/cryptol-specs/AES.cry      cry
#
#                                              content
# 0  let {{\nmul_result : [64] -> [64] -> [2][64]\n...
# 1  let allocArg name ty = crucible_fresh_var name...
# 2  \nlet {{\n// Our algorithm is grouped by rows,...
# 3  // Conveninet utilities\ninclude "common.saw";...
# 4  module AES where\n\nimport `Common::AES\n\ntyp...

# %%
nocomment_df = nomod_df.copy()
nocomment_df["content"] = nocomment_df["content"].apply(strip_cryptol_comments_all)
nocomment_df["content"] = nocomment_df["content"].apply(normalize_blanklines)

# %%
nocomment_df.head(20)
# Out:
#                                              filename filetype  \
# 0   AES-GCM-SIV-proof/proof/ref-128/clmul_emulator...      saw
# 1          AES-GCM-SIV-proof/proof/ref-128/common.saw      saw
# 2   AES-GCM-SIV-proof/proof/ref-128/aes_emulation.saw      saw
# 3           AES-GCM-SIV-proof/proof/ref-128/proof.saw      saw
# 4       AES-GCM-SIV-proof/proof/cryptol-specs/AES.cry      cry
# 5    AES-GCM-SIV-proof/proof/cryptol-specs/AES128.cry      cry
# 6   AES-GCM-SIV-proof/proof/cryptol-specs/intrinsi...      cry
# 7    AES-GCM-SIV-proof/proof/cryptol-specs/AES256.cry      cry
# 8      AES-GCM-SIV-proof/proof/cryptol-specs/TBox.cry      cry
# 9       AES-GCM-SIV-proof/proof/ref-256/GCM_SIV_c.saw      saw
# 10  AES-GCM-SIV-proof/proof/ref-256/aes_emulation.saw      saw
# 11  AES-GCM-SIV-proof/proof/cryptol-specs/Common/A...      cry
# 12     AES-GCM-SIV-proof/proof/asm/cryptol/Asm128.cry      cry
# 13  AES-GCM-SIV-proof/proof/asm/cryptol/AES128_GCM...      cry
# 14        AES-GCM-SIV-proof/proof/asm/cryptol/X86.cry      cry
# 15  AES-GCM-SIV-proof/proof/asm/deps/saw-script/in...      saw
# 16  AES-GCM-SIV-proof/proof/asm/deps/saw-script/in...      saw
# 17  AES-GCM-SIV-proof/proof/asm/deps/saw-script/in...      saw
# 18  AES-GCM-SIV-proof/proof/asm/deps/saw-script/in...      saw
# 19  AES-GCM-SIV-proof/proof/asm/deps/saw-script/in...      saw
#
#                                               content
# 0   let {{\nmul_result : [64] -> [64] -> [2][64]\n...
# 1   let allocArg name ty = crucible_fresh_var name...
# 2   let {{\ntoState : [4][32] -> State\ntoState co...
# 3   include "common.saw";\n\nc_code <- llvm_load_m...
# 4   module AES where\n\nimport `Common::AES\n\ntyp...
# 5   module AES128 where\n\nimport `Common::AES\nim...
# 6   module Intrinsics where\n\nimport `Common::AES...
# 7   module AES256 where\n\nimport `Common::AES\nim...
# 8   type Nb         = 4\ntype State      = [4][Nb]...
# 9   AES_256_Key_Expansion <-\n  proof\n    proving...
# 10  let {{\ntoState : [4][32] -> State\ntoState co...
# 11  module Common::AES where\n\nparameter\n  type ...
# 12  module GenAsm128 where\n\nimport X86\nimport A...
# 13  module AES128_GCM_SIV where\n\nimport AES128 a...
# 14  module X86 where\n\nimport AES128\n\naesenc : ...
# 15  let {{ f x = if x == (0:[8]) then (1:[8]) else...
# 16  c <- llvm_load_module "side.bc";\n\nlet alloc_...
# 17  m <- llvm_load_module "./test.bc";\n\ncrucible...
# 18  m <- llvm_load_module "./test.bc";\n\nlet init...
# 19  m <- llvm_load_module "vectortest.bc";\n\nlet ...

# %%
nocomment_df.tail(20)
# Out:
#                                                filename filetype  \
# 1310  saw-script/doc/rust-verification-with-saw/code...      saw
# 1311  saw-script/doc/rust-verification-with-saw/code...      saw
# 1312  saw-script/doc/rust-verification-with-saw/code...      saw
# 1313  saw-script/doc/rust-verification-with-saw/code...      saw
# 1314  saw-script/doc/rust-verification-with-saw/code...      saw
# 1315  saw-script/doc/rust-verification-with-saw/code...      saw
# 1316  saw-script/doc/rust-verification-with-saw/code...      saw
# 1317  saw-script/doc/rust-verification-with-saw/code...      saw
# 1318  saw-script/doc/rust-verification-with-saw/code...      saw
# 1319  saw-script/doc/rust-verification-with-saw/code...      saw
# 1320  saw-script/doc/rust-verification-with-saw/code...      saw
# 1321  saw-script/doc/rust-verification-with-saw/code...      cry
# 1322  saw-script/doc/rust-verification-with-saw/code...      saw
# 1323  saw-script/doc/rust-verification-with-saw/code...      saw
# 1324  saw-script/doc/rust-verification-with-saw/code...      saw
# 1325  saw-script/doc/rust-verification-with-saw/code...      cry
# 1326  saw-script/doc/rust-verification-with-saw/code...      saw
# 1327  saw-script/doc/rust-verification-with-saw/code...      saw
# 1328  saw-script/otherTests/cryptol-saw-core/instanc...      cry
# 1329  saw-script/otherTests/cryptol-saw-core/supercl...      cry
#
#                                                 content
# 1310  enable_experimental;\n\nm <- mir_load_module "...
# 1311  enable_experimental;\n\nm <- mir_load_module "...
# 1312  enable_experimental;\n\nm <- mir_load_module "...
# 1313  enable_experimental;\n\nlet times_two_spec = d...
# 1314  enable_experimental;\n\nm <- mir_load_module "...
# 1315  enable_experimental;\n\nm <- mir_load_module "...
# 1316  enable_experimental;\n\nlet times_two_spec = d...
# 1317  enable_experimental;\n\nlet flip_spec = do {\n...
# 1318  enable_experimental;\n\nlet index_fail_spec = ...
# 1319  enable_experimental;\n\nlet read_ref_spec = do...
# 1320  enable_experimental;\n\nm <- mir_load_module "...
# 1321  module Salsa20Extras where\n\nimport Salsa20\n...
# 1322  enable_experimental;\n\nm <- mir_load_module "...
# 1323  enable_experimental;\n\nm <- mir_load_module "...
# 1324  enable_experimental;\n\nm <- mir_load_module "...
# 1325  module Salsa20 where\n\nquarterround : [4][32]...
# 1326  enable_experimental;\n\nm <- mir_load_module "...
# 1327  enable_experimental;\n\nm <- mir_load_module "...
# 1328  zeroBit : Bit\nzeroBit = zero\n\nzeroInteger :...
# 1329  zeroRing : {a} (Ring a) => a\nzeroRing = zero\...

# %%
nocomment_df["variant"] = "without_comments"
nocomment_df.head()
# Out:
#                                             filename filetype  \
# 0  AES-GCM-SIV-proof/proof/ref-128/clmul_emulator...      saw
# 1         AES-GCM-SIV-proof/proof/ref-128/common.saw      saw
# 2  AES-GCM-SIV-proof/proof/ref-128/aes_emulation.saw      saw
# 3          AES-GCM-SIV-proof/proof/ref-128/proof.saw      saw
# 4      AES-GCM-SIV-proof/proof/cryptol-specs/AES.cry      cry
#
#                                              content           variant
# 0  let {{\nmul_result : [64] -> [64] -> [2][64]\n...  without_comments
# 1  let allocArg name ty = crucible_fresh_var name...  without_comments
# 2  let {{\ntoState : [4][32] -> State\ntoState co...  without_comments
# 3  include "common.saw";\n\nc_code <- llvm_load_m...  without_comments
# 4  module AES where\n\nimport `Common::AES\n\ntyp...  without_comments

# %%
nocomment_df.to_json("data/training_datasets/verified_nocomments.jsonl", orient="records", lines=True, force_ascii=False)

# %%
from src.preprocessing.comment_extractor import extract_strip_cry_comments
# Create Hybrid Dataset
out_path = Path("cache/GPT_comment_decisions_cache.jsonl")
out_path.parent.mkdir(parents=True, exist_ok=True)  # create dirs if missing
DECISION_CACHE_PATH = "cache/GPT_comment_decisions_cache.jsonl"
comment_rows = []
dataset_rows = []
for index, row in nomod_df.iterrows():
    comments, file_record_ = extract_strip_cry_comments(
        filename=row.filename,
        content=row.content,
        llm_model_name="gpt-oss:20b",
        decision_cache_path=DECISION_CACHE_PATH
    )
    comment_rows.extend(comments)
    file_record = {
        "filename": file_record_["filename"],
        "filetype": row.filetype,
        "content": file_record_["content"],
        "variant": "hybrid"
    }
    dataset_rows.append(file_record)

comment_df = pd.DataFrame(comment_rows)
hybrid_df = pd.DataFrame(dataset_rows)

# %%
comment_df.head()
# Out:
#                                             filename  \
# 0         AES-GCM-SIV-proof/proof/ref-128/common.saw
# 1         AES-GCM-SIV-proof/proof/ref-128/common.saw
# 2  AES-GCM-SIV-proof/proof/ref-128/aes_emulation.saw
# 3  AES-GCM-SIV-proof/proof/ref-128/aes_emulation.saw
# 4  AES-GCM-SIV-proof/proof/ref-128/aes_emulation.saw
#
#                                        sha1  \
# 0  c3d48b34470014b7f5ed9e9d4748d1e788e93552
# 1  ceef442edab01d684b21f326c9c65fd1eb9d980c
# 2  27352c3f8e8a5db2e229750ff9c73666cb5e0c1e
# 3  3f2371e7338a838474a148d835d1291aaddb4fda
# 4  aefdf86c5134797994323a3d6a54641ba572ced3
#
#                                              comment  keep  \
# 0            // To little endian byte representation  True
# 1          // A litle endian bytes, to a bit vector.  True
# 2  // Our algorithm is grouped by rows, but the C...  True
# 3  // Our state to the C represenation of the state.  True
# 4                     // Key schedule representation  True
#
#                                              snippet
# 0  toBytes : {n} (fin n) => [8 * n] -> [n][8]\nto...
# 1  fromBytes : {n} (fin n) => [n][8] -> [8 * n]\n...
# 2  toState : [4][32] -> State\ntoState cols = tra...
# 3  fromState : State -> [4][32]\nfromState rows =...
# 4  flatSchedule : KeySchedule -> [44][32]\nflatSc...

# %%
hybrid_df.head()
# Out:
#                                             filename filetype  \
# 0  AES-GCM-SIV-proof/proof/ref-128/clmul_emulator...      saw
# 1         AES-GCM-SIV-proof/proof/ref-128/common.saw      saw
# 2  AES-GCM-SIV-proof/proof/ref-128/aes_emulation.saw      saw
# 3          AES-GCM-SIV-proof/proof/ref-128/proof.saw      saw
# 4      AES-GCM-SIV-proof/proof/cryptol-specs/AES.cry      cry
#
#                                              content variant
# 0  let {{\nmul_result : [64] -> [64] -> [2][64]\n...  hybrid
# 1  let allocArg name ty = crucible_fresh_var name...  hybrid
# 2  let {{\n// Our algorithm is grouped by rows, b...  hybrid
# 3  include "common.saw";\n\n// C code that needs ...  hybrid
# 4  module AES where\n\nimport `Common::AES\n\ntyp...  hybrid

# %%
HYBRID_PATH = "data/training_datasets/verified_hybrid.jsonl"
COMMENT_STAT_PATH = "data/GPTcomment_stats.jsonl"

hybrid_df.to_json(HYBRID_PATH, lines=True, orient="records")
comment_df.to_json(COMMENT_STAT_PATH, lines=True, orient="records")
