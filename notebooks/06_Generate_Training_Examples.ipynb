# %%
from pathlib import Path 
import os, dotenv, yaml

with open("config.yaml", "r") as f:
    config = yaml.safe_load(f)

dotenv.load_dotenv()
os.chdir(Path(config["pythonpath"]).expanduser())

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from dotenv import load_dotenv

# %%
VARIATION = "nocomments"
VERSION = config["version"]

source_code_df = pd.read_json(f"data/clean_datasets/{VARIATION}_{VERSION}.jsonl", lines=True)
source_code_df['filetype'] = source_code_df['filetype'].apply(
    lambda x: 'cryptol' if x == 'cry' else 'saw' if x == 'saw' else 'text'
    )

mcc_df = pd.read_json(f"data/clean_datasets/mcc_stats_{VARIATION}_{VERSION}.jsonl", lines=True)

add_columns = mcc_df.columns.difference(source_code_df.columns).tolist()
print(add_columns)
source_code_df = source_code_df.merge(
    mcc_df[["filename", *add_columns]],
    on="filename",
    how="left",
    validate="one_to_one"
)
#source_code_df.head()
# Out:
# ['avg_mcc', 'imports', 'imports_count', 'json_path', 'max_mcc', 'num_declarations', 'num_declarations_with_mcc', 'num_definitions', 'num_types', 'total_mcc']

# %%
from src.agent.generate import ModelConfig, TemplateBundle, iter_call_pydantic_ai, build_prompt_call_pydantic_ai

file_cache_path = Path(f"cache/alpaca_instruct_cache/SFT_{VARIATION}_source_code_{VERSION}.jsonl")
file_cache_path.parent.mkdir(parents=True, exist_ok=True)  # create dirs if missing

#test_df = source_code_df.sample(10, random_state=42).reset_index(drop=True)

modelConfig = ModelConfig(
    model="openai:gpt-5.1",
    retries=2
)

template = TemplateBundle(
    spec_system="system_spec_simple_gen.j2",
    spec_user="user_spec_simple_gen.j2"
)

result = iter_call_pydantic_ai(
    source_code_df, 
    model_cfg=modelConfig,
    spec_templates=template,
    input_mode="none",
    file_cache_path=file_cache_path
)
result.head()
# Out:
# Processing row 0 / 832: AES-GCM-SIV-proof/proof/cryptol-specs/AES.cry
# Processing row 10 / 832: aws-lc-verification/cryptol-specs/Common/ModDivZ.cry
# Processing row 20 / 832: aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Cipher.cry
# Processing row 30 / 832: aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/CBC.cry
# Processing row 40 / 832: aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/Round.cry
# Processing row 50 / 832: aws-lc-verification/cryptol-specs/Common/EC/p384_field.cry
# Processing row 60 / 832: aws-lc-verification/cryptol-specs/McEliece_KEM/spec/Key_Generation.cry
# Processing row 70 / 832: aws-lc-verification/SAW/spec/AES_KW/X86.cry
# Processing row 80 / 832: aws-lc-verification/cryptol-specs-aes-gcm/Primitive/Symmetric/Cipher/Block/Modes/TDES_CBC.cry
# Processing row 90 / 832: aws-lc-verification/cryptol-specs-aes-gcm/Primitive/Keyless/Hash/SHA3/SHA3_224.cry
# Processing row 100 / 832: aws-lc-verification/cryptol-specs-aes-gcm/McEliece_KEM/high-level/Decrypt.cry
# Processing row 110 / 832: BLST-Verification/spec/Serialization.cry
# Processing row 120 / 832: BLST-Verification/spec/implementation/CryptolHelpers.cry
# Processing row 130 / 832: cryptol/examples/inflist.cry
# Processing row 140 / 832: cryptol/docs/ProgrammingCryptol/enigma/ticket141.cry
# Processing row 150 / 832: cryptol/examples/contrib/A51.cry
# Processing row 160 / 832: cryptol/examples/MiniLock/prim/Base64.cry
# Processing row 170 / 832: cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/AES_GCM_SIV.cry
# Processing row 180 / 832: cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/GCM/Tests/AES128_GCM.cry
# Processing row 190 / 832: cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/CFB.cry
# Processing row 200 / 832: cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/Tests/AES192_CBC.cry
# Processing row 210 / 832: cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/Instantiations/AES192_CTR.cry
# Processing row 220 / 832: cryptol-specs/Primitive/Symmetric/Cipher/Block/Simon/Instantiations/Simon128_128.cry
# Processing row 230 / 832: cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Instantiations/Speck64_96.cry
# Processing row 240 / 832: cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/Instantiations/AES128.cry
# Processing row 250 / 832: cryptol-specs/Primitive/Symmetric/MAC/HMAC/Instantiations/HMAC_SHA1.cry
# Processing row 260 / 832: cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA.cry
# Processing row 270 / 832: cryptol-specs/Primitive/Keyless/Hash/SHA2/Instantiations/SHA256_FFI.cry
# Processing row 280 / 832: cryptol-specs/Primitive/Keyless/Hash/SHA3/Instantiations/SHA3_224.cry
# Processing row 290 / 832: cryptol-specs/Primitive/Asymmetric/Signature/ECDSA/Specification.cry
# Processing row 300 / 832: cryptol-specs/Primitive/Asymmetric/Signature/ECDSA/Instantiations/ECDSA_P384_SHA3_384.cry
# Processing row 310 / 832: cryptol-specs/Primitive/Asymmetric/Signature/XMSS/Instantiations/XMSS_SHA2_10_256_FFI.cry
# Processing row 320 / 832: cryptol-specs/Primitive/Asymmetric/KEM/ECDH/Instantiations/ECDH_P224.cry
# Processing row 330 / 832: formal-verso/lib/Option.cry
# Processing row 340 / 832: saw-script/intTests/test0003_w4/divTest.cry
# Processing row 350 / 832: saw-script/intTests/test0052_smt_array_1/Test.cry
# Processing row 360 / 832: saw-script/intTests/test2337/test.cry
# Processing row 370 / 832: saw-script/examples/sequential_aigs/StateMachine.cry
# Processing row 380 / 832: cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/Tests/AES128_CBC/001_aes128_cbc_encrypt_vector.cry
# Processing row 390 / 832: cryptol_slices/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/Tests/AES256/001_aes256TestVectorsPass.cry
# Processing row 400 / 832: cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA2/Tests/SHA384/004_alphabet896.cry
# Processing row 410 / 832: cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA3/Tests/SHAKE128/003_k1.cry
# Processing row 420 / 832: cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA3/Tests/SHA3_224/004_t512.cry
# Processing row 430 / 832: cryptol_slices/cryptol-specs/Primitive/Keyless/Hash/SHA1/Specification/015_Ch.cry
# Processing row 440 / 832: cryptol_slices/cryptol-specs/Primitive/Asymmetric/Signature/SphincsPlus/3.1/sphincsplus128f/003_PRF_msg.cry
# Processing row 450 / 832: cryptol_slices/cryptol-specs/Common/GF28/008_inverseDefined.cry
# Processing row 460 / 832: cryptol_slices/cryptol-specs/Common/EC/PrimeField/Tests/P192/001_S.cry
# Processing row 470 / 832: cryptol_slices/BLST-Verification/spec/Maybe/003_maybe.cry
# Processing row 480 / 832: cryptol_slices/BLST-Verification/spec/rfc8017/001_I2OSP.cry
# Processing row 490 / 832: cryptol_slices/BLST-Verification/spec/FieldExtras/001_F_sum.cry
# Processing row 500 / 832: cryptol_slices/BLST-Verification/spec/implementation/Types/004_vec512_abs.cry
# Processing row 510 / 832: cryptol_slices/saw-script/intTests/test_FNV_a1_rev/FNV_a1/005_fnv1a_offset_basis.cry
# Processing row 520 / 832: cryptol_slices/saw-script/intTests/test_bisimulation/Comp/003_andImp.cry
# Processing row 530 / 832: cryptol_slices/saw-script/intTests/test0052_smt_array_1/Test/001_lookup_update_axiom_1.cry
# Processing row 540 / 832: cryptol_slices/saw-script/exercises/functional-correctness/swap/solution/Swap/001_swap_list.cry
# Processing row 550 / 832: cryptol_slices/saw-script/examples/llvm/union/test/005_bits_to_inc_2_st.cry
# Processing row 560 / 832: cryptol_slices/saw-script/examples/sequential_aigs/StateMachine/010_sat_miter.cry
# Processing row 570 / 832: cryptol_slices/cryptol/docs/ProgrammingCryptol/enigma/Enigma/010_mkEnigma.cry
# Processing row 580 / 832: cryptol_slices/cryptol/examples/append/001_x.cry
# Processing row 590 / 832: cryptol_slices/cryptol/examples/funstuff/marble/002_popCount.cry
# Processing row 600 / 832: cryptol_slices/cryptol/examples/funstuff/FoxChickenCorn/016_chickenWithCorn.cry
# Processing row 610 / 832: cryptol_slices/cryptol/examples/funstuff/FoxChickenCorn/010_stuffOnlyMovedWithFarmer.cry
# Processing row 620 / 832: cryptol_slices/cryptol/examples/contrib/EvenMansour/002_is_a_permutation.cry
# Processing row 630 / 832: cryptol_slices/cryptol/examples/MiniLock/prim/bv/004_safe_sub.cry
# Processing row 640 / 832: cryptol_slices/cryptol/lib/Cryptol/Reference/002_pdiv.cry
# Processing row 650 / 832: cryptol_slices/formal-verso/lib/Option/002_some.cry
# Processing row 660 / 832: cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/AES_256_GCM/009_EKij.cry
# Processing row 670 / 832: cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/MEE_CBC/004_unpad.cry
# Processing row 680 / 832: cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/AES_GCM/005_testPass4.cry
# Processing row 690 / 832: cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AESKeyWrap/008_wrapBlock.cry
# Processing row 700 / 832: cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/CFB/001_cfbEnc.cry
# Processing row 710 / 832: cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/State/002_stateToMsg.cry
# Processing row 720 / 832: cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/Round/008_InvShiftRows.cry
# Processing row 730 / 832: cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/GF28/008_gf28MatrixMult.cry
# Processing row 740 / 832: cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Keyless/Hash/FNV/002_pad.cry
# Processing row 750 / 832: cryptol_slices/aws-lc-verification/cryptol-specs/Common/Morphism/006_Set_mor.cry
# Processing row 760 / 832: cryptol_slices/aws-lc-verification/cryptol-specs/Common/Set/005_ProdSet.cry
# Processing row 770 / 832: cryptol_slices/aws-lc-verification/cryptol-specs/Common/EC/ref_ec_mul/003_F.cry
# Processing row 780 / 832: cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/Types/010_GFMASK.cry
# Processing row 790 / 832: cryptol_slices/aws-lc-verification/SAW/spec/AES_KW/X86/003_aesenclast.cry
# Processing row 800 / 832: cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Primitive/Symmetric/Cipher/Block/Modes/TDES_CFB/001_cfbTDesEnc.cry
# Processing row 810 / 832: cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Common/ntt/002_all_powers.cry
# Processing row 820 / 832: cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Common/ntt/017_ivroots.cry
# Processing row 830 / 832: cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Common/LUP/011_swap.cry
#                                             filename filetype set  \
# 0      AES-GCM-SIV-proof/proof/cryptol-specs/AES.cry  cryptol
# 1   AES-GCM-SIV-proof/proof/cryptol-specs/AES128.cry  cryptol
# 2   AES-GCM-SIV-proof/proof/cryptol-specs/AES256.cry  cryptol
# 3     AES-GCM-SIV-proof/proof/cryptol-specs/TBox.cry  cryptol
# 4  AES-GCM-SIV-proof/proof/cryptol-specs/Common/A...  cryptol
#
#                                          instruction input output  \
# 0  Write a Cryptol module named AES that defines ...
# 1  Write a Cryptol module named AES128 that expos...
# 2  Write a Cryptol module named AES256 that defin...
# 3  Write a detailed Cryptol specification that ca...
# 4  Write a Cryptol module that defines a paramete...
#
#                                              content
# 0  module AES where\n\nimport `Common::AES\n\ntyp...
# 1  module AES128 where\n\nimport `Common::AES\nim...
# 2  module AES256 where\n\nimport `Common::AES\nim...
# 3  type Nb         = 4\ntype State      = [4][Nb]...
# 4  module Common::AES where\n\nparameter\n  type ...

# %%
import textwrap

WRAP = 80

result_sample = result.sample(10, random_state=42).reset_index(drop=True)

for idx, row in result_sample.iterrows():
    print(f"=== Example {idx}: {row['filename']} ===")
    instr = str(row["instruction"] or "")
    wrapped_instr = "\n\n".join(
        textwrap.fill(p, width=WRAP, break_long_words=False, break_on_hyphens=False)
        for p in instr.splitlines()
    )
    print(f"Instruction:\n{wrapped_instr}\n")
    print(f"Source Code:\n{'=' * WRAP}\n{row['content']}\n{'=' * WRAP}")
# Out:
# === Example 0: cryptol_slices/cryptol/examples/funstuff/FoxChickenCorn/010_stuffOnlyMovedWithFarmer.cry ===
# Instruction:
# Write a detailed Cryptol specification for a state-transition predicate
# stuffOnlyMovedWithFarmer in the classic fox–chicken–corn river crossing puzzle.
# Represent one river bank as a 4-bit word where each bit indicates the presence
# of farmer, fox, chicken, and corn. A BankState should be a record with left and
# right banks. The predicate takes two BankState values (before and after a move)
# and returns true exactly when: the farmer changes banks, at most one non-farmer
# object moves with the farmer, and only items on the farmer’s bank may move.
# Include any helper predicates (e.g., farmerHere, moveFollowsRules, popCount) and
# appropriate polymorphic typing constraints.
#
# Source Code:
# ================================================================================
# type OneBank = [4]
# type BankState = {left : OneBank, right : OneBank}
#
# farmer = 0x1
#
# stuffOnlyMovedWithFarmer : BankState -> BankState -> Bit
# stuffOnlyMovedWithFarmer b b' =
#   if farmerHere b.left
#   then farmerHere b'.right && moveFollowsRules b.left b'.right
#     (b'.right - b.right)
#   else farmerHere b'.left && moveFollowsRules b.right b'.left
#     (b'.left - b.left)
#
# moveFollowsRules fromBank toBank whatMoved =
#   farmerMoved && atMostOneObjectMoved
#   where
#     farmerMoved = (whatMoved && farmer) == farmer
#     atMostOneObjectMoved = popCount (whatMoved && ~farmer) <= 1
#
# farmerHere : OneBank -> Bit
# farmerHere b = (b && farmer) > 0
#
# popCount : {a} (fin a, a >= 1) => [a] -> [width a]
# popCount bs =
#   ic ! 0
#   where
#     ic =
#       [0] # [if elt then prev + 1 else prev | elt <- bs
#                                             | prev <- ic]
#
# ================================================================================
# === Example 1: cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Common/ntt/010_unit.cry ===
# Instruction:
# Write Cryptol code that defines a length-256 standard basis vector over the
# finite field Z/8380417Z, parameterized by an index n < 256, returning an array
# over that field with a single 1 at position n and 0 elsewhere.
#
# Source Code:
# ================================================================================
# type q = 8380417
# type Fld = Z q
# type nn = 256
#
# unit : {n} (n < nn) => [nn]Fld
# unit = [if `n == i then 1 else 0 | i <- [0 .. < nn]]
#
# ================================================================================
# === Example 2: cryptol-specs/Primitive/Asymmetric/Signature/ECDSA/Specification.cry ===
# Instruction:
# Write a Cryptol module that specifies ECDSA signing and verification over an
# abstract elliptic-curve and hash interface, enforcing that the elliptic-curve
# order width is at least 224 bits and that the hash security strength is at least
# the curve’s security strength. Re-export sign, verify, and publicKey.
#
# Source Code:
# ================================================================================
# module Primitive::Asymmetric::Signature::ECDSA::Specification where
#
# import interface Common::EC::ECInterface as EC
#
# import interface Primitive::Keyless::Hash::HashInterface as Hash
#
# import Primitive::Asymmetric::Signature::ECDSA::UnconstrainedSpec
#     { EC = interface EC , Hash = interface Hash } as USpec
#
# interface constraint (width EC::n >= 224)
#
# type ECSecurityStrength = (width EC::n / 2)
#
# interface constraint (ECSecurityStrength <= Hash::SecurityStrength)
#
# sign = USpec::sign
# verify = USpec::verify
# publicKey = USpec::publicKey
#
# ================================================================================
# === Example 3: cryptol_slices/saw-script/examples/sequential_aigs/StateMachine/004_equiv.cry ===
# Instruction:
# Write a Cryptol specification that defines a generic state machine step type SM
# (from input and state to output and next state), along with helper functions to
# run a state machine over a finite sequence of inputs and to extract only the
# output sequence. Then define a Boolean-valued equivalence predicate that, for
# any finite length n, two state machines, and an input sequence of length n,
# returns true exactly when their output traces are elementwise equal. Use a
# zero-initialized state for both machines, require appropriate type class
# constraints (including comparison on outputs and zero for states), and implement
# any needed Boolean fold to aggregate equality results.
#
# Source Code:
# ================================================================================
# type SM i o s = (i, s) -> (o, s)
#
# run : {n, i, s, o} (Zero s) => SM i o s -> [n]i -> [n](o, s)
# run sm is =
#   oss
#   where
#     states = [zero] # [os.1 | os <- oss]
#     oss = [sm (i, s) | i <- is | s <- states]
#
# eval : {n, i, s, o} (Zero s) => SM i o s -> [n]i -> [n](o)
# eval sm is = [os.0 | os <- run sm is]
#
# equiv : {n, i, s1, s2, o}
#   (Cmp o, fin n, Zero s1, Zero s2) =>
#     SM i o s1 -> SM i o s2 -> [n]i -> Bool
# equiv sm1 sm2 is =
#   all [o1 == o2 | o1 <- eval sm1 is | o2 <- eval sm2 is]
#   where
#     all : {m} (fin m) => [m]Bool -> Bool
#     all xs =
#       its ! 0
#       where
#         its = [True] # [x && it | x <- xs | it <- its]
#
# ================================================================================
# === Example 4: cryptol-specs/Common/utils.cry ===
# Instruction:
# Write a Cryptol module named Common::utils that provides general-purpose
# utilities for reasoning about modular arithmetic and higher-order iteration.
# Include: while and do-while style higher-order loops over an arbitrary state
# type; conversions between modular integers and bitvectors (both directions,
# including changing moduli and conversions to/from unbounded integers); an
# integer modulus extraction that enforces a minimum modulus; parity and
# absolute-value helpers; tuple unzipping; small constant-time multipliers by 2,
# 3, 4, and 8; and a type-level constraint capturing odd numbers. Also implement a
# half function over modular integers with an odd modulus, and a corresponding
# property that states adding half x to itself yields x. Finally, provide function
# composition utilities, including composing a list of endofunctions.
#
# Source Code:
# ================================================================================
# module Common::utils where
#
# while : {a} (a -> Bit) -> (a -> a) -> a -> a
# while condition body initial_state =
#   if(condition initial_state) then while condition body (body initial_state)
#   else initial_state
#
# dowhile : {a} (a -> Bit) -> (a -> a) -> a -> a
# dowhile condition body initial_state =
#   if(condition next_state) then while condition body next_state else next_state
#   where next_state = body initial_state
#
# ZtoBV : {p, a} (fin p, p >= 1, fin a) => Z p -> [a]
# ZtoBV x = (fromInteger (fromZ x))
#
# BVtoZ : {p, a} (fin p, p >= 1, fin a) => [a] -> Z p
# BVtoZ x = (fromInteger (toInteger x))
#
# ZtoZ : {p, q} (fin p, fin q, p >= 1, q >= 1) => Z p -> Z q
# ZtoZ x = (fromInteger (fromZ x))
#
# integerToBV : {m} (fin m) => Integer -> [m]
# integerToBV x = fromInteger x
#
# integerFromBV : {m} (fin m) => [m] -> Integer
# integerFromBV x = toInteger x
#
# integerModulusFromBV : {m} (fin m) => [m] -> Integer
# integerModulusFromBV x = if (integerFromBV x) < 3 then 3 else (integerFromBV x)
#
# isEven : Integer -> Bit
# isEven x = ~((fromInteger x) : [1]) ! 0
#
# abs : Integer -> Integer
# abs x = if x >= zero then x else zero-x
#
# unzip : {a,f,s} [a](f,s) -> ([a]f,[a]s)
# unzip tuples = (map (\x -> x.0) tuples , map (\x -> x.1) tuples)
#
# mul2 x = x + x
#
# mul3 x = x + mul2 x
#
# mul4 x = mul2(mul2 x)
#
# mul8 x = mul2(mul4 x)
#
# type constraint isOdd a = (a / 2) * 2 == a - 1
#
# half : {p} (fin p, p >= 3, isOdd p) => Z p -> Z p
# half x = fromInteger (if isEven xint then xint/2 else ((xint + `p) / 2))
#   where
#     xint = fromZ x
#
# half_correct : {p} (fin p, p >= 3, isOdd p) => Z p -> Bit
# property half_correct x = half x + half x == x
#
# compose : {a} () => (a -> a) -> (a -> a) -> a -> a
# compose f g = \x -> g (f x)
#
# composeMany : {nf, a} () => [nf](a -> a) -> a -> a
# composeMany fcns
#     | nf == 0 => \x -> x
#     | nf == 1 => fcns@0
#     | nf == 2 => compose (fcns@0) (fcns@1)
#     | nf > 2  => compose (fcns@0) (composeMany (drop `{1} fcns))
#
# ================================================================================
# === Example 5: cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AESKeyWrap/003_aesUnwrapKey.cry ===
# Instruction:
# Write a detailed Cryptol specification that implements the AES Key Wrap key
# unwrapping algorithm (RFC 3394 style) for arbitrary wrapped key lengths. Your
# code should:
#
#
#
# - Take an AES key, an 8-byte IV, and an n-byte wrapped key, with constraints
# that n ≥ 24, n is a multiple of 8, and the number of 8-byte blocks (n/8) fits in
# 64 bits.
#
# - Implement the iterative unwrap rounds over 6 outer iterations and the
# appropriate inner loop over data blocks, matching the RFC 3394 counter/tweak
# computation.
#
# - Return a pair: a success flag bit indicating whether the IV check passed, and
# the unwrapped key bytes when successful, or zeroed bytes when not.
#
# - Factor the logic into helper definitions for a single unwrap round and a
# single block unwrap.
#
# Source Code:
# ================================================================================
# import Primitive::Symmetric::Cipher::Block::AES
#
#
#
#
#
# aesUnwrapKey : {n}
#   (fin n, n >= 24, n % 8 == 0, width (n / 8) <= 64) =>
#     [AESKeySize] -> [8][8] -> [n][8] -> (Bit, [n - 8][8])
# aesUnwrapKey key iv ciphertext =
#   if (join iv) == A' then (True, split (join R')) else (False, zero)
#   where
#     (A', R') = aesUnwrapKeyUnchecked key ciphertext
# aesUnwrapKeyUnchecked : {n}
#   (fin n, n >= 24, n % 8 == 0, width (n / 8) <= 64) =>
#     [AESKeySize] -> [n][8] -> ([64], [n / 8 - 1][64])
# aesUnwrapKeyUnchecked key ciphertext =
#   intermediates ! 0
#   where
#     A = join (take`{8} ciphertext)
#     R =
#       split`{parts = (n - 8) / 8, each = 64}
#         (join (drop`{8} ciphertext))
#     intermediates =
#       [(A, R)] # [unwrapRound key s j | s <- intermediates
#                                       | j <- [5, 4 .. 0]]
# unwrapRound : {n}
#   (fin n, n >= 1, width n <= 64) =>
#     [AESKeySize] -> ([64], [n][64]) -> [64] -> ([64], [n][64])
# unwrapRound key (A, R) j =
#   unwrappedBlocks ! 0
#   where
#     unwrappedBlocks =
#       [(A, R)] # [unwrapBlock key s j i | s <- unwrappedBlocks
#                                         | i <- [n, n - 1 .. 1]]
# unwrapBlock : {n}
#   (fin n, width n <= 64) =>
#     [AESKeySize] -> ([64], [n][64]) -> [64] -> [64] -> ([64], [n][64])
# unwrapBlock key (A, R) j i =
#   (A', R')
#   where
#     B =
#       aesDecrypt ((A ^ (((`n : [64]) * j) + i)) # (R @ (i - 1)), key)
#     A' = take`{64} B
#     R' = update R (i - 1) (drop`{64} B)
#
# ================================================================================
# === Example 6: cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Common/ntt/016_butterfly.cry ===
# Instruction:
# Write a Cryptol specification that defines an NTT butterfly operation over the
# finite field of integers modulo 8380417, using a fixed primitive root 1753.
# Include a stream of powers of r² for all roots of unity, and define a function
# that, given a depth parameter and two length-n field vectors (even and odd),
# returns the concatenation of the updated left and right outputs using the
# appropriate twiddle factors. Use size-polymorphic types with fin constraints.
#
# Source Code:
# ================================================================================
# type q = 8380417
# type Fld = Z q
#
# r : Fld
# r = 1753
#
# roots : [inf]Fld
# roots = iterate ((*) (r * r)) 1
#
# butterfly : {n}
#   (fin n, n > 0) =>
#     Integer -> [n]Fld -> [n]Fld -> [2 * n]Fld
# butterfly depth even odd =
#   lft # rht
#   where
#     j = 2 ^^ depth
#     lft = [even @ i + roots @ (i * j) * odd @ i | i <- [0 .. < n]]
#     rht = [even @ i - roots @ (i * j) * odd @ i | i <- [0 .. < n]]
#
# ================================================================================
# === Example 7: aws-lc-verification/cryptol-specs-aes-gcm/Primitive/Keyless/Hash/SHA3/SHA3_512.cry ===
# Instruction:
# Write a Cryptol module implementing SHA3-512 as a thin specialization of an
# existing generic SHA3 hash module, setting the digest size to 512 bits.
#
# Source Code:
# ================================================================================
# module Primitive::Keyless::Hash::SHA3::SHA3_512 =
#        Primitive::Keyless::Hash::SHA3::SHA3
#   where
#
# type digest = 512
#
# ================================================================================
# === Example 8: cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA.cry ===
# Instruction:
# Write a Cryptol module that implements the internal SHA-2 word-oriented
# compression and streaming interface, parameterized by a word size and
# round-count. The module should: (1) expose a top-level hash function that takes
# an arbitrary-length bitvector and returns a digest of configurable size, using
# Merkle–Damgård padding based on the bit-length; (2) define the standard SHA-2 Ch
# and Maj boolean functions, message schedule, and compression round function over
# a vector of eight chaining variables and a schedule of j words; (3) define an
# abstract initial vector, round constants, and four sigma/SIGMA functions as
# parameters; and (4) provide a byte-stream state record with init, update, and
# finalization functions, plus an array-based update variant using a byte-array
# abstraction.
#
# Source Code:
# ================================================================================
# module Primitive::Keyless::Hash::SHA2Internal::SHA where
#
# import Array
# import Common::ByteArray
#
# sha : {L} (2 * w >= width L) => [L] -> [digest_size]
# sha M = take (join (SHA_2_Common' [ split x | x <- parse`{num_blocks L} (pad`{L} M) ]))
#
# parameter
#
#   /** Word size
#     Specifications are based on word size w, rather than digest size (8 * w)
#     or block size (m == 16 * w), in order to avoid confusing Cryptol's type
#     constraint verifier with integer division.
#   */
#
#   type wp : #
#   type constraint (fin wp, wp >= 2, 32 >= width wp)
#
#   type digest_size : #
#   type constraint (fin digest_size, 8*wp >= digest_size)
#
#   type j : #
#   type constraint (fin j, j >= 17)
#
#   H0 : [8][wp]
#   K  : [j][wp]
#
#   SIGMA_0 : [wp] -> [wp]
#   SIGMA_1 : [wp] -> [wp]
#   sigma_0 : [wp] -> [wp]
#   sigma_1 : [wp] -> [wp]
#
# SHAH0 = H0
# S0 = SIGMA_0
# S1 = SIGMA_1
# s0 = sigma_0
# s1 = sigma_1
# type digestSize = digest_size
#
# type securityStrength = digest_size / 2
#
# Ch : [wp] -> [wp] -> [wp] -> [wp]
# Ch x y z = (x && y) ^ (~x && z)
#
# Maj : [wp] -> [wp] -> [wp] -> [wp]
# Maj x y z = (x && y) ^ (x && z) ^ (y && z)
#
# processBlock_Common : [8][wp] -> [16][wp] -> [8][wp]
# processBlock_Common H Mi = compress_Common H (messageSchedule_Common Mi)
#
# private
#   type w = wp
#
#   type block_size = 16 * w
#
#   type num_blocks L     = (L+1+2*w) /^ block_size
#   type padded_size L    = num_blocks L * block_size
#
#   pad : {L} (2 * w >= width L) => [L] -> [padded_size L]
#   pad M = M # 0b1 # zero # (`L : [2*w])
#
#   parse : {m} [m * block_size] -> [m][block_size]
#   parse = split
#
#   messageSchedule_Common : [16][w] -> [j][w]
#   messageSchedule_Common Mi = take W
#     where
#     W : [inf][_]
#     W = Mi # [ w1 + s0 w2 + w3 + s1 w4
#              | w1 <- W
#              | w2 <- drop`{1} W
#              | w3 <- drop`{9} W
#              | w4 <- drop`{14} W
#              ]
#
#   compress_Common : [8][w] -> [j][w] -> [8][w]
#   compress_Common H W =
#         [ (as ! 0) + (H @ 0),
#       (bs ! 0) + (H @ 1),
#       (cs ! 0) + (H @ 2),
#       (ds ! 0) + (H @ 3),
#       (es ! 0) + (H @ 4),
#       (fs ! 0) + (H @ 5),
#       (gs ! 0) + (H @ 6),
#       (hs ! 0) + (H @ 7)
#     ]
#     where
#       T1 = [h + S1 e + Ch e f g + k_t + w_t
#                 | h <- hs | e <- es | f <- fs | g <- gs | k_t <- K | w_t <- W]
#       T2 = [ S0 a + Maj a b c | a <- as | b <- bs | c <- cs]
#       hs = take`{j + 1}([H @ 7] # gs)
#       gs = take`{j + 1}([H @ 6] # fs)
#       fs = take`{j + 1}([H @ 5] # es)
#       es = take`{j + 1}([H @ 4] # [d + t1 | d <- ds | t1 <- T1])
#       ds = take`{j + 1}([H @ 3] # cs)
#       cs = take`{j + 1}([H @ 2] # bs)
#       bs = take`{j + 1}([H @ 1] # as)
#       as = take`{j + 1}([H @ 0] # [t1 + t2 | t1 <- T1 | t2 <- T2])
#
#   SHA_2_Common' : {L} (fin L) => [L][16][w] -> [8][w]
#   SHA_2_Common' blocks = hash ! 0
#     where
#     hash = [H0] # [ processBlock_Common h b | h <- hash | b <- blocks]
#
# type SHAState = { h : [8][w]
#                 , block : [w * 2][8]
#                 , n : [32]
#                 , sz : [w * 2]
#                 }
#
# SHAInit : SHAState
# SHAInit = { h = H0
#           , block = zero
#           , n = 0
#           , sz = 0
#           }
#
# SHAUpdate : {n} (fin n) => SHAState -> [n][8] -> SHAState
# SHAUpdate sinit bs = ss!0
#   where ss = [sinit] # [ SHAUpdate1 s b | s <- ss | b <- bs ]
#
# SHAFinal : SHAState -> [digest_size]
# SHAFinal s = take (join (processBlock_Common h b'))
#   // Because the message is always made up of bytes, and the size is a
#   // fixed number of bytes, the 1 pad will always be at least a byte.
#   where s' = SHAUpdate1 s 0x80
#                                         (h, b) = if s'.n <= (`w*2 - (`w/4)) then (s'.h, s'.block)
#                  else (processBlock_Common s'.h (split (join s'.block)), zero)
#         b' = split (join b || (zero # s.sz))
#
# SHAImp : {n} (fin n) => [n][8] -> [digest_size]
# SHAImp msg = SHAFinal (SHAUpdate SHAInit msg)
#
# private
#
#           SHAUpdate1 : SHAState -> [8] -> SHAState
#   SHAUpdate1 s b =
#     if s.n == (2 * `w - 1)
#       then { h = processBlock_Common s.h (split (join (update s.block s.n b)))
#            , block = zero
#            , n = 0
#            , sz = s.sz + 8
#            }
#       else { h = s.h
#            , block = update s.block s.n b
#            , n = s.n + 1
#            , sz = s.sz + 8
#            }
#
# type SHAState_Array =
#   { h : [8][w]
#   , block : ByteArray
#   , n : [32]
#   , sz : [w * 2]
#   }
#
# SHAInit_Array : SHAState_Array
# SHAInit_Array =
#   { h = H0
#   , block = arrayConstant 0
#   , n = 0
#   , sz = 0
#   }
#
# SHAUpdate_Array : (w >= 32) => SHAState_Array -> ByteArray -> [64] -> SHAState_Array
# SHAUpdate_Array state data len =
#   if state.n != 0
#     then if len < 2 * `w - n
#       then state'
#       else state''
#     else state'''
#  where
#    n = 0 # state.n
#    state' = { h = state.h, block = block', n = drop n', sz = state.sz + (0 # len) * 8 }
#     where
#       block' = arrayCopy state.block n data 0 len
#       n' = n + len
#    state'' = { h = h'', block = block''', n = drop n''', sz = state.sz + (0 # len) * 8 }
#     where
#       h' = processBlock state.h (arrayCopy state.block n data 0 (2 * `w - n)) 0
#       block' = arrayCopy state.block n data 0 (2 * `w - n)
#       index' = 2 * `w - n
#       len' = len - (2 * `w - n)
#       (h'', index'', len'') = if len' >= 2 * `w
#         then
#           ( (processBlocks h' (arrayCopy (arrayConstant 0) 0 data index' ((len' / (2 * `w)) * (2 * `w))) 0 (len' / (2 * `w)))
#           , index' + len' - (len' % (2 * `w))
#           , len' % (2 * `w)
#           )
#         else (h', index', len')
#       (block''', n''') = if len'' != 0
#         then ((arrayCopy block' 0 data index'' len''), len'')
#         else (block', 0)
#    state''' = { h = h'', block = block''', n = drop n''', sz = state.sz + (0 # len) * 8 }
#     where
#       (h'', index'', len'') = if len >= 2 * `w
#         then
#           ( (processBlocks state.h data 0 (len / (2 * `w)))
#           , len - (len % (2 * `w))
#           , len % (2 * `w)
#           )
#         else (state.h, 0, len)
#       (block''', n''') = if len'' != 0
#         then ((arrayCopy state.block 0 data index'' len''), len'')
#         else (state.block, n)
#
# SHAFinal_Array : (w >= 32) => SHAState_Array -> [digest_size]
# SHAFinal_Array state = take (join h''')
#   where
#     n = 0 # state.n
#     block' = arrayUpdate state.block n 0x80
#     n' = n + 1
#     (h'', block'', n'') = if n' > 2 * `w - `w / 4
#       then ((processBlock state.h (arraySet block' n' 0 (2 * `w - n')) 0), (arraySet block' n' 0 (2 * `w - n')), 0)
#       else (state.h, block', n')
#     h''' = processBlock
#       h''
#       (arrayRangeUpdate
#         (arraySet block'' n'' 0 (2 * `w - `w / 4 - n''))
#         (2 * `w - `w / 4)
#         (split`{parts=(w+3)/4} (0 # state.sz)))
#       0
#
# // Imperative SHA implementation
# SHAImp_Array : (w >= 32) => ByteArray -> [64] -> [digest_size]
# SHAImp_Array msg len = SHAFinal_Array (SHAUpdate_Array SHAInit_Array msg len)
#
# processBlocks : [8][w] -> ByteArray -> [64] -> [64] -> [8][w]
# processBlocks [a, b, c, d, e, f, g, h] data index n = processBlock [a', b', c', d', e', f', g', h'] data index'
#   where
#     (a', b', c', d', e', f', g', h', index') = processBlocksLoop n data a b c d e f g h index
#
# processBlock : [8][w] -> ByteArray -> [64] -> [8][w]
# processBlock h block index =
#   processBlock_Common h (split (join (arrayRangeLookup block index)))
#
# processBlocksLoop : [64] -> ByteArray -> [w] -> [w] -> [w] -> [w] -> [w] -> [w] -> [w] -> [w] -> [64] -> ([w], [w], [w], [w], [w], [w], [w], [w], [64])
# processBlocksLoop num data a b c d e f g h index = if (index + 2 * `w) < (num * 2 * `w)
#   then processBlocksLoop num data a' b' c' d' e' f' g' h' (index + 2 * `w)
#   else (a, b, c, d, e, f, g, h, index)
#   where
#     [a', b', c', d', e', f', g', h'] = (processBlock [a, b, c, d, e, f, g, h] data index)
#
# arrayRangeEqual_arrayRangeLookup_lemma : {n} (fin n, n >= 1, n <= 1000) => ByteArray -> ByteArray -> Bit
# arrayRangeEqual_arrayRangeLookup_lemma a b = arrayRangeEqual a 0 b 0 `n == (arrayRangeLookup`{n=n} a 0 == arrayRangeLookup b 0)
#
# ================================================================================
# === Example 9: cryptol_slices/saw-script/examples/llvm/union/test/009_inc_2.cry ===
# Instruction:
# Write Cryptol code defining a 32-bit state record with fields x and y, and a
# function inc_2 that returns the state with both fields incremented by one.
#
# Source Code:
# ================================================================================
# type Inc_2_st = {x : [32], y : [32]}
#
# inc_2 : Inc_2_st -> Inc_2_st
# inc_2 st = {x = st.x + 1, y = st.y + 1}
#
# ================================================================================
