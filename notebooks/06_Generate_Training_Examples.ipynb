# %%
from pathlib import Path 
import os, dotenv, yaml

with open("config.yaml", "r") as f:
    config = yaml.safe_load(f)

dotenv.load_dotenv()
os.chdir(Path(config["pythonpath"]).expanduser())

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from dotenv import load_dotenv

# %%
VARIATION = "nocomments"
VERSION = config["version"]

source_code_df = pd.read_json(f"data/clean_datasets/{VARIATION}_{VERSION}.jsonl", lines=True)
source_code_df['filetype'] = source_code_df['filetype'].apply(
    lambda x: 'cryptol' if x == 'cry' else 'saw' if x == 'saw' else 'text'
    )

source_code_df.head()
# Out:
#                                             filename filetype  \
# 0      AES-GCM-SIV-proof/proof/cryptol-specs/AES.cry  cryptol
# 1   AES-GCM-SIV-proof/proof/cryptol-specs/AES128.cry  cryptol
# 2   AES-GCM-SIV-proof/proof/cryptol-specs/AES256.cry  cryptol
# 3     AES-GCM-SIV-proof/proof/cryptol-specs/TBox.cry  cryptol
# 4  AES-GCM-SIV-proof/proof/cryptol-specs/Common/A...  cryptol
#
#                                              content           variant  \
# 0  module AES where\n\nimport `Common::AES\n\ntyp...  without_comments
# 1  module AES128 where\n\nimport `Common::AES\nim...  without_comments
# 2  module AES256 where\n\nimport `Common::AES\nim...  without_comments
# 3  type Nb         = 4\ntype State      = [4][Nb]...  without_comments
# 4  module Common::AES where\n\nparameter\n  type ...  without_comments
#
#    n_imports_original  n_imports_final
# 0                 NaN              NaN
# 1                 NaN              NaN
# 2                 NaN              NaN
# 3                 NaN              NaN
# 4                 NaN              NaN

# %%
from src.agent.generate import ModelConfig, TemplateBundle, iter_call_pydantic_ai, build_prompt_call_pydantic_ai

file_cache_path = Path(f"cache/alpaca_instruct_cache/SFT_{VARIATION}_source_code_{VERSION}.jsonl")
file_cache_path.parent.mkdir(parents=True, exist_ok=True)  # create dirs if missing

test_df = source_code_df.sample(10,_s_sssd_sasdffad_ fffssfad---00asfdfffadsfafsadfsddfafasdfasdffdsaffffsadfrandom_state=42).reset_index(drop=True)

modelConfig = ModelConfig(
    model="openai:gpt-5.1",
    retries=2
)

template = TemplateBundle(
    spec_system="system_spec_simple_gen.j2",
    spec_user="user_spec_simple_gen.j2"
)

result = iter_call_pydantic_ai(
    test_df, 
    model_cfg=modelConfig,
    spec_templates=template,
    input_mode="none",
    file_cache_path=file_cache_path
)
result.head()
# Out:
# File path: cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Common/ntt/010_unit.cry
#
# Relevant Cryptol knowledge (for your analysis only — do not quote verbatim and do not include any code in the instruction):
# -----8<-----
# SOURCE: /Users/josh/Automated_Reasoning_for_Cryptography/DataPreprocess/text/Cryptol-Reference-Manual-MD/Basic-Syntax.md
# ## Numeric Literals
# Numeric literals may be written in binary, octal, decimal, or
# hexadecimal notation. The base of a literal is determined by its prefix:
# `0b` for binary, `0o` for octal, no special prefix for decimal, and `0x`
# for hexadecimal.
#
# ``` cryptol
# 254                 // Decimal literal
# 0254                // Decimal literal
# 0b11111110          // Binary literal
# 0o376               // Octal literal
# 0xFE                // Hexadecimal literal
# 0xfe                // Hexadecimal literal
# ```
#
# Numeric literals in binary, octal, or hexadecimal notation result in bit
# sequences of a fixed length (i.e., they have type `[n]` for some
# <span class="title-ref">n</span>). The length is determined by the base
# and the number of digits in the literal. Decimal literals are
# overloaded, and so the type is inferred from context in which the
# literal is used. Examples:
#
# ``` cryptol
# 0b1010              // : [4],   1 * number of digits
# 0o1234              // : [12],  3 * number of digits
# 0x1234              // : [16],  4 * number of digits
#
# 10                  // : {a}. (Literal 10 a) => a
#                     // a = Integer or [n] where n >= width 10
# ```
#
# Numeric literals may also be written as polynomials by writing a
# polynomial expression in terms of <span class="title-ref">x</span>
# between an opening `<|` and a closing `|>`. Numeric literals in
# polynomial notation result in bit sequences of length one more than the
# degree of the polynomial. Examples:
#
# ``` cryptol
# <| x^^6 + x^^4 + x^^2 + x^^1 + 1 |>  // : [7], equal to 0b1010111
# <| x^^4 + x^^3 + x |>                // : [5], equal to 0b11010
# ```
#
# Cryptol also supports fractional literals using binary (prefix `0b`),
# octal (prefix `0o`), decimal (no prefix), and hexadecimal (prefix `ox`)
# digits. A fractional literal must contain a `.` a
#
# ---
#
# SOURCE: /Users/josh/Automated_Reasoning_for_Cryptography/DataPreprocess/text/Cryptol-Reference-Manual-MD/Foreign-Function-Interface.md
# ### Quick reference
#
#
# | Cryptol type (or kind) | C argument type(s) | C return type | C output argument type(s) |
# |----|----|----|----|
# | `#` | `size_t` | N/A | N/A |
# | `Bit` | `uint8_t` | `uint8_t` | `uint8_t*` |
# | `[K]Bit` where `0  <= K <= 8` | `uint8_t` | `uint8_t` | `uint8_t*` |
# | `[K]Bit` where `8  <  K <= 16` | `uint16_t` | `uint16_t` | `uint16_t*` |
# | `[K]Bit` where `16 <  K <= 32` | `uint32_t` | `uint32_t` | `uint32_t*` |
# | `[K]Bit` where `32 <  K <= 64` | `uint64_t` | `uint64_t` | `uint64_t*` |
# | `Float32` | `float` | `float` | `float*` |
# | `Float64` | `double` | `double` | `double*` |
# | `Integer` | `mpz_t` | N/A | `mpz_t` |
# | `Rational` | `mpq_t` | N/A | `mpq_t` |
# | `Z n` | `mpz_t` | N/A | `mpz_t` |
# | `[n1][n2]...[nk]T` | `U*` | N/A | `U*` |
# | `(T1, T2, ..., Tn)` | `U1, U2, ..., Un` | N/A | `V1, V2, ..., Vn` |
# | `{f1: T1, f2: T2, ..., fn: Tn}` | `U1, U2, ..., Un` | N/A | `V1, V2, ..., Vn` |
#
# where `K` is a constant number, `ni` are variable numbers, `Ti` is a
# type, `Ui` is its C argument type, and `Vi` is its C output argument
# type.
#
# ## Example
#
#
# The Cryptol signature
#
# ``` cryptol
# foreign c fun : {n} (fin n) => [n][10] -> {a : Bit, b : [64]}
#                                -> (Float64, [n + 1][20])
# ```
#
# corresponds to the C signature
#
# ``` c
# void fun(size_t n, uint16_t *in0, uint8_t in1_a, uint64_t in1_b,
#          double *out_0, uint32_t *out_1);
# ```
# -----8<-----
#
# Task: Generate exactly ONE AlpacaRow as JSON with keys: instruction, input, output.
#
# Hard rules:
# - The instruction MUST be standalone: the assistant who will write the Cryptol file will NOT see this excerpt.
# - The instruction must request ONLY Cryptol source code (do NOT ask for SAWScript, external proofs, or non-Cryptol artifacts).
# - Do NOT include any Cryptol snippets or fenced code blocks in the instruction.
#   - No triple backticks, no inline backticks, and do not paste lines from the excerpt or RAG context.
#   - You may mention module/function names and describe types/IO in prose, but do not format them as code.
# - Set input to "" (empty string).
# - Set output to "" (empty string).
# - Keep the instruction <= 150 words.
#
# Code excerpt (context for you only; never copy verbatim into the instruction):
# -----8<-----
# type q = 8380417
# type Fld = Z q
# type nn = 256
#
# unit : {n} (n < nn) => [nn]Fld
# unit = [if `n == i then 1 else 0 | i <- [0 .. < nn]]
#
# -----8<-----
# File path: cryptol-specs/Primitive/Asymmetric/Signature/ECDSA/Specification.cry
#
# Relevant Cryptol knowledge (for your analysis only — do not quote verbatim and do not include any code in the instruction):
# -----8<-----
# SOURCE: /Users/josh/Automated_Reasoning_for_Cryptography/DataPreprocess/text/Cryptol-Reference-Manual-MD/Foreign-Function-Interface.md
# ### Quick reference
#
#
# | Cryptol type (or kind) | C argument type(s) | C return type | C output argument type(s) |
# |----|----|----|----|
# | `#` | `size_t` | N/A | N/A |
# | `Bit` | `uint8_t` | `uint8_t` | `uint8_t*` |
# | `[K]Bit` where `0  <= K <= 8` | `uint8_t` | `uint8_t` | `uint8_t*` |
# | `[K]Bit` where `8  <  K <= 16` | `uint16_t` | `uint16_t` | `uint16_t*` |
# | `[K]Bit` where `16 <  K <= 32` | `uint32_t` | `uint32_t` | `uint32_t*` |
# | `[K]Bit` where `32 <  K <= 64` | `uint64_t` | `uint64_t` | `uint64_t*` |
# | `Float32` | `float` | `float` | `float*` |
# | `Float64` | `double` | `double` | `double*` |
# | `Integer` | `mpz_t` | N/A | `mpz_t` |
# | `Rational` | `mpq_t` | N/A | `mpq_t` |
# | `Z n` | `mpz_t` | N/A | `mpz_t` |
# | `[n1][n2]...[nk]T` | `U*` | N/A | `U*` |
# | `(T1, T2, ..., Tn)` | `U1, U2, ..., Un` | N/A | `V1, V2, ..., Vn` |
# | `{f1: T1, f2: T2, ..., fn: Tn}` | `U1, U2, ..., Un` | N/A | `V1, V2, ..., Vn` |
#
# where `K` is a constant number, `ni` are variable numbers, `Ti` is a
# type, `Ui` is its C argument type, and `Vi` is its C output argument
# type.
#
# ## Example
#
#
# The Cryptol signature
#
# ``` cryptol
# foreign c fun : {n} (fin n) => [n][10] -> {a : Bit, b : [64]}
#                                -> (Float64, [n + 1][20])
# ```
#
# corresponds to the C signature
#
# ``` c
# void fun(size_t n, uint16_t *in0, uint8_t in1_a, uint64_t in1_b,
#          double *out_0, uint32_t *out_1);
# ```
#
# ---
#
# SOURCE: /Users/josh/Automated_Reasoning_for_Cryptography/DataPreprocess/text/Cryptol-Reference-Manual-MD/Overloaded-Operations.md
# ### Enums
#
#
# The following constraints can be derived for enums:
#
# > - `Eq`
# > - `Cmp`
# > - `SignedCmp`
#
# The condition for an enum to be an instance of any of the above
# constraints is that all the fields of all its constructors are instances
# of that constraint. For instance, if you have
#
# ``` cryptol
# enum T a b = A a | B b deriving (Eq, Cmp)
# ```
#
# then `Eq (T a b)` will only hold if `Eq a` and `Eq b` hold, and
# `Cmp (T a b)` will only hold if `Cmp a` and `Cmp b` hold.
#
# Two enum values of the same type compare equal if they have the same
# constructor and the same field values for that constructor, and unequal
# otherwise. For instance, using the `T` type above, `A 0x0 == A 0x0`, but
# `A 0x0 != A 0x1` and `A 0x0 != B 0x0`.
#
# Two enum values of the same type are ordered first by their constructor,
# then for values with the same constructor, by lexicographic ordering on
# the fields of that constructor. The order of constructors is the order
# in which they are listed in the `enum` declaration; constructors listed
# earlier compare less than constructors listed later. In the above
# example of `T a b`, any value with constructor `A` always compares less
# than any value with constructor `B`. So you would have
# `A 0x0 < A 0x1 < B 0x0 < B 0x1`. For signed comparisons, fields are
# compared using signed comparisons but constructors themselves are still
# ordered in the same way, so `A (-1) <$ A 1 <$ B (-1) <$ B 1`.
#
# The `Eq`, `Cmp`, and `SignedCmp` instances for the built-in `Option` and
# `Result` types are actually just standard derived instances, so they
# work the same way as described above (for instance, `None < Some x`,
# `Ok x < Err y`).%\>
#
# <https://galoisinc.github.io/cryptol/master/TypeDeclarations.html> \<%..
# <span id="type-declarations">type-declarations</span>:
# -----8<-----
#
# Task: Generate exactly ONE AlpacaRow as JSON with keys: instruction, input, output.
#
# Hard rules:
# - The instruction MUST be standalone: the assistant who will write the Cryptol file will NOT see this excerpt.
# - The instruction must request ONLY Cryptol source code (do NOT ask for SAWScript, external proofs, or non-Cryptol artifacts).
# - Do NOT include any Cryptol snippets or fenced code blocks in the instruction.
#   - No triple backticks, no inline backticks, and do not paste lines from the excerpt or RAG context.
#   - You may mention module/function names and describe types/IO in prose, but do not format them as code.
# - Set input to "" (empty string).
# - Set output to "" (empty string).
# - Keep the instruction <= 150 words.
#
# Code excerpt (context for you only; never copy verbatim into the instruction):
# -----8<-----
# module Primitive::Asymmetric::Signature::ECDSA::Specification where
#
# import interface Common::EC::ECInterface as EC
#
# import interface Primitive::Keyless::Hash::HashInterface as Hash
#
# import Primitive::Asymmetric::Signature::ECDSA::UnconstrainedSpec
#     { EC = interface EC , Hash = interface Hash } as USpec
#
# interface constraint (width EC::n >= 224)
#
# type ECSecurityStrength = (width EC::n / 2)
#
# interface constraint (ECSecurityStrength <= Hash::SecurityStrength)
#
# sign = USpec::sign
# verify = USpec::verify
# publicKey = USpec::publicKey
#
# -----8<-----
# File path: cryptol_slices/saw-script/examples/sequential_aigs/StateMachine/004_equiv.cry
#
# Relevant Cryptol knowledge (for your analysis only — do not quote verbatim and do not include any code in the instruction):
# -----8<-----
# SOURCE: /Users/josh/Automated_Reasoning_for_Cryptography/DataPreprocess/text/Cryptol-Reference-Manual-MD/Overloaded-Operations.md
# ### Zero
#
#
# ``` cryptol
# Zero
#   zero        : {a} (Zero a) => a
# ```
#
# |                    |                    |
# |--------------------|--------------------|
# | Type               | Condition          |
# | `Bit`              |                    |
# | `Integer`          |                    |
# | `Rational`         |                    |
# | `Z n`              | `fin n`, `n >= 1`  |
# | `Float e p`        | `ValidFloat e p`   |
# | `[n] a`            | `Zero a`           |
# | `a -> b`           | `Zero b`           |
# | `(a,b)`            | `Zero a`, `Zero b` |
# | `{f1 : a, f2 : b}` | `Zero a`, `Zero b` |
#
# Instances
#
# ### Logical Operations
#
#
# ``` cryptol
# Logic
#   (&&)        : {a} (Logic a) => a -> a -> a
#   (||)        : {a} (Logic a) => a -> a -> a
#   (^)         : {a} (Logic a) => a -> a -> a
#   complement  : {a} (Logic a) => a -> a
# ```
#
# |                    |                      |
# |--------------------|----------------------|
# | Type               | Condition            |
# | `Bit`              |                      |
# | `[n] a`            | `Logic a`            |
# | `a -> b`           | `Logic b`            |
# | `(a,b)`            | `Logic a`, `Logic b` |
# | `{f1 : a, f2 : b}` | `Logic a`, `Logic b` |
#
# Instances
#
# ---
#
# SOURCE: /Users/josh/Automated_Reasoning_for_Cryptography/DataPreprocess/text/Cryptol-Reference-Manual-MD/Overloaded-Operations.md
# ### Comparisons
#
#
# ``` cryptol
# Cmp
#   (<)         : {a} (Cmp a) => a -> a -> Bit
#   (>)         : {a} (Cmp a) => a -> a -> Bit
#   (<=)        : {a} (Cmp a) => a -> a -> Bit
#   (>=)        : {a} (Cmp a) => a -> a -> Bit
#   min         : {a} (Cmp a) => a -> a -> a
#   max         : {a} (Cmp a) => a -> a -> a
#   abs         : {a} (Cmp a, Ring a) => a -> a
# ```
#
# |                    |                  |
# |--------------------|------------------|
# | Type               | Condition        |
# | `Bit`              |                  |
# | `Integer`          |                  |
# | `Rational`         |                  |
# | `Float e p`        | `ValidFloat e p` |
# | `[n] a`            | `fin n`, `Cmp a` |
# | `(a,b)`            | `Cmp a`, `Cmp b` |
# | `{f1 : a, f2 : b}` | `Cmp a`, `Cmp b` |
# | `Option a`         | `Cmp a`          |
# | `Result t e`       | `Cmp t`, `Cmp e` |
#
# Instances
#
# ### Signed Comparisons
#
#
# ``` cryptol
# SignedCmp
#   (<$)        : {a} (SignedCmp a) => a -> a -> Bit
#   (>$)        : {a} (SignedCmp a) => a -> a -> Bit
#   (<=$)       : {a} (SignedCmp a) => a -> a -> Bit
#   (>=$)       : {a} (SignedCmp a) => a -> a -> Bit
# ```
#
# |                    |                                    |
# |--------------------|------------------------------------|
# | Type               | Condition                          |
# | `[n] Bit`          | `fin n`, `n >= 1`                  |
# | `[n] a`            | `fin n`, `SignedCmp a`, `a /= Bit` |
# | `(a,b)`            | `SignedCmp a`, `SignedCmp b`       |
# | `{f1 : a, f2 : b}` | `SignedCmp a`, `SignedCmp b`       |
# | `Option a`         | `SignedCmp a`                      |
# | `Result t e`       | `SignedCmp t`, `SignedCmp e`       |
#
# Instances
# -----8<-----
#
# Task: Generate exactly ONE AlpacaRow as JSON with keys: instruction, input, output.
#
# Hard rules:
# - The instruction MUST be standalone: the assistant who will write the Cryptol file will NOT see this excerpt.
# - The instruction must request ONLY Cryptol source code (do NOT ask for SAWScript, external proofs, or non-Cryptol artifacts).
# - Do NOT include any Cryptol snippets or fenced code blocks in the instruction.
#   - No triple backticks, no inline backticks, and do not paste lines from the excerpt or RAG context.
#   - You may mention module/function names and describe types/IO in prose, but do not format them as code.
# - Set input to "" (empty string).
# - Set output to "" (empty string).
# - Keep the instruction <= 150 words.
#
# Code excerpt (context for you only; never copy verbatim into the instruction):
# -----8<-----
# type SM i o s = (i, s) -> (o, s)
#
# run : {n, i, s, o} (Zero s) => SM i o s -> [n]i -> [n](o, s)
# run sm is =
#   oss
#   where
#     states = [zero] # [os.1 | os <- oss]
#     oss = [sm (i, s) | i <- is | s <- states]
#
# eval : {n, i, s, o} (Zero s) => SM i o s -> [n]i -> [n](o)
# eval sm is = [os.0 | os <- run sm is]
#
# equiv : {n, i, s1, s2, o}
#   (Cmp o, fin n, Zero s1, Zero s2) =>
#     SM i o s1 -> SM i o s2 -> [n]i -> Bool
# equiv sm1 sm2 is =
#   all [o1 == o2 | o1 <- eval sm1 is | o2 <- eval sm2 is]
#   where
#     all : {m} (fin m) => [m]Bool -> Bool
#     all xs =
#       its ! 0
#       where
#         its = [True] # [x && it | x <- xs | it <- its]
#
# -----8<-----
# File path: cryptol-specs/Common/utils.cry
#
# Relevant Cryptol knowledge (for your analysis only — do not quote verbatim and do not include any code in the instruction):
# -----8<-----
# SOURCE: /Users/josh/Automated_Reasoning_for_Cryptography/DataPreprocess/text/Cryptol-Reference-Manual-MD/Overloaded-Operations.md
# ### Basic Arithmetic
#
#
# ``` cryptol
# Ring
#   fromInteger : {a} (Ring a) => Integer -> a
#   (+)         : {a} (Ring a) => a -> a -> a
#   (-)         : {a} (Ring a) => a -> a -> a
#   (*)         : {a} (Ring a) => a -> a -> a
#   negate      : {a} (Ring a) => a -> a
#   (^^)        : {a, e} (Ring a, Integral e) => a -> e -> a
# ```
#
# |                    |                       |
# |--------------------|-----------------------|
# | Type               | Condition             |
# | `Integer`          |                       |
# | `Rational`         |                       |
# | `Z n`              | `fin n`, `n >= 1`     |
# | `Float e p`        | `ValidFloat e p`      |
# | `[n] Bit`          | `fin n`               |
# | `[n] a`            | `Ring a`, `a /=  Bit` |
# | `a -> b`           | `Ring b`              |
# | `(a,b)`            | `Ring a`, `Ring b`    |
# | `{f1 : a, f2 : b}` | `Ring a`, `Ring b`    |
#
# Instances
#
# ### Integral Operations
#
#
# ``` cryptol
# Integral
#   (/)         : {a} (Integral a) => a -> a -> a
#   (%)         : {a} (Integral a) => a -> a -> a
#   (^^)        : {a, e} (Ring a, Integral e) => a -> e -> a
#   toInteger   : {a} (Integral a) => a -> Integer
#   infFrom     : {a} (Integral a) => a -> [inf]a
#   infFromThen : {a} (Integral a) => a -> a -> [inf]a
# ```
#
# |           |           |
# |-----------|-----------|
# | Type      | Condition |
# | `Integer` |           |
# | `[n] Bit` | `fin n`   |
#
# Instances
#
# ### Division
#
#
# ``` cryptol
# Field
#   recip       : {a} (Field a) => a -> a
#   (/.)        : {a} (Field a) => a -> a -> a
# ```
#
# |             |                  |
# |-------------|------------------|
# | Type        | Condition        |
# | `Rational`  |                  |
# | `Z n`       | `prime n`        |
# | `Float e p` | `ValidFloat e p` |
#
# Instances
#
# ---
#
# SOURCE: /Users/josh/Automated_Reasoning_for_Cryptography/DataPreprocess/text/Cryptol-Reference-Manual-MD/Basic-Syntax.md
# ## Built-in Type-level Operators
# Cryptol includes a variety of operators that allow computations on the
# numeric types used to specify the sizes of sequences.
#
# <table style="width:75%;">
# <caption>Type-level operators</caption>
# <colgroup>
# <col style="width: 18%" />
# <col style="width: 56%" />
# </colgroup>
# <thead>
# <tr>
# <th>Operator</th>
# <th><blockquote>
# <p>Meaning</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td><blockquote>
# <p><code>+</code></p>
# </blockquote></td>
# <td><blockquote>
# <p>Addition</p>
# </blockquote></td>
# </tr>
# <tr>
# <td><blockquote>
# <p><code>-</code></p>
# </blockquote></td>
# <td><blockquote>
# <p>Subtraction</p>
# </blockquote></td>
# </tr>
# <tr>
# <td><blockquote>
# <p><code>*</code></p>
# </blockquote></td>
# <td><blockquote>
# <p>Multiplication</p>
# </blockquote></td>
# </tr>
# <tr>
# <td><blockquote>
# <p><code>/</code></p>
# </blockquote></td>
# <td><blockquote>
# <p>Division</p>
# </blockquote></td>
# </tr>
# <tr>
# <td><blockquote>
# <p><code>/^</code></p>
# </blockquote></td>
# <td><blockquote>
# <p>Ceiling division (<code>/</code> rounded up)</p>
# </blockquote></td>
# </tr>
# <tr>
# <td><blockquote>
# <p><code>%</code></p>
# </blockquote></td>
# <td><blockquote>
# <p>Modulus</p>
# </blockquote></td>
# </tr>
# <tr>
# <td><blockquote>
# <p><code>%^</code></p>
# </blockquote></td>
# <td><blockquote>
# <p>Ceiling modulus (compute padding)</p>
# </blockquote></td>
# </tr>
# <tr>
# <td><blockquote>
# <p><code>^^</code></p>
# </blockquote></td>
# <td><blockquote>
# <p>Exponentiation</p>
# </blockquote></td>
# </tr>
# <tr>
# <td><blockquote>
# <p><code>lg2</code></p>
# </blockquote></td>
# <td><blockquote>
# <p>Ceiling logarithm (base 2)</p>
# </blockquote></td>
# </tr>
# <tr>
# <td><blockquote>
# <p><code>width</code></p>
# </blockquote></td>
# <td><blockquote>
# <p>Bit width (equal to <code>lg2(n+1)</code>)</p>
# </blockquote></td>
# </tr>
# <tr>
# <td><blockquote>
# <p><code>max</code></p>
# -----8<-----
#
# Task: Generate exactly ONE AlpacaRow as JSON with keys: instruction, input, output.
#
# Hard rules:
# - The instruction MUST be standalone: the assistant who will write the Cryptol file will NOT see this excerpt.
# - The instruction must request ONLY Cryptol source code (do NOT ask for SAWScript, external proofs, or non-Cryptol artifacts).
# - Do NOT include any Cryptol snippets or fenced code blocks in the instruction.
#   - No triple backticks, no inline backticks, and do not paste lines from the excerpt or RAG context.
#   - You may mention module/function names and describe types/IO in prose, but do not format them as code.
# - Set input to "" (empty string).
# - Set output to "" (empty string).
# - Keep the instruction <= 150 words.
#
# Code excerpt (context for you only; never copy verbatim into the instruction):
# -----8<-----
# module Common::utils where
#
# while : {a} (a -> Bit) -> (a -> a) -> a -> a
# while condition body initial_state =
#   if(condition initial_state) then while condition body (body initial_state)
#   else initial_state
#
# dowhile : {a} (a -> Bit) -> (a -> a) -> a -> a
# dowhile condition body initial_state =
#   if(condition next_state) then while condition body next_state else next_state
#   where next_state = body initial_state
#
# ZtoBV : {p, a} (fin p, p >= 1, fin a) => Z p -> [a]
# ZtoBV x = (fromInteger (fromZ x))
#
# BVtoZ : {p, a} (fin p, p >= 1, fin a) => [a] -> Z p
# BVtoZ x = (fromInteger (toInteger x))
#
# ZtoZ : {p, q} (fin p, fin q, p >= 1, q >= 1) => Z p -> Z q
# ZtoZ x = (fromInteger (fromZ x))
#
# integerToBV : {m} (fin m) => Integer -> [m]
# integerToBV x = fromInteger x
#
# integerFromBV : {m} (fin m) => [m] -> Integer
# integerFromBV x = toInteger x
#
# integerModulusFromBV : {m} (fin m) => [m] -> Integer
# integerModulusFromBV x = if (integerFromBV x) < 3 then 3 else (integerFromBV x)
#
# isEven : Integer -> Bit
# isEven x = ~((fromInteger x) : [1]) ! 0
#
# abs : Integer -> Integer
# abs x = if x >= zero then x else zero-x
#
# unzip : {a,f,s} [a](f,s) -> ([a]f,[a]s)
# unzip tuples = (map (\x -> x.0) tuples , map (\x -> x.1) tuples)
#
# mul2 x = x + x
#
# mul3 x = x + mul2 x
#
# mul4 x = mul2(mul2 x)
#
# mul8 x = mul2(mul4 x)
#
# type constraint isOdd a = (a / 2) * 2 == a - 1
#
# half : {p} (fin p, p >= 3, isOdd p) => Z p -> Z p
# half x = fromInteger (if isEven xint then xint/2 else ((xint + `p) / 2))
#   where
#     xint = fromZ x
#
# half_correct : {p} (fin p, p >= 3, isOdd p) => Z p -> Bit
# property half_correct x = half x + half x == x
#
# compose : {a} () => (a -> a) -> (a -> a) -> a -> a
# compose f g = \x -> g (f x)
#
# composeMany : {nf, a} () => [nf](a -> a) -> a -> a
# composeMany fcns
#     | nf == 0 => \x -> x
#     | nf == 1 => fcns@0
#     | nf == 2 => compose (fcns@0) (fcns@1)
#     | nf > 2  => compose (fcns@0) (composeMany (drop `{1} fcns))
#
# -----8<-----
# File path: cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AESKeyWrap/003_aesUnwrapKey.cry
#
# Relevant Cryptol knowledge (for your analysis only — do not quote verbatim and do not include any code in the instruction):
# -----8<-----
# SOURCE: /Users/josh/Automated_Reasoning_for_Cryptography/DataPreprocess/text/Cryptol-Reference-Manual-MD/Foreign-Function-Interface.md
# ### Quick reference
#
#
# | Cryptol type (or kind) | C argument type(s) | C return type | C output argument type(s) |
# |----|----|----|----|
# | `#` | `size_t` | N/A | N/A |
# | `Bit` | `uint8_t` | `uint8_t` | `uint8_t*` |
# | `[K]Bit` where `0  <= K <= 8` | `uint8_t` | `uint8_t` | `uint8_t*` |
# | `[K]Bit` where `8  <  K <= 16` | `uint16_t` | `uint16_t` | `uint16_t*` |
# | `[K]Bit` where `16 <  K <= 32` | `uint32_t` | `uint32_t` | `uint32_t*` |
# | `[K]Bit` where `32 <  K <= 64` | `uint64_t` | `uint64_t` | `uint64_t*` |
# | `Float32` | `float` | `float` | `float*` |
# | `Float64` | `double` | `double` | `double*` |
# | `Integer` | `mpz_t` | N/A | `mpz_t` |
# | `Rational` | `mpq_t` | N/A | `mpq_t` |
# | `Z n` | `mpz_t` | N/A | `mpz_t` |
# | `[n1][n2]...[nk]T` | `U*` | N/A | `U*` |
# | `(T1, T2, ..., Tn)` | `U1, U2, ..., Un` | N/A | `V1, V2, ..., Vn` |
# | `{f1: T1, f2: T2, ..., fn: Tn}` | `U1, U2, ..., Un` | N/A | `V1, V2, ..., Vn` |
#
# where `K` is a constant number, `ni` are variable numbers, `Ti` is a
# type, `Ui` is its C argument type, and `Vi` is its C output argument
# type.
#
# ## Example
#
#
# The Cryptol signature
#
# ``` cryptol
# foreign c fun : {n} (fin n) => [n][10] -> {a : Bit, b : [64]}
#                                -> (Float64, [n + 1][20])
# ```
#
# corresponds to the C signature
#
# ``` c
# void fun(size_t n, uint16_t *in0, uint8_t in1_a, uint64_t in1_b,
#          double *out_0, uint32_t *out_1);
# ```
#
# ---
#
# SOURCE: /Users/josh/Automated_Reasoning_for_Cryptography/DataPreprocess/text/Cryptol-Reference-Manual-MD/Overloaded-Operations.md
# ### Basic Arithmetic
#
#
# ``` cryptol
# Ring
#   fromInteger : {a} (Ring a) => Integer -> a
#   (+)         : {a} (Ring a) => a -> a -> a
#   (-)         : {a} (Ring a) => a -> a -> a
#   (*)         : {a} (Ring a) => a -> a -> a
#   negate      : {a} (Ring a) => a -> a
#   (^^)        : {a, e} (Ring a, Integral e) => a -> e -> a
# ```
#
# |                    |                       |
# |--------------------|-----------------------|
# | Type               | Condition             |
# | `Integer`          |                       |
# | `Rational`         |                       |
# | `Z n`              | `fin n`, `n >= 1`     |
# | `Float e p`        | `ValidFloat e p`      |
# | `[n] Bit`          | `fin n`               |
# | `[n] a`            | `Ring a`, `a /=  Bit` |
# | `a -> b`           | `Ring b`              |
# | `(a,b)`            | `Ring a`, `Ring b`    |
# | `{f1 : a, f2 : b}` | `Ring a`, `Ring b`    |
#
# Instances
#
# ### Integral Operations
#
#
# ``` cryptol
# Integral
#   (/)         : {a} (Integral a) => a -> a -> a
#   (%)         : {a} (Integral a) => a -> a -> a
#   (^^)        : {a, e} (Ring a, Integral e) => a -> e -> a
#   toInteger   : {a} (Integral a) => a -> Integer
#   infFrom     : {a} (Integral a) => a -> [inf]a
#   infFromThen : {a} (Integral a) => a -> a -> [inf]a
# ```
#
# |           |           |
# |-----------|-----------|
# | Type      | Condition |
# | `Integer` |           |
# | `[n] Bit` | `fin n`   |
#
# Instances
#
# ### Division
#
#
# ``` cryptol
# Field
#   recip       : {a} (Field a) => a -> a
#   (/.)        : {a} (Field a) => a -> a -> a
# ```
#
# |             |                  |
# |-------------|------------------|
# | Type        | Condition        |
# | `Rational`  |                  |
# | `Z n`       | `prime n`        |
# | `Float e p` | `ValidFloat e p` |
#
# Instances
# -----8<-----
#
# Task: Generate exactly ONE AlpacaRow as JSON with keys: instruction, input, output.
#
# Hard rules:
# - The instruction MUST be standalone: the assistant who will write the Cryptol file will NOT see this excerpt.
# - The instruction must request ONLY Cryptol source code (do NOT ask for SAWScript, external proofs, or non-Cryptol artifacts).
# - Do NOT include any Cryptol snippets or fenced code blocks in the instruction.
#   - No triple backticks, no inline backticks, and do not paste lines from the excerpt or RAG context.
#   - You may mention module/function names and describe types/IO in prose, but do not format them as code.
# - Set input to "" (empty string).
# - Set output to "" (empty string).
# - Keep the instruction <= 150 words.
#
# Code excerpt (context for you only; never copy verbatim into the instruction):
# -----8<-----
# import Primitive::Symmetric::Cipher::Block::AES
#
#
#
#
#
# aesUnwrapKey : {n}
#   (fin n, n >= 24, n % 8 == 0, width (n / 8) <= 64) =>
#     [AESKeySize] -> [8][8] -> [n][8] -> (Bit, [n - 8][8])
# aesUnwrapKey key iv ciphertext =
#   if (join iv) == A' then (True, split (join R')) else (False, zero)
#   where
#     (A', R') = aesUnwrapKeyUnchecked key ciphertext
# aesUnwrapKeyUnchecked : {n}
#   (fin n, n >= 24, n % 8 == 0, width (n / 8) <= 64) =>
#     [AESKeySize] -> [n][8] -> ([64], [n / 8 - 1][64])
# aesUnwrapKeyUnchecked key ciphertext =
#   intermediates ! 0
#   where
#     A = join (take`{8} ciphertext)
#     R =
#       split`{parts = (n - 8) / 8, each = 64}
#         (join (drop`{8} ciphertext))
#     intermediates =
#       [(A, R)] # [unwrapRound key s j | s <- intermediates
#                                       | j <- [5, 4 .. 0]]
# unwrapRound : {n}
#   (fin n, n >= 1, width n <= 64) =>
#     [AESKeySize] -> ([64], [n][64]) -> [64] -> ([64], [n][64])
# unwrapRound key (A, R) j =
#   unwrappedBlocks ! 0
#   where
#     unwrappedBlocks =
#       [(A, R)] # [unwrapBlock key s j i | s <- unwrappedBlocks
#                                         | i <- [n, n - 1 .. 1]]
# unwrapBlock : {n}
#   (fin n, width n <= 64) =>
#     [AESKeySize] -> ([64], [n][64]) -> [64] -> [64] -> ([64], [n][64])
# unwrapBlock key (A, R) j i =
#   (A', R')
#   where
#     B =
#       aesDecrypt ((A ^ (((`n : [64]) * j) + i)) # (R @ (i - 1)), key)
#     A' = take`{64} B
#     R' = update R (i - 1) (drop`{64} B)
#
# -----8<-----
# File path: cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Common/ntt/016_butterfly.cry
#
# Relevant Cryptol knowledge (for your analysis only — do not quote verbatim and do not include any code in the instruction):
# -----8<-----
# SOURCE: /Users/josh/Automated_Reasoning_for_Cryptography/DataPreprocess/text/Cryptol-Reference-Manual-MD/Foreign-Function-Interface.md
# ### Quick reference
#
#
# | Cryptol type (or kind) | C argument type(s) | C return type | C output argument type(s) |
# |----|----|----|----|
# | `#` | `size_t` | N/A | N/A |
# | `Bit` | `uint8_t` | `uint8_t` | `uint8_t*` |
# | `[K]Bit` where `0  <= K <= 8` | `uint8_t` | `uint8_t` | `uint8_t*` |
# | `[K]Bit` where `8  <  K <= 16` | `uint16_t` | `uint16_t` | `uint16_t*` |
# | `[K]Bit` where `16 <  K <= 32` | `uint32_t` | `uint32_t` | `uint32_t*` |
# | `[K]Bit` where `32 <  K <= 64` | `uint64_t` | `uint64_t` | `uint64_t*` |
# | `Float32` | `float` | `float` | `float*` |
# | `Float64` | `double` | `double` | `double*` |
# | `Integer` | `mpz_t` | N/A | `mpz_t` |
# | `Rational` | `mpq_t` | N/A | `mpq_t` |
# | `Z n` | `mpz_t` | N/A | `mpz_t` |
# | `[n1][n2]...[nk]T` | `U*` | N/A | `U*` |
# | `(T1, T2, ..., Tn)` | `U1, U2, ..., Un` | N/A | `V1, V2, ..., Vn` |
# | `{f1: T1, f2: T2, ..., fn: Tn}` | `U1, U2, ..., Un` | N/A | `V1, V2, ..., Vn` |
#
# where `K` is a constant number, `ni` are variable numbers, `Ti` is a
# type, `Ui` is its C argument type, and `Vi` is its C output argument
# type.
#
# ## Example
#
#
# The Cryptol signature
#
# ``` cryptol
# foreign c fun : {n} (fin n) => [n][10] -> {a : Bit, b : [64]}
#                                -> (Float64, [n + 1][20])
# ```
#
# corresponds to the C signature
#
# ``` c
# void fun(size_t n, uint16_t *in0, uint8_t in1_a, uint64_t in1_b,
#          double *out_0, uint32_t *out_1);
# ```
#
# ---
#
# SOURCE: /Users/josh/Automated_Reasoning_for_Cryptography/DataPreprocess/text/Cryptol-Reference-Manual-MD/Basic-Syntax.md
# ## Numeric Literals
# Numeric literals may be written in binary, octal, decimal, or
# hexadecimal notation. The base of a literal is determined by its prefix:
# `0b` for binary, `0o` for octal, no special prefix for decimal, and `0x`
# for hexadecimal.
#
# ``` cryptol
# 254                 // Decimal literal
# 0254                // Decimal literal
# 0b11111110          // Binary literal
# 0o376               // Octal literal
# 0xFE                // Hexadecimal literal
# 0xfe                // Hexadecimal literal
# ```
#
# Numeric literals in binary, octal, or hexadecimal notation result in bit
# sequences of a fixed length (i.e., they have type `[n]` for some
# <span class="title-ref">n</span>). The length is determined by the base
# and the number of digits in the literal. Decimal literals are
# overloaded, and so the type is inferred from context in which the
# literal is used. Examples:
#
# ``` cryptol
# 0b1010              // : [4],   1 * number of digits
# 0o1234              // : [12],  3 * number of digits
# 0x1234              // : [16],  4 * number of digits
#
# 10                  // : {a}. (Literal 10 a) => a
#                     // a = Integer or [n] where n >= width 10
# ```
#
# Numeric literals may also be written as polynomials by writing a
# polynomial expression in terms of <span class="title-ref">x</span>
# between an opening `<|` and a closing `|>`. Numeric literals in
# polynomial notation result in bit sequences of length one more than the
# degree of the polynomial. Examples:
#
# ``` cryptol
# <| x^^6 + x^^4 + x^^2 + x^^1 + 1 |>  // : [7], equal to 0b1010111
# <| x^^4 + x^^3 + x |>                // : [5], equal to 0b11010
# ```
#
# Cryptol also supports fractional literals using binary (prefix `0b`),
# octal (prefix `0o`), decimal (no prefix), and hexadecimal (prefix `ox`)
# digits. A fractional literal must contain a `.` a
# -----8<-----
#
# Task: Generate exactly ONE AlpacaRow as JSON with keys: instruction, input, output.
#
# Hard rules:
# - The instruction MUST be standalone: the assistant who will write the Cryptol file will NOT see this excerpt.
# - The instruction must request ONLY Cryptol source code (do NOT ask for SAWScript, external proofs, or non-Cryptol artifacts).
# - Do NOT include any Cryptol snippets or fenced code blocks in the instruction.
#   - No triple backticks, no inline backticks, and do not paste lines from the excerpt or RAG context.
#   - You may mention module/function names and describe types/IO in prose, but do not format them as code.
# - Set input to "" (empty string).
# - Set output to "" (empty string).
# - Keep the instruction <= 150 words.
#
# Code excerpt (context for you only; never copy verbatim into the instruction):
# -----8<-----
# type q = 8380417
# type Fld = Z q
#
# r : Fld
# r = 1753
#
# roots : [inf]Fld
# roots = iterate ((*) (r * r)) 1
#
# butterfly : {n}
#   (fin n, n > 0) =>
#     Integer -> [n]Fld -> [n]Fld -> [2 * n]Fld
# butterfly depth even odd =
#   lft # rht
#   where
#     j = 2 ^^ depth
#     lft = [even @ i + roots @ (i * j) * odd @ i | i <- [0 .. < n]]
#     rht = [even @ i - roots @ (i * j) * odd @ i | i <- [0 .. < n]]
#
# -----8<-----
# File path: aws-lc-verification/cryptol-specs-aes-gcm/Primitive/Keyless/Hash/SHA3/SHA3_512.cry
#
# Relevant Cryptol knowledge (for your analysis only — do not quote verbatim and do not include any code in the instruction):
# -----8<-----
# SOURCE: /Users/josh/Automated_Reasoning_for_Cryptography/DataPreprocess/text/Cryptol-Reference-Manual-MD/Modules.md
# # Modules
#
#
# A *module* is used to group related definitions. Each file may contain
# at most one top-level module.
#
# ``` cryptol
# module M where
#
# type T = [8]
#
# f : [8]
# f = 10
# ```
#
# Module names should avoid using two consecutive underscores, because
# those are used to generate names for various anonymous modules.
#
# ## Hierarchical Module Names
#
#
# Modules may have either simple or *hierarchical* names. Hierarchical
# names are constructed by gluing together ordinary identifiers using the
# symbol `::`.
#
# ``` cryptol
# module Hash::SHA256 where
#
# sha256 = ...
# ```
#
# The structure in the name may be used to group together related modules.
# The Cryptol implementation uses the structure of the name to locate the
# file containing the module definition. For example, when searching for
# module `Hash::SHA256`, Cryptol will look for a file named `SHA256.cry`
# in a directory called `Hash`, contained in one of the directories
# specified by `CRYPTOLPATH`.
#
# ## Module Imports
#
#
# To use the definitions from one module in another module, we use
# `import` declarations:
#
# ``` cryptol
# // Provide some definitions
# module M where
#
# f : [8]
# f = 2
# ```
#
# ``` cryptol
# // Uses definitions from `M`
# module N where
#
# import M  // import all definitions from `M`
#
# g = f   // `f` was imported from `M`
# ```
#
# ### Import Lists
#
#
# Sometimes, we may want to import only some of the definitions from a
# module. To do so, we use an import declaration with an *import list*.
#
# ``` cryptol
# module M where
#
# f = 0x02
# g = 0x03
# h = 0x04
# ```
#
# ``` cryptol
# module N where
#
# import M(f,g)  // Imports only `f` and `g`, but not `h`
#
# x = f + g
# ```
#
# Using explicit import lists helps reduce name collisions. It also tends
# to make code easier to understand, because it makes it easy to see the
# source of definitions.
#
# ---
#
# SOURCE: /Users/josh/Automated_Reasoning_for_Cryptography/DataPreprocess/text/Cryptol-Reference-Manual-MD/Basic-Syntax.md
# ## Keywords and Built-in Operators
# The following identifiers have special meanings in Cryptol, and may not
# be used for programmer defined names:
#
# <div id="Keywords">
#
# ``` none
# by              else         include        let            pragma         then
# case            enum         infix          module         primitive      type
# constraint      foreign      infixl         newtype        private        where
# deriving        if           infixr         of             property
# down            import       interface      parameter      submodule
# ```
#
# </div>
#
# The following table contains Cryptol's operators and their associativity
# with lowest precedence operators first, and highest precedence last.
#
# <table style="width:83%;">
# <caption>Operator precedences</caption>
# <colgroup>
# <col style="width: 58%" />
# <col style="width: 25%" />
# </colgroup>
# <thead>
# <tr>
# <th>Operator</th>
# <th>Associativity</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td><blockquote>
# <p><code>==&gt;</code></p>
# </blockquote></td>
# <td>right</td>
# </tr>
# <tr>
# <td><blockquote>
# <p><code>\/</code></p>
# </blockquote></td>
# <td>right</td>
# </tr>
# <tr>
# <td><blockquote>
# <p><code>/\</code></p>
# </blockquote></td>
# <td>right</td>
# </tr>
# <tr>
# <td><blockquote>
# <p><code>==</code> <code>!=</code> <code>===</code> <code>!==</code></p>
# </blockquote></td>
# <td>not associative</td>
# </tr>
# <tr>
# <td><blockquote>
# <p><code>&gt;</code> <code>&lt;</code> <code>&lt;=</code>
# <code>&gt;=</code> <code>&lt;$</code> <code>&gt;$</code>
# <code>&lt;=$</code> <code>&gt;=$</code></p>
# </blockquote></td>
# <td>not associative</td>
# </tr>
# <tr>
# <td><blockquote>
# <p><code>||</code></p>
# </blockquote></td>
# <td>right</td>
# </tr>
# <tr>
# <td><blockquote>
# <p><code>^</code></p>
# </blockquote></td>
# <td>left</td>
# </tr>
# <tr>
# <td><blockquote>
# <p><code>&amp;&amp;</cod
# -----8<-----
#
# Task: Generate exactly ONE AlpacaRow as JSON with keys: instruction, input, output.
#
# Hard rules:
# - The instruction MUST be standalone: the assistant who will write the Cryptol file will NOT see this excerpt.
# - The instruction must request ONLY Cryptol source code (do NOT ask for SAWScript, external proofs, or non-Cryptol artifacts).
# - Do NOT include any Cryptol snippets or fenced code blocks in the instruction.
#   - No triple backticks, no inline backticks, and do not paste lines from the excerpt or RAG context.
#   - You may mention module/function names and describe types/IO in prose, but do not format them as code.
# - Set input to "" (empty string).
# - Set output to "" (empty string).
# - Keep the instruction <= 150 words.
#
# Code excerpt (context for you only; never copy verbatim into the instruction):
# -----8<-----
# module Primitive::Keyless::Hash::SHA3::SHA3_512 =
#        Primitive::Keyless::Hash::SHA3::SHA3
#   where
#
# type digest = 512
#
# -----8<-----
# File path: cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA.cry
#
# Relevant Cryptol knowledge (for your analysis only — do not quote verbatim and do not include any code in the instruction):
# -----8<-----
# SOURCE: /Users/josh/Automated_Reasoning_for_Cryptography/DataPreprocess/text/Cryptol-Reference-Manual-MD/Modules.md
# # Modules
#
#
# A *module* is used to group related definitions. Each file may contain
# at most one top-level module.
#
# ``` cryptol
# module M where
#
# type T = [8]
#
# f : [8]
# f = 10
# ```
#
# Module names should avoid using two consecutive underscores, because
# those are used to generate names for various anonymous modules.
#
# ## Hierarchical Module Names
#
#
# Modules may have either simple or *hierarchical* names. Hierarchical
# names are constructed by gluing together ordinary identifiers using the
# symbol `::`.
#
# ``` cryptol
# module Hash::SHA256 where
#
# sha256 = ...
# ```
#
# The structure in the name may be used to group together related modules.
# The Cryptol implementation uses the structure of the name to locate the
# file containing the module definition. For example, when searching for
# module `Hash::SHA256`, Cryptol will look for a file named `SHA256.cry`
# in a directory called `Hash`, contained in one of the directories
# specified by `CRYPTOLPATH`.
#
# ## Module Imports
#
#
# To use the definitions from one module in another module, we use
# `import` declarations:
#
# ``` cryptol
# // Provide some definitions
# module M where
#
# f : [8]
# f = 2
# ```
#
# ``` cryptol
# // Uses definitions from `M`
# module N where
#
# import M  // import all definitions from `M`
#
# g = f   // `f` was imported from `M`
# ```
#
# ### Import Lists
#
#
# Sometimes, we may want to import only some of the definitions from a
# module. To do so, we use an import declaration with an *import list*.
#
# ``` cryptol
# module M where
#
# f = 0x02
# g = 0x03
# h = 0x04
# ```
#
# ``` cryptol
# module N where
#
# import M(f,g)  // Imports only `f` and `g`, but not `h`
#
# x = f + g
# ```
#
# Using explicit import lists helps reduce name collisions. It also tends
# to make code easier to understand, because it makes it easy to see the
# source of definitions.
#
# ---
#
# SOURCE: /Users/josh/Automated_Reasoning_for_Cryptography/DataPreprocess/text/Cryptol-Reference-Manual-MD/Basic-Syntax.md
# ## Built-in Type-level Operators
# Cryptol includes a variety of operators that allow computations on the
# numeric types used to specify the sizes of sequences.
#
# <table style="width:75%;">
# <caption>Type-level operators</caption>
# <colgroup>
# <col style="width: 18%" />
# <col style="width: 56%" />
# </colgroup>
# <thead>
# <tr>
# <th>Operator</th>
# <th><blockquote>
# <p>Meaning</p>
# </blockquote></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td><blockquote>
# <p><code>+</code></p>
# </blockquote></td>
# <td><blockquote>
# <p>Addition</p>
# </blockquote></td>
# </tr>
# <tr>
# <td><blockquote>
# <p><code>-</code></p>
# </blockquote></td>
# <td><blockquote>
# <p>Subtraction</p>
# </blockquote></td>
# </tr>
# <tr>
# <td><blockquote>
# <p><code>*</code></p>
# </blockquote></td>
# <td><blockquote>
# <p>Multiplication</p>
# </blockquote></td>
# </tr>
# <tr>
# <td><blockquote>
# <p><code>/</code></p>
# </blockquote></td>
# <td><blockquote>
# <p>Division</p>
# </blockquote></td>
# </tr>
# <tr>
# <td><blockquote>
# <p><code>/^</code></p>
# </blockquote></td>
# <td><blockquote>
# <p>Ceiling division (<code>/</code> rounded up)</p>
# </blockquote></td>
# </tr>
# <tr>
# <td><blockquote>
# <p><code>%</code></p>
# </blockquote></td>
# <td><blockquote>
# <p>Modulus</p>
# </blockquote></td>
# </tr>
# <tr>
# <td><blockquote>
# <p><code>%^</code></p>
# </blockquote></td>
# <td><blockquote>
# <p>Ceiling modulus (compute padding)</p>
# </blockquote></td>
# </tr>
# <tr>
# <td><blockquote>
# <p><code>^^</code></p>
# </blockquote></td>
# <td><blockquote>
# <p>Exponentiation</p>
# </blockquote></td>
# </tr>
# <tr>
# <td><blockquote>
# <p><code>lg2</code></p>
# </blockquote></td>
# <td><blockquote>
# <p>Ceiling logarithm (base 2)</p>
# </blockquote></td>
# </tr>
# <tr>
# <td><blockquote>
# <p><code>width</code></p>
# </blockquote></td>
# <td><blockquote>
# <p>Bit width (equal to <code>lg2(n+1)</code>)</p>
# </blockquote></td>
# </tr>
# <tr>
# <td><blockquote>
# <p><code>max</code></p>
# -----8<-----
#
# Task: Generate exactly ONE AlpacaRow as JSON with keys: instruction, input, output.
#
# Hard rules:
# - The instruction MUST be standalone: the assistant who will write the Cryptol file will NOT see this excerpt.
# - The instruction must request ONLY Cryptol source code (do NOT ask for SAWScript, external proofs, or non-Cryptol artifacts).
# - Do NOT include any Cryptol snippets or fenced code blocks in the instruction.
#   - No triple backticks, no inline backticks, and do not paste lines from the excerpt or RAG context.
#   - You may mention module/function names and describe types/IO in prose, but do not format them as code.
# - Set input to "" (empty string).
# - Set output to "" (empty string).
# - Keep the instruction <= 150 words.
#
# Code excerpt (context for you only; never copy verbatim into the instruction):
# -----8<-----
# module Primitive::Keyless::Hash::SHA2Internal::SHA where
#
# import Array
# import Common::ByteArray
#
# sha : {L} (2 * w >= width L) => [L] -> [digest_size]
# sha M = take (join (SHA_2_Common' [ split x | x <- parse`{num_blocks L} (pad`{L} M) ]))
#
# parameter
#
#   /** Word size
#     Specifications are based on word size w, rather than digest size (8 * w)
#     or block size (m == 16 * w), in order to avoid confusing Cryptol's type
#     constraint verifier with integer division.
#   */
#
#   type wp : #
#   type constraint (fin wp, wp >= 2, 32 >= width wp)
#
#   type digest_size : #
#   type constraint (fin digest_size, 8*wp >= digest_size)
#
#   type j : #
#   type constraint (fin j, j >= 17)
#
#   H0 : [8][wp]
#   K  : [j][wp]
#
#   SIGMA_0 : [wp] -> [wp]
#   SIGMA_1 : [wp] -> [wp]
#   sigma_0 : [wp] -> [wp]
#   sigma_1 : [wp] -> [wp]
#
# SHAH0 = H0
# S0 = SIGMA_0
# S1 = SIGMA_1
# s0 = sigma_0
# s1 = sigma_1
# type digestSize = digest_size
#
# type securityStrength = digest_size / 2
#
# Ch : [wp] -> [wp] -> [wp] -> [wp]
# Ch x y z = (x && y) ^ (~x && z)
#
# Maj : [wp] -> [wp] -> [wp] -> [wp]
# Maj x y z = (x && y) ^ (x && z) ^ (y && z)
#
# processBlock_Common : [8][wp] -> [16][wp] -> [8][wp]
# processBlock_Common H Mi = compress_Common H (messageSchedule_Common Mi)
#
# private
#   type w = wp
#
#   type block_size = 16 * w
#
#   type num_blocks L     = (L+1+2*w) /^ block_size
#   type padded_size L    = num_blocks L * block_size
#
#   pad : {L} (2 * w >= width L) => [L] -> [padded_size L]
#   pad M = M # 0b1 # zero # (`L : [2*w])
#
#   parse : {m} [m * block_size] -> [m][block_size]
#   parse = split
#
#   messageSchedule_Common : [16][w] -> [j][w]
#   messageSchedule_Common Mi = take W
#     where
#     W : [inf][_]
#     W = Mi # [ w1 + s0 w2 + w3 + s1 w4
#              | w1 <- W
#              | w2 <- drop`{1} W
#              | w3 <- drop`{9} W
#              | w4 <- drop`{14} W
#              ]
#
#   compress_Common : [8][w] -> [j][w] -> [8][w]
#   compress_Common H W =
#         [ (as ! 0) + (H @ 0),
#       (bs ! 0) + (H @ 1),
#       (cs ! 0) + (H @ 2),
#       (ds ! 0) + (H @ 3),
#       (es ! 0) + (H @ 4),
#       (fs ! 0) + (H @ 5),
#       (gs ! 0) + (H @ 6),
#       (hs ! 0) + (H @ 7)
#     ]
#     where
#       T1 = [h + S1 e + Ch e f g + k_t + w_t
#                 | h <- hs | e <- es | f <- fs | g <- gs | k_t <- K | w_t <- W]
#       T2 = [ S0 a + Maj a b c | a <- as | b <- bs | c <- cs]
#       hs = take`{j + 1}([H @ 7] # gs)
#       gs = take`{j + 1}([H @ 6] # fs)
#       fs = take`{j + 1}([H @ 5] # es)
#       es = take`{j + 1}([H @ 4] # [d + t1 | d <- ds | t1 <- T1])
#       ds = take`{j + 1}([H @ 3] # cs)
#       cs = take`{j + 1}([H @ 2] # bs)
#       bs = take`{j + 1}([H @ 1] # as)
#       as = take`{j + 1}([H @ 0] # [t1 + t2 | t1 <- T1 | t2 <- T2])
#
#   SHA_2_Common' : {L} (fin L) => [L][16][w] -> [8][w]
#   SHA_2_Common' blocks = hash ! 0
#     where
#     hash = [H0] # [ processBlock_Common h b | h <- hash | b <- blocks]
#
# type SHAState = { h : [8][w]
#                 , block : [w * 2][8]
#                 , n : [32]
#                 , sz : [w * 2]
#                 }
#
# SHAInit : SHAState
# SHAInit = { h = H0
#           , block = zero
#           , n = 0
#           , sz = 0
#           }
#
# SHAUpdate : {n} (fin n) => SHAState -> [n][8] -> SHAState
# SHAUpdate sinit bs = ss!0
#   where ss = [sinit] # [ SHAUpdate1 s b | s <- ss | b <- bs ]
#
# SHAFinal : SHAState -> [digest_size]
# SHAFinal s = take (join (processBlock_Common h b'))
#   // Because the message is always made up of bytes, and the size is a
#   // fixed number of bytes, the 1 pad will always be at least a byte.
#   where s' = SHAUpdate1 s 0x80
#                                         (h, b) = if s'.n <= (`w*2 - (`w/4)) then (s'.h, s'.block)
#                  else (processBlock_Common s'.h (split (join s'.block)), zero)
#         b' = split (join b || (zero # s.sz))
#
# SHAImp : {n} (fin n) => [n][8] -> [digest_size]
# SHAImp msg = SHAFinal (SHAUpdate SHAInit msg)
#
# private
#
#           SHAUpdate1 : SHAState -> [8] -> SHAState
#   SHAUpdate1 s b =
#     if s.n == (2 * `w - 1)
#       then { h = processBlock_Common s.h (split (join (update s.block s.n b)))
#            , block = zero
#            , n = 0
#            , sz = s.sz + 8
#            }
#       else { h = s.h
#            , block = update s.block s.n b
#            , n = s.n + 1
#            , sz = s.sz + 8
#            }
#
# type SHAState_Array =
#   { h : [8][w]
#   , block : ByteArray
#   , n : [32]
#   , sz : [w * 2]
#   }
#
# SHAInit_Array : SHAState_Array
# SHAInit_Array =
#   { h = H0
#   , block = arrayConstant 0
#   , n = 0
#   , sz = 0
#   }
#
# SHAUpdate_Array : (w >= 32) => SHAState_Array -> ByteArray -> [64] -> SHAState_Array
# SHAUpdate_Array state data len =
#   if state.n != 0
#     then if len < 2 * `w - n
#       then state'
#       else state''
#     else state'''
#  where
#    n = 0 # state.n
#    state' = { h = state.h, block = block', n = drop n', sz = state.sz + (0 # len) * 8 }
#     where
#       block' = arrayCopy state.block n data 0 len
#       n' = n + len
#    state'' = { h = h'', block = block''', n = drop n''', sz = state.sz + (0 # len) * 8 }
#     where
#       h' = processBlock state.h (arrayCopy state.block n data 0 (2 * `w - n)) 0
#       block' = arrayCopy state.block n data 0 (2 * `w - n)
#       index' = 2 * `w - n
#       len' = len - (2 * `w - n)
#       (h'', index'', len'') = if len' >= 2 * `w
#         then
#           ( (processBlocks h' (arrayCopy (arrayConstant 0) 0 data index' ((len' / (2 * `w)) * (2 * `w))) 0 (len' / (2 * `w)))
#           , index' + len' - (len' % (2 * `w))
#           , len' % (2 * `w)
#           )
#         else (h', index', len')
#       (block''', n''') = if len'' != 0
#         then ((arrayCopy block' 0 data index'' len''), len'')
#         else (block', 0)
#    state''' = { h = h'', block = block''', n = drop n''', sz = state.sz + (0 # len) * 8 }
#     where
#       (h'', index'', len'') = if len >= 2 * `w
#         then
#           ( (processBlocks state.h data 0 (len / (2 * `w)))
#           , len - (len % (2 * `w))
#           , len % (2 * `w)
#           )
#         else (state.h, 0, len)
#       (block''', n''') = if len'' != 0
#         then ((arrayCopy state.block 0 data index'' len''), len'')
#         else (sta
# …(truncated)…
#
# -----8<-----
# File path: cryptol_slices/saw-script/examples/llvm/union/test/009_inc_2.cry
#
# Relevant Cryptol knowledge (for your analysis only — do not quote verbatim and do not include any code in the instruction):
# -----8<-----
# SOURCE: /Users/josh/Automated_Reasoning_for_Cryptography/DataPreprocess/text/Cryptol-Reference-Manual-MD/Expressions.md
# ## Explicit Type Instantiation
#
#
# If `f` is a polymorphic value with type:
#
# ``` cryptol
# f : { tyParam } tyParam
# f = zero
# ```
#
# you can evaluate `f`, passing it a type parameter:
#
# ``` cryptol
# f `{ tyParam = 13 }
# ```
#
# ## Local Declarations
#
#
# Local declarations have the weakest precedence of all expressions.
#
# ``` cryptol
# 2 + x : [T]
#   where
#   type T = 8
#   x      = 2          // `T` and `x` are in scope of `2 + x : `[T]`
#
# if x then 1 else 2
#   where x = 2         // `x` is in scope in the whole `if`
#
# \y -> x + y
#   where x = 2         // `y` is not in scope in the defintion of `x`
# ```
#
# ## Block Arguments
#
#
# When used as the last argument to a function call, `if` and lambda
# expressions do not need parens:
#
# ``` cryptol
# f \x -> x       // call `f` with one argument `x -> x`
# 2 + if x
#       then y
#       else z    // call `+` with two arguments: `2` and `if ...`
# ```
#
# ## Conditionals
#
#
# The `if ... then ... else` construct can be used with multiple branches.
# For example:
#
# ``` cryptol
# x = if y % 2 == 0 then 22 else 33
#
# x = if y % 2 == 0 then 1
#      | y % 3 == 0 then 2
#      | y % 5 == 0 then 3
#      else 7
# ```
#
# ---
#
# SOURCE: /Users/josh/Automated_Reasoning_for_Cryptography/DataPreprocess/text/Cryptol-Reference-Manual-MD/Foreign-Function-Interface.md
# ## Basic usage
# Suppose we want to implement the following function in C:
#
# ``` cryptol
# add : [32] -> [32] -> [32]
# ```
#
# In our Cryptol file, we declare it as a `foreign` function with no body:
#
# ``` cryptol
# foreign add : [32] -> [32] -> [32]
# ```
#
# Note that this uses Cryptol's C calling convention. (For more about the
# specifics of the Cryptol FFI's calling conventions, see the `calling
# conventions section <calling-conventions>`.)
#
# Next, we write the following C function:
#
# ``` c
# uint32_t add(uint32_t x, uint32_t y) {
#   return x + y;
# }
# ```
#
# Cryptol can generate a C header file containing the appropriate function
# prototypes given the corresponding Cryptol `foreign` declarations with
# the `:generate-foreign-header` command. You can then `#include` the
# generated header file in your C file to help write the C implementation.
#
# ```
# Cryptol> :generate-foreign-header Example.cry
# Loading module Example
# Writing header to Example.h
# ```
#
# The C code must first be compiled into a dynamically loaded shared
# library. When Cryptol loads the module containing the `foreign`
# declaration, it will look for a shared library in the same directory as
# the Cryptol module, with the same name as the Cryptol file but with a
# different file extension. The exact extension it uses is
# platform-specific:
#
# - On Linux, it looks for the extension `.so`.
# - On macOS, it looks for the extension `.dylib`.
# - On Windows, it looks for the extension `.dll`.
#
# For example, if you are on Linux and your `foreign` declaration is in
# `Foo.cry`, Cryptol will dynamically load `Foo.so`. Then for each
# `foreign` declaration it will look for a symbol with the same name in
# the shared library. So in this case the function we want to call must be
# bound to the symbol `add` in the shared library.
#
# Once the module is loaded, the foreign `add
# -----8<-----
#
# Task: Generate exactly ONE AlpacaRow as JSON with keys: instruction, input, output.
#
# Hard rules:
# - The instruction MUST be standalone: the assistant who will write the Cryptol file will NOT see this excerpt.
# - The instruction must request ONLY Cryptol source code (do NOT ask for SAWScript, external proofs, or non-Cryptol artifacts).
# - Do NOT include any Cryptol snippets or fenced code blocks in the instruction.
#   - No triple backticks, no inline backticks, and do not paste lines from the excerpt or RAG context.
#   - You may mention module/function names and describe types/IO in prose, but do not format them as code.
# - Set input to "" (empty string).
# - Set output to "" (empty string).
# - Keep the instruction <= 150 words.
#
# Code excerpt (context for you only; never copy verbatim into the instruction):
# -----8<-----
# type Inc_2_st = {x : [32], y : [32]}
#
# inc_2 : Inc_2_st -> Inc_2_st
# inc_2 st = {x = st.x + 1, y = st.y + 1}
#
# -----8<-----
#                                             filename filetype set  \
# 0  cryptol_slices/cryptol/examples/funstuff/FoxCh...  cryptol
# 1  cryptol_slices/aws-lc-verification/cryptol-spe...  cryptol
# 2  cryptol-specs/Primitive/Asymmetric/Signature/E...  cryptol
# 3  cryptol_slices/saw-script/examples/sequential_...  cryptol
# 4                     cryptol-specs/Common/utils.cry  cryptol
#
#                                          instruction input output  \
# 0  Write a Cryptol module that defines the Fox-Ch...
# 1  Write a Cryptol module that defines a finite f...
# 2  Write a Cryptol module that gives a constraine...
# 3  Write a Cryptol module that defines a generic,...
# 4  Write a Cryptol module that defines a collecti...
#
#                                              content
# 0  type OneBank = [4]\ntype BankState = {left : O...
# 1  type q = 8380417\ntype Fld = Z q\ntype nn = 25...
# 2  module Primitive::Asymmetric::Signature::ECDSA...
# 3  type SM i o s = (i, s) -> (o, s)\n\nrun : {n, ...
# 4  module Common::utils where\n\nwhile : {a} (a -...

# %%
import textwrap

WRAP = 80

for idx, row in result.iterrows():
    print(f"=== Example {idx}: {row['filename']} ===")
    instr = str(row["instruction"] or "")
    wrapped_instr = "\n\n".join(
        textwrap.fill(p, width=WRAP, break_long_words=False, break_on_hyphens=False)
        for p in instr.splitlines()
    )
    print(f"Instruction:\n{wrapped_instr}\n")
    print(f"Source Code:\n{'=' * WRAP}\n{row['content']}\n{'=' * WRAP}")
# Out:
# === Example 0: cryptol_slices/cryptol/examples/funstuff/FoxChickenCorn/010_stuffOnlyMovedWithFarmer.cry ===
# Instruction:
# Write a Cryptol module that defines the Fox-Chicken-Corn river crossing state
# and a predicate named stuffOnlyMovedWithFarmer that checks whether a transition
# between two bank states is valid. Represent each bank’s contents as a 4-bit word
# (farmer plus three objects), and define a record type for the overall state with
# left and right banks. The predicate should return true exactly when any objects
# that change banks do so only in combination with the farmer, and at most one
# non-farmer object moves per step. Include any helper predicates you need, such
# as checking where the farmer is, counting moved bits, and constraining moves to
# be legal.
#
# Source Code:
# ================================================================================
# type OneBank = [4]
# type BankState = {left : OneBank, right : OneBank}
#
# farmer = 0x1
#
# stuffOnlyMovedWithFarmer : BankState -> BankState -> Bit
# stuffOnlyMovedWithFarmer b b' =
#   if farmerHere b.left
#   then farmerHere b'.right && moveFollowsRules b.left b'.right
#     (b'.right - b.right)
#   else farmerHere b'.left && moveFollowsRules b.right b'.left
#     (b'.left - b.left)
#
# moveFollowsRules fromBank toBank whatMoved =
#   farmerMoved && atMostOneObjectMoved
#   where
#     farmerMoved = (whatMoved && farmer) == farmer
#     atMostOneObjectMoved = popCount (whatMoved && ~farmer) <= 1
#
# farmerHere : OneBank -> Bit
# farmerHere b = (b && farmer) > 0
#
# popCount : {a} (fin a, a >= 1) => [a] -> [width a]
# popCount bs =
#   ic ! 0
#   where
#     ic =
#       [0] # [if elt then prev + 1 else prev | elt <- bs
#                                             | prev <- ic]
#
# ================================================================================
# === Example 1: cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Common/ntt/010_unit.cry ===
# Instruction:
# Write a Cryptol module that defines a finite field element type modulo the prime
# 8,380,417 and a constant 256 for the vector length. Implement a polymorphic
# function named unit that, for any index n less than 256, returns the length-256
# vector over this field that is the standard basis vector with value 1 at
# position n and 0 elsewhere. Use a list comprehension style definition over the
# index range and ensure the function’s type and constraints enforce that the
# index is strictly less than 256. Do not include any tests or proofs, just the
# core type aliases and the unit function definition.
#
# Source Code:
# ================================================================================
# type q = 8380417
# type Fld = Z q
# type nn = 256
#
# unit : {n} (n < nn) => [nn]Fld
# unit = [if `n == i then 1 else 0 | i <- [0 .. < nn]]
#
# ================================================================================
# === Example 2: cryptol-specs/Primitive/Asymmetric/Signature/ECDSA/Specification.cry ===
# Instruction:
# Write a Cryptol module that gives a constrained ECDSA specification over an
# abstract elliptic-curve interface and a hash interface. The module should import
# a separate unconstrained ECDSA specification and then re-export its sign,
# verify, and public key derivation operations. Add interface constraints tying
# the elliptic-curve group order size to a minimum of 224 bits, define a security
# strength value as half the curve order bit-width, and require that the hash
# interface’s security strength is at least this value. Use only type-level and
# interface constraints for these requirements; do not hard-code a particular
# curve or hash function.
#
# Source Code:
# ================================================================================
# module Primitive::Asymmetric::Signature::ECDSA::Specification where
#
# import interface Common::EC::ECInterface as EC
#
# import interface Primitive::Keyless::Hash::HashInterface as Hash
#
# import Primitive::Asymmetric::Signature::ECDSA::UnconstrainedSpec
#     { EC = interface EC , Hash = interface Hash } as USpec
#
# interface constraint (width EC::n >= 224)
#
# type ECSecurityStrength = (width EC::n / 2)
#
# interface constraint (ECSecurityStrength <= Hash::SecurityStrength)
#
# sign = USpec::sign
# verify = USpec::verify
# publicKey = USpec::publicKey
#
# ================================================================================
# === Example 3: cryptol_slices/saw-script/examples/sequential_aigs/StateMachine/004_equiv.cry ===
# Instruction:
# Write a Cryptol module that defines a generic, clocked state machine interface
# SM as a function from an input and current state to an output and next state,
# and then defines functions run, eval, and equiv over this interface. The run
# function should iterate a given state machine over a sequence of inputs,
# starting from a zero-initialized state and returning the sequence of
# output/state pairs. The eval function should project just the outputs from run.
# The equiv function should take two state machines and an input sequence and
# return a Boolean indicating whether the output traces of the two machines are
# equal element-wise for all time steps. Use suitable type polymorphism and
# typeclass constraints for zero-initialized states and comparable outputs.
#
# Source Code:
# ================================================================================
# type SM i o s = (i, s) -> (o, s)
#
# run : {n, i, s, o} (Zero s) => SM i o s -> [n]i -> [n](o, s)
# run sm is =
#   oss
#   where
#     states = [zero] # [os.1 | os <- oss]
#     oss = [sm (i, s) | i <- is | s <- states]
#
# eval : {n, i, s, o} (Zero s) => SM i o s -> [n]i -> [n](o)
# eval sm is = [os.0 | os <- run sm is]
#
# equiv : {n, i, s1, s2, o}
#   (Cmp o, fin n, Zero s1, Zero s2) =>
#     SM i o s1 -> SM i o s2 -> [n]i -> Bool
# equiv sm1 sm2 is =
#   all [o1 == o2 | o1 <- eval sm1 is | o2 <- eval sm2 is]
#   where
#     all : {m} (fin m) => [m]Bool -> Bool
#     all xs =
#       its ! 0
#       where
#         its = [True] # [x && it | x <- xs | it <- its]
#
# ================================================================================
# === Example 4: cryptol-specs/Common/utils.cry ===
# Instruction:
# Write a Cryptol module that defines a collection of general-purpose utilities
# similar to those in a small helper library. Include: higher-order iteration
# combinators for while and do-while style loops over an arbitrary state type;
# conversion helpers between modular integers, bitvectors, and unbounded integers
# with appropriate finiteness and positivity constraints; predicates and utilities
# such as isEven, absolute value on integers, and an integer modulus lower-bounded
# by 3 derived from a bitvector; simple linear-time tuple unzip for a sequence of
# pairs; small multiplication-by-constant helpers using repeated addition; a
# type-level constraint expressing that a modulus is odd; a half function on
# modular integers under that odd-modulus constraint; a property asserting that
# doubling half returns the original value; and function composition utilities
# including composition of an array of endofunctions.
#
# Source Code:
# ================================================================================
# module Common::utils where
#
# while : {a} (a -> Bit) -> (a -> a) -> a -> a
# while condition body initial_state =
#   if(condition initial_state) then while condition body (body initial_state)
#   else initial_state
#
# dowhile : {a} (a -> Bit) -> (a -> a) -> a -> a
# dowhile condition body initial_state =
#   if(condition next_state) then while condition body next_state else next_state
#   where next_state = body initial_state
#
# ZtoBV : {p, a} (fin p, p >= 1, fin a) => Z p -> [a]
# ZtoBV x = (fromInteger (fromZ x))
#
# BVtoZ : {p, a} (fin p, p >= 1, fin a) => [a] -> Z p
# BVtoZ x = (fromInteger (toInteger x))
#
# ZtoZ : {p, q} (fin p, fin q, p >= 1, q >= 1) => Z p -> Z q
# ZtoZ x = (fromInteger (fromZ x))
#
# integerToBV : {m} (fin m) => Integer -> [m]
# integerToBV x = fromInteger x
#
# integerFromBV : {m} (fin m) => [m] -> Integer
# integerFromBV x = toInteger x
#
# integerModulusFromBV : {m} (fin m) => [m] -> Integer
# integerModulusFromBV x = if (integerFromBV x) < 3 then 3 else (integerFromBV x)
#
# isEven : Integer -> Bit
# isEven x = ~((fromInteger x) : [1]) ! 0
#
# abs : Integer -> Integer
# abs x = if x >= zero then x else zero-x
#
# unzip : {a,f,s} [a](f,s) -> ([a]f,[a]s)
# unzip tuples = (map (\x -> x.0) tuples , map (\x -> x.1) tuples)
#
# mul2 x = x + x
#
# mul3 x = x + mul2 x
#
# mul4 x = mul2(mul2 x)
#
# mul8 x = mul2(mul4 x)
#
# type constraint isOdd a = (a / 2) * 2 == a - 1
#
# half : {p} (fin p, p >= 3, isOdd p) => Z p -> Z p
# half x = fromInteger (if isEven xint then xint/2 else ((xint + `p) / 2))
#   where
#     xint = fromZ x
#
# half_correct : {p} (fin p, p >= 3, isOdd p) => Z p -> Bit
# property half_correct x = half x + half x == x
#
# compose : {a} () => (a -> a) -> (a -> a) -> a -> a
# compose f g = \x -> g (f x)
#
# composeMany : {nf, a} () => [nf](a -> a) -> a -> a
# composeMany fcns
#     | nf == 0 => \x -> x
#     | nf == 1 => fcns@0
#     | nf == 2 => compose (fcns@0) (fcns@1)
#     | nf > 2  => compose (fcns@0) (composeMany (drop `{1} fcns))
#
# ================================================================================
# === Example 5: cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AESKeyWrap/003_aesUnwrapKey.cry ===
# Instruction:
# Write a Cryptol module that implements the AES Key Wrap key-unwrapping operation
# as specified in NIST SP 800-38F. Define a top-level function aesUnwrapKey that
# takes an AES key, an 8-byte IV, and an n-byte wrapped key (with n ≥ 24, a
# multiple of 8, and n/8 representable in at most 64 bits). It must return a pair
# of a status bit indicating IV/authentication success and the unwrapped (n −
# 8)-byte key (or all zeros if the IV check fails). Internally, factor the
# algorithm into helpers analogous to an unchecked unwrap, a per-round unwrap, and
# a per-block unwrap, parameterized over the number of 64-bit blocks, using AES
# decryption for each block transform.
#
# Source Code:
# ================================================================================
# import Primitive::Symmetric::Cipher::Block::AES
#
#
#
#
#
# aesUnwrapKey : {n}
#   (fin n, n >= 24, n % 8 == 0, width (n / 8) <= 64) =>
#     [AESKeySize] -> [8][8] -> [n][8] -> (Bit, [n - 8][8])
# aesUnwrapKey key iv ciphertext =
#   if (join iv) == A' then (True, split (join R')) else (False, zero)
#   where
#     (A', R') = aesUnwrapKeyUnchecked key ciphertext
# aesUnwrapKeyUnchecked : {n}
#   (fin n, n >= 24, n % 8 == 0, width (n / 8) <= 64) =>
#     [AESKeySize] -> [n][8] -> ([64], [n / 8 - 1][64])
# aesUnwrapKeyUnchecked key ciphertext =
#   intermediates ! 0
#   where
#     A = join (take`{8} ciphertext)
#     R =
#       split`{parts = (n - 8) / 8, each = 64}
#         (join (drop`{8} ciphertext))
#     intermediates =
#       [(A, R)] # [unwrapRound key s j | s <- intermediates
#                                       | j <- [5, 4 .. 0]]
# unwrapRound : {n}
#   (fin n, n >= 1, width n <= 64) =>
#     [AESKeySize] -> ([64], [n][64]) -> [64] -> ([64], [n][64])
# unwrapRound key (A, R) j =
#   unwrappedBlocks ! 0
#   where
#     unwrappedBlocks =
#       [(A, R)] # [unwrapBlock key s j i | s <- unwrappedBlocks
#                                         | i <- [n, n - 1 .. 1]]
# unwrapBlock : {n}
#   (fin n, width n <= 64) =>
#     [AESKeySize] -> ([64], [n][64]) -> [64] -> [64] -> ([64], [n][64])
# unwrapBlock key (A, R) j i =
#   (A', R')
#   where
#     B =
#       aesDecrypt ((A ^ (((`n : [64]) * j) + i)) # (R @ (i - 1)), key)
#     A' = take`{64} B
#     R' = update R (i - 1) (drop`{64} B)
#
# ================================================================================
# === Example 6: cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Common/ntt/016_butterfly.cry ===
# Instruction:
# Write a Cryptol module that defines a radix-2 NTT butterfly over the finite
# field Z_q, where q is the prime 8380417. Use a field element r = 1753 to
# generate an infinite stream of roots of unity via repeated squaring (multiplying
# by r squared each step, starting from 1). Then define a polymorphic butterfly
# function parameterized by n, with constraints that n is finite and greater than
# 0, taking an Integer depth argument and two length-n vectors of field elements
# (even and odd), and returning a length-2n vector. The first n outputs are
# even[i] plus root[i * (2^depth)] times odd[i], and the second n outputs are
# even[i] minus the same product. Use list comprehensions and indexing over 0 to
# n-1.
#
# Source Code:
# ================================================================================
# type q = 8380417
# type Fld = Z q
#
# r : Fld
# r = 1753
#
# roots : [inf]Fld
# roots = iterate ((*) (r * r)) 1
#
# butterfly : {n}
#   (fin n, n > 0) =>
#     Integer -> [n]Fld -> [n]Fld -> [2 * n]Fld
# butterfly depth even odd =
#   lft # rht
#   where
#     j = 2 ^^ depth
#     lft = [even @ i + roots @ (i * j) * odd @ i | i <- [0 .. < n]]
#     rht = [even @ i - roots @ (i * j) * odd @ i | i <- [0 .. < n]]
#
# ================================================================================
# === Example 7: aws-lc-verification/cryptol-specs-aes-gcm/Primitive/Keyless/Hash/SHA3/SHA3_512.cry ===
# Instruction:
# Write a Cryptol module implementing the SHA3-512 hash specification as a
# specialization of a generic SHA3 construction. The module should use a
# hierarchical module name corresponding to SHA3_512 and set an appropriate type
# alias for the digest size of 512 bits. Ensure that the design cleanly reuses or
# instantiates the generic SHA3 permutation/sponge parameters for this output
# size, including any rate/capacity settings needed for SHA3-512. Expose a
# top-level function that takes a finite sequence of bytes as input and returns a
# 512-bit digest value. Include any necessary type synonyms or constraints so the
# interface is clear and type-safe, and keep the code self-contained within this
# module.
#
# Source Code:
# ================================================================================
# module Primitive::Keyless::Hash::SHA3::SHA3_512 =
#        Primitive::Keyless::Hash::SHA3::SHA3
#   where
#
# type digest = 512
#
# ================================================================================
# === Example 8: cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA.cry ===
# Instruction:
# Write a Cryptol module that provides a fully parameterized SHA-2 compression and
# incremental hashing core, structurally equivalent to the SHA2Internal SHA
# specification. The module should:
#
#
#
# - Be parameterized by a word size w, digest size, round count j, initial hash
# vector, and round constants.
#
# - Define the SHAState record (with chaining value, partial block buffer, byte
# counter, and total bit length) and corresponding array-based state variant using
# a generic byte-array type.
#
# - Implement padding, message parsing into 16-word blocks, message schedule
# expansion, compression over j rounds, and multi-block iteration.
#
# - Provide both a one-shot interface from a sequence of bytes to a digest and an
# incremental interface with init, update, and final operations for both sequence
# and array-based states.
#
#
#
# Focus only on Cryptol code; no proofs or SAWScript.
#
# Source Code:
# ================================================================================
# module Primitive::Keyless::Hash::SHA2Internal::SHA where
#
# import Array
# import Common::ByteArray
#
# sha : {L} (2 * w >= width L) => [L] -> [digest_size]
# sha M = take (join (SHA_2_Common' [ split x | x <- parse`{num_blocks L} (pad`{L} M) ]))
#
# parameter
#
#   /** Word size
#     Specifications are based on word size w, rather than digest size (8 * w)
#     or block size (m == 16 * w), in order to avoid confusing Cryptol's type
#     constraint verifier with integer division.
#   */
#
#   type wp : #
#   type constraint (fin wp, wp >= 2, 32 >= width wp)
#
#   type digest_size : #
#   type constraint (fin digest_size, 8*wp >= digest_size)
#
#   type j : #
#   type constraint (fin j, j >= 17)
#
#   H0 : [8][wp]
#   K  : [j][wp]
#
#   SIGMA_0 : [wp] -> [wp]
#   SIGMA_1 : [wp] -> [wp]
#   sigma_0 : [wp] -> [wp]
#   sigma_1 : [wp] -> [wp]
#
# SHAH0 = H0
# S0 = SIGMA_0
# S1 = SIGMA_1
# s0 = sigma_0
# s1 = sigma_1
# type digestSize = digest_size
#
# type securityStrength = digest_size / 2
#
# Ch : [wp] -> [wp] -> [wp] -> [wp]
# Ch x y z = (x && y) ^ (~x && z)
#
# Maj : [wp] -> [wp] -> [wp] -> [wp]
# Maj x y z = (x && y) ^ (x && z) ^ (y && z)
#
# processBlock_Common : [8][wp] -> [16][wp] -> [8][wp]
# processBlock_Common H Mi = compress_Common H (messageSchedule_Common Mi)
#
# private
#   type w = wp
#
#   type block_size = 16 * w
#
#   type num_blocks L     = (L+1+2*w) /^ block_size
#   type padded_size L    = num_blocks L * block_size
#
#   pad : {L} (2 * w >= width L) => [L] -> [padded_size L]
#   pad M = M # 0b1 # zero # (`L : [2*w])
#
#   parse : {m} [m * block_size] -> [m][block_size]
#   parse = split
#
#   messageSchedule_Common : [16][w] -> [j][w]
#   messageSchedule_Common Mi = take W
#     where
#     W : [inf][_]
#     W = Mi # [ w1 + s0 w2 + w3 + s1 w4
#              | w1 <- W
#              | w2 <- drop`{1} W
#              | w3 <- drop`{9} W
#              | w4 <- drop`{14} W
#              ]
#
#   compress_Common : [8][w] -> [j][w] -> [8][w]
#   compress_Common H W =
#         [ (as ! 0) + (H @ 0),
#       (bs ! 0) + (H @ 1),
#       (cs ! 0) + (H @ 2),
#       (ds ! 0) + (H @ 3),
#       (es ! 0) + (H @ 4),
#       (fs ! 0) + (H @ 5),
#       (gs ! 0) + (H @ 6),
#       (hs ! 0) + (H @ 7)
#     ]
#     where
#       T1 = [h + S1 e + Ch e f g + k_t + w_t
#                 | h <- hs | e <- es | f <- fs | g <- gs | k_t <- K | w_t <- W]
#       T2 = [ S0 a + Maj a b c | a <- as | b <- bs | c <- cs]
#       hs = take`{j + 1}([H @ 7] # gs)
#       gs = take`{j + 1}([H @ 6] # fs)
#       fs = take`{j + 1}([H @ 5] # es)
#       es = take`{j + 1}([H @ 4] # [d + t1 | d <- ds | t1 <- T1])
#       ds = take`{j + 1}([H @ 3] # cs)
#       cs = take`{j + 1}([H @ 2] # bs)
#       bs = take`{j + 1}([H @ 1] # as)
#       as = take`{j + 1}([H @ 0] # [t1 + t2 | t1 <- T1 | t2 <- T2])
#
#   SHA_2_Common' : {L} (fin L) => [L][16][w] -> [8][w]
#   SHA_2_Common' blocks = hash ! 0
#     where
#     hash = [H0] # [ processBlock_Common h b | h <- hash | b <- blocks]
#
# type SHAState = { h : [8][w]
#                 , block : [w * 2][8]
#                 , n : [32]
#                 , sz : [w * 2]
#                 }
#
# SHAInit : SHAState
# SHAInit = { h = H0
#           , block = zero
#           , n = 0
#           , sz = 0
#           }
#
# SHAUpdate : {n} (fin n) => SHAState -> [n][8] -> SHAState
# SHAUpdate sinit bs = ss!0
#   where ss = [sinit] # [ SHAUpdate1 s b | s <- ss | b <- bs ]
#
# SHAFinal : SHAState -> [digest_size]
# SHAFinal s = take (join (processBlock_Common h b'))
#   // Because the message is always made up of bytes, and the size is a
#   // fixed number of bytes, the 1 pad will always be at least a byte.
#   where s' = SHAUpdate1 s 0x80
#                                         (h, b) = if s'.n <= (`w*2 - (`w/4)) then (s'.h, s'.block)
#                  else (processBlock_Common s'.h (split (join s'.block)), zero)
#         b' = split (join b || (zero # s.sz))
#
# SHAImp : {n} (fin n) => [n][8] -> [digest_size]
# SHAImp msg = SHAFinal (SHAUpdate SHAInit msg)
#
# private
#
#           SHAUpdate1 : SHAState -> [8] -> SHAState
#   SHAUpdate1 s b =
#     if s.n == (2 * `w - 1)
#       then { h = processBlock_Common s.h (split (join (update s.block s.n b)))
#            , block = zero
#            , n = 0
#            , sz = s.sz + 8
#            }
#       else { h = s.h
#            , block = update s.block s.n b
#            , n = s.n + 1
#            , sz = s.sz + 8
#            }
#
# type SHAState_Array =
#   { h : [8][w]
#   , block : ByteArray
#   , n : [32]
#   , sz : [w * 2]
#   }
#
# SHAInit_Array : SHAState_Array
# SHAInit_Array =
#   { h = H0
#   , block = arrayConstant 0
#   , n = 0
#   , sz = 0
#   }
#
# SHAUpdate_Array : (w >= 32) => SHAState_Array -> ByteArray -> [64] -> SHAState_Array
# SHAUpdate_Array state data len =
#   if state.n != 0
#     then if len < 2 * `w - n
#       then state'
#       else state''
#     else state'''
#  where
#    n = 0 # state.n
#    state' = { h = state.h, block = block', n = drop n', sz = state.sz + (0 # len) * 8 }
#     where
#       block' = arrayCopy state.block n data 0 len
#       n' = n + len
#    state'' = { h = h'', block = block''', n = drop n''', sz = state.sz + (0 # len) * 8 }
#     where
#       h' = processBlock state.h (arrayCopy state.block n data 0 (2 * `w - n)) 0
#       block' = arrayCopy state.block n data 0 (2 * `w - n)
#       index' = 2 * `w - n
#       len' = len - (2 * `w - n)
#       (h'', index'', len'') = if len' >= 2 * `w
#         then
#           ( (processBlocks h' (arrayCopy (arrayConstant 0) 0 data index' ((len' / (2 * `w)) * (2 * `w))) 0 (len' / (2 * `w)))
#           , index' + len' - (len' % (2 * `w))
#           , len' % (2 * `w)
#           )
#         else (h', index', len')
#       (block''', n''') = if len'' != 0
#         then ((arrayCopy block' 0 data index'' len''), len'')
#         else (block', 0)
#    state''' = { h = h'', block = block''', n = drop n''', sz = state.sz + (0 # len) * 8 }
#     where
#       (h'', index'', len'') = if len >= 2 * `w
#         then
#           ( (processBlocks state.h data 0 (len / (2 * `w)))
#           , len - (len % (2 * `w))
#           , len % (2 * `w)
#           )
#         else (state.h, 0, len)
#       (block''', n''') = if len'' != 0
#         then ((arrayCopy state.block 0 data index'' len''), len'')
#         else (state.block, n)
#
# SHAFinal_Array : (w >= 32) => SHAState_Array -> [digest_size]
# SHAFinal_Array state = take (join h''')
#   where
#     n = 0 # state.n
#     block' = arrayUpdate state.block n 0x80
#     n' = n + 1
#     (h'', block'', n'') = if n' > 2 * `w - `w / 4
#       then ((processBlock state.h (arraySet block' n' 0 (2 * `w - n')) 0), (arraySet block' n' 0 (2 * `w - n')), 0)
#       else (state.h, block', n')
#     h''' = processBlock
#       h''
#       (arrayRangeUpdate
#         (arraySet block'' n'' 0 (2 * `w - `w / 4 - n''))
#         (2 * `w - `w / 4)
#         (split`{parts=(w+3)/4} (0 # state.sz)))
#       0
#
# // Imperative SHA implementation
# SHAImp_Array : (w >= 32) => ByteArray -> [64] -> [digest_size]
# SHAImp_Array msg len = SHAFinal_Array (SHAUpdate_Array SHAInit_Array msg len)
#
# processBlocks : [8][w] -> ByteArray -> [64] -> [64] -> [8][w]
# processBlocks [a, b, c, d, e, f, g, h] data index n = processBlock [a', b', c', d', e', f', g', h'] data index'
#   where
#     (a', b', c', d', e', f', g', h', index') = processBlocksLoop n data a b c d e f g h index
#
# processBlock : [8][w] -> ByteArray -> [64] -> [8][w]
# processBlock h block index =
#   processBlock_Common h (split (join (arrayRangeLookup block index)))
#
# processBlocksLoop : [64] -> ByteArray -> [w] -> [w] -> [w] -> [w] -> [w] -> [w] -> [w] -> [w] -> [64] -> ([w], [w], [w], [w], [w], [w], [w], [w], [64])
# processBlocksLoop num data a b c d e f g h index = if (index + 2 * `w) < (num * 2 * `w)
#   then processBlocksLoop num data a' b' c' d' e' f' g' h' (index + 2 * `w)
#   else (a, b, c, d, e, f, g, h, index)
#   where
#     [a', b', c', d', e', f', g', h'] = (processBlock [a, b, c, d, e, f, g, h] data index)
#
# arrayRangeEqual_arrayRangeLookup_lemma : {n} (fin n, n >= 1, n <= 1000) => ByteArray -> ByteArray -> Bit
# arrayRangeEqual_arrayRangeLookup_lemma a b = arrayRangeEqual a 0 b 0 `n == (arrayRangeLookup`{n=n} a 0 == arrayRangeLookup b 0)
#
# ================================================================================
# === Example 9: cryptol_slices/saw-script/examples/llvm/union/test/009_inc_2.cry ===
# Instruction:
# Write a Cryptol module that defines a 32-bit state record type named Inc_2_st
# with two 32-bit fields x and y, and a function inc_2 that takes such a state and
# returns a new state where both x and y are incremented by 1 modulo 2^32. Use
# clear type synonyms or record type declarations as appropriate so the structure
# of the state is explicit, and ensure the function operates purely on this record
# without any additional parameters or side effects.
#
# Source Code:
# ================================================================================
# type Inc_2_st = {x : [32], y : [32]}
#
# inc_2 : Inc_2_st -> Inc_2_st
# inc_2 st = {x = st.x + 1, y = st.y + 1}
#
# ================================================================================
