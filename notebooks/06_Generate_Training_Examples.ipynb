# %%
from pathlib import Path 
import os, dotenv, yaml

with open("config.yaml", "r") as f:
    config = yaml.safe_load(f)

dotenv.load_dotenv()
os.chdir(Path(config["pythonpath"]).expanduser())

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from dotenv import load_dotenv

# %%
VARIATION = "nocomments"
VERSION = config["version"]

source_code_df = pd.read_json(f"data/clean_datasets/{VARIATION}_{VERSION}.jsonl", lines=True)
source_code_df['filetype'] = source_code_df['filetype'].apply(
    lambda x: 'cryptol' if x == 'cry' else 'saw' if x == 'saw' else 'text'
    )

source_code_df.head()
# Out:
#                                             filename filetype  \
# 0      AES-GCM-SIV-proof/proof/cryptol-specs/AES.cry  cryptol
# 1   AES-GCM-SIV-proof/proof/cryptol-specs/AES128.cry  cryptol
# 2   AES-GCM-SIV-proof/proof/cryptol-specs/AES256.cry  cryptol
# 3     AES-GCM-SIV-proof/proof/cryptol-specs/TBox.cry  cryptol
# 4  AES-GCM-SIV-proof/proof/cryptol-specs/Common/A...  cryptol
#
#                                              content           variant  \
# 0  module AES where\n\nimport `Common::AES\n\ntyp...  without_comments
# 1  module AES128 where\n\nimport `Common::AES\nim...  without_comments
# 2  module AES256 where\n\nimport `Common::AES\nim...  without_comments
# 3  type Nb         = 4\ntype State      = [4][Nb]...  without_comments
# 4  module Common::AES where\n\nparameter\n  type ...  without_comments
#
#    n_imports_original  n_imports_final
# 0                 NaN              NaN
# 1                 NaN              NaN
# 2                 NaN              NaN
# 3                 NaN              NaN
# 4                 NaN              NaN

# %%
from src.agent.generate import ModelConfig, iter_call_pydantic_ai, build_prompt_call_pydantic_ai

file_cache_path = Path(f"cache/alpaca_instruct_cache/SFT_{VARIATION}_source_code_{VERSION}.jsonl")
file_cache_path.parent.mkdir(parents=True, exist_ok=True)  # create dirs if missing

test_df = source_code_df.sample(1, random_state=42).reset_index(drop=True)

modelConfig = ModelConfig(
    model="openai:gpt-5.1",
    retries=2
)

result = iter_call_pydantic_ai(
    test_df, 
    model_cfg=modelConfig,
    input_mode="none",
    file_cache_path=file_cache_path
)
result.head()
# Out:
# ---------------------------------------------------------------------------
# TemplateNotFound                          Traceback (most recent call last)
# Cell In[6], line 13
#       6 test_df = source_code_df.sample(1, random_state=42).reset_index(drop=True)
#       8 modelConfig = ModelConfig(
#       9     model="openai:gpt-5.1",
#      10     retries=2
#      11 )
# ---> 13 result = iter_call_pydantic_ai(
#      14     test_df,
#      15     model_cfg=modelConfig,
#      16     input_mode="none",
#      17     file_cache_path=file_cache_path
#      18 )
#      19 result.head()
#
# File ~/Automated_Reasoning_for_Cryptography/DataPreprocess/src/agent/generate.py:331, in iter_call_pydantic_ai(input_df, input_mode, file_cache_path, model_cfg, prompt_cfg, rag_cfg)
#     328 prompt_cfg = prompt_cfg or PromptConfig()
#     329 rag_cfg = rag_cfg or RAGConfig()
# --> 331 agents = build_agents(model_cfg, prompt_cfg)
#     333 fileKVCache = FileKVCache(file_cache_path)
#     334 returned_rows: List[Dict[str, Any]] = []
#
# File ~/Automated_Reasoning_for_Cryptography/DataPreprocess/src/agent/generate.py:218, in build_agents(model_cfg, prompt_cfg)
#     211 """
#     212 Create agents for:
#     213   - AlpacaRow instruction generation
#     214   - QAPairList generation (scraped web page)
#     215 """
#     216 renderer = PromptRenderer(prompt_cfg.template_dir)
# --> 218 system_spec = renderer.render("system_spec_instruction.j2").strip()
#     219 system_qa = renderer.render("system_qa.j2").strip()
#     221 model_name = _normalize_model(model_cfg.model)
#
# File ~/Automated_Reasoning_for_Cryptography/DataPreprocess/src/agent/generate.py:126, in PromptRenderer.render(self, name, **ctx)
#     125 def render(self, name: str, **ctx: Any) -> str:
# --> 126     return self.env.get_template(name).render(**ctx)
#
# File /opt/anaconda3/envs/Automated_Reasoning_for_Cryptography/lib/python3.12/site-packages/jinja2/environment.py:1016, in Environment.get_template(self, name, parent, globals)
#    1013 if parent is not None:
#    1014     name = self.join_path(name, parent)
# -> 1016 return self._load_template(name, globals)
#
# File /opt/anaconda3/envs/Automated_Reasoning_for_Cryptography/lib/python3.12/site-packages/jinja2/environment.py:975, in Environment._load_template(self, name, globals)
#     971             template.globals.update(globals)
#     973         return template
# --> 975 template = self.loader.load(self, name, self.make_globals(globals))
#     977 if self.cache is not None:
#     978     self.cache[cache_key] = template
#
# File /opt/anaconda3/envs/Automated_Reasoning_for_Cryptography/lib/python3.12/site-packages/jinja2/loaders.py:126, in BaseLoader.load(self, environment, name, globals)
#     122     globals = {}
#     124 # first we try to get the source for this template together
#     125 # with the filename and the uptodate function.
# --> 126 source, filename, uptodate = self.get_source(environment, name)
#     128 # try to load the code from the bytecode cache if there is a
#     129 # bytecode cache configured.
#     130 bcc = environment.bytecode_cache
#
# File /opt/anaconda3/envs/Automated_Reasoning_for_Cryptography/lib/python3.12/site-packages/jinja2/loaders.py:209, in FileSystemLoader.get_source(self, environment, template)
#     207     plural = "path" if len(self.searchpath) == 1 else "paths"
#     208     paths_str = ", ".join(repr(p) for p in self.searchpath)
# --> 209     raise TemplateNotFound(
#     210         template,
#     211         f"{template!r} not found in search {plural}: {paths_str}",
#     212     )
#     214 with open(filename, encoding=self.encoding) as f:
#     215     contents = f.read()
#
# TemplateNotFound: 'system_spec_instruction.j2' not found in search path: '/Users/josh/Automated_Reasoning_for_Cryptography/DataPreprocess/src/agent/prompts'
