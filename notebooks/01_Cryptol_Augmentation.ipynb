# %% [markdown]
# # Cryptol slicer notebook
#
# This notebook calls the Haskell `toy-cryptol-ast` executable to slice Cryptol modules
# into per-definition files. It assumes:
#
# 1. You have the `toy-cryptol-ast` repo checked out.
# 2. You can run `cabal build` or `cabal run toy-cryptol-ast` successfully from that repo.
# 3. You have a local checkout of `cryptol-specs` (or any directory tree of `.cry` files).

# %%
from pathlib import Path 
import os, dotenv, yaml

with open("config.yaml", "r") as f:
    config = yaml.safe_load(f)

dotenv.load_dotenv()
os.chdir(Path(config["pythonpath"]).expanduser())

# %%
import subprocess
import pandas as pd

# --- CONFIG: EDIT THESE FOR YOUR MACHINE ---
VERSION = config["version"]
# Root of your repo/workspace that contains both the Cryptol specs and the file list
REPO_ROOT_DIR = Path(config["repo_root"]).expanduser()  # <-- adjust if needed

# Path to the file listing all .cry files (e.g., 0_long_files.txt)
all_sources_raw_df = pd.read_json(f"data/clean_datasets/nocomments_{VERSION}.jsonl", lines=True)
FILE_LIST = all_sources_raw_df["filename"].tolist()

# Root directory where all slice directories will be created
OUTPUT_ROOT = REPO_ROOT_DIR / "cryptol_slices"

# Directory containing the cabal project for toy-cryptol-ast
CABAL_PROJECT_ROOT = "toy-cryptol-ast"  # directory with toy-cryptol-ast.cabal

# %%
def run_haskell_slicer(cry_path: Path, out_dir: Path):
    """
    Call: cabal run toy-cryptol-ast -- <file> <OUTDIR>
    from within CABAL_PROJECT_ROOT.
    """
    out_dir.mkdir(parents=True, exist_ok=True)

    cmd = [
        "cabal",
        "run",
        "toy-cryptol-ast",
        "--",
        str(cry_path),
        str(out_dir),
    ]

    print("Running:", " ".join(cmd))
    result = subprocess.run(
        cmd,
        cwd=str(CABAL_PROJECT_ROOT),  # run inside the cabal project
        capture_output=True,
        text=True,
    )

    if result.returncode != 0:
        print(f"❌ Error ({result.returncode}) on {cry_path}")
        if result.stdout.strip():
            print("STDOUT:\n", result.stdout)
        if result.stderr.strip():
            print("STDERR:\n", result.stderr)
    else:
        print(f"✅ OK: {cry_path}")
        if result.stdout.strip():
            print("STDOUT:\n", result.stdout)

# %%
def iter_file_list(file_list: Path):
    """
    Yield each non-empty, non-comment line from FILE_LIST.
    Lines should be repo-relative paths like:
      cryptol-specs/Primitive/Symmetric/Cipher/Block/KATAN.cry
    """
    with file_list.open() as f:
        for raw in f:
            line = raw.strip()
            if not line:
                continue
            if line.startswith("#"):
                continue
            yield line


def cry_rel_to_paths(rel: str):
    """
    Given a relative .cry path from FILE_LIST, return:
      (absolute_input_path, absolute_output_dir_path)
    Output dir is:
      OUTPUT_ROOT / relative_path_without_.cry_suffix
    """
    cry_rel = Path(rel)
    cry_abs = REPO_ROOT_DIR / cry_rel

    # Example:
    #   rel: cryptol-specs/Primitive/Symmetric/Cipher/Block/KATAN.cry
    #   out: OUTPUT_ROOT/cryptol-specs/Primitive/Symmetric/Cipher/Block/KATAN/
    out_dir = OUTPUT_ROOT / cry_rel.with_suffix("")

    return cry_abs, out_dir


print(f"Reading list from: {FILE_LIST}")
print(f"Output root:       {OUTPUT_ROOT}")
OUTPUT_ROOT.mkdir(parents=True, exist_ok=True)

for rel in FILE_LIST:
    cry_path, out_dir = cry_rel_to_paths(rel)

    if not cry_path.is_file():
        print(f"⚠️  Skipping {cry_path} (file not found)")
        continue

    print("\n=== Slicing:", cry_path, "===")
    print("  → output dir:", out_dir)
    run_haskell_slicer(cry_path, out_dir)
# Out:
# Reading list from: ['AES-GCM-SIV-proof/proof/cryptol-specs/AES.cry', 'AES-GCM-SIV-proof/proof/cryptol-specs/AES128.cry', 'AES-GCM-SIV-proof/proof/cryptol-specs/AES256.cry', 'AES-GCM-SIV-proof/proof/asm/cryptol/X86.cry', 'aws-lc-verification/cryptol-specs/Common/Field.cry', 'aws-lc-verification/cryptol-specs/Common/mod_arith.cry', 'aws-lc-verification/cryptol-specs/Common/ModDivZ.cry', 'aws-lc-verification/cryptol-specs/Common/Set.cry', 'aws-lc-verification/cryptol-specs/Common/Morphism.cry', 'aws-lc-verification/cryptol-specs/Common/bv.cry', 'aws-lc-verification/cryptol-specs/Common/utils.cry', 'aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/MEE_CBC.cry', 'aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/AES_256_GCM.cry', 'aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/AES_GCM.cry', 'aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/GCM.cry', 'aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Cipher.cry', 'aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES_parameterized.cry', 'aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AESKeyWrapPadded.cry', 'aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AESKeyWrap.cry', 'aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/TripleDES.cry', 'aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/TDES_CBC.cry', 'aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/CBC.cry', 'aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/CTR.cry', 'aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/TDES_CFB.cry', 'aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/CFB.cry', 'aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/GF28.cry', 'aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/Algorithm.cry', 'aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/SBox.cry', 'aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/ExpandKey.cry', 'aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/SubByteSBox.cry', 'aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/Round.cry', 'aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/SubBytePlain.cry', 'aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/TBox.cry', 'aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/State.cry', 'aws-lc-verification/cryptol-specs/Primitive/Keyless/Hash/FNV.cry', 'aws-lc-verification/cryptol-specs/Primitive/Keyless/Hash/SHA1.cry', 'aws-lc-verification/cryptol-specs/Common/EC/ec_point_ops.cry', 'aws-lc-verification/cryptol-specs/Common/EC/ref_ec_mul.cry', 'aws-lc-verification/cryptol-specs/Common/EC/p384_ec_point_ops.cry', 'aws-lc-verification/cryptol-specs/McEliece_KEM/low-level/types.cry', 'aws-lc-verification/cryptol-specs/McEliece_KEM/spec/CM_Parameters.cry', 'aws-lc-verification/cryptol-specs/McEliece_KEM/spec/CM_696.cry', 'aws-lc-verification/cryptol-specs/McEliece_KEM/spec/Encapsulation.cry', 'aws-lc-verification/cryptol-specs/McEliece_KEM/spec/CM_819.cry', 'aws-lc-verification/cryptol-specs/McEliece_KEM/spec/Key_Generation.cry', 'aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/benes.cry', 'aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/decrypt_helpers.cry', 'aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/Types.cry', 'aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/util.cry', 'aws-lc-verification/SAW/spec/HASH/SHA384.cry', 'aws-lc-verification/SAW/spec/EC/EC_FIPS.cry', 'aws-lc-verification/SAW/spec/AES_KW/AES.cry', 'aws-lc-verification/SAW/spec/AES_KW/X86.cry', 'aws-lc-verification/NSym/spec/SHA384recEquiv.cry', 'aws-lc-verification/NSym/spec/SHA512recEquiv.cry', 'aws-lc-verification/cryptol-specs-aes-gcm/Common/ntt.cry', ' ...
# Output root:       /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/AES-GCM-SIV-proof/proof/cryptol-specs/AES.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/AES-GCM-SIV-proof/proof/cryptol-specs/AES
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/AES-GCM-SIV-proof/proof/cryptol-specs/AES.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/AES-GCM-SIV-proof/proof/cryptol-specs/AES
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/AES-GCM-SIV-proof/proof/cryptol-specs/AES.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/AES-GCM-SIV-proof/proof/cryptol-specs/AES128.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/AES-GCM-SIV-proof/proof/cryptol-specs/AES128
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/AES-GCM-SIV-proof/proof/cryptol-specs/AES128.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/AES-GCM-SIV-proof/proof/cryptol-specs/AES128
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/AES-GCM-SIV-proof/proof/cryptol-specs/AES128.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/AES-GCM-SIV-proof/proof/cryptol-specs/AES256.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/AES-GCM-SIV-proof/proof/cryptol-specs/AES256
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/AES-GCM-SIV-proof/proof/cryptol-specs/AES256.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/AES-GCM-SIV-proof/proof/cryptol-specs/AES256
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/AES-GCM-SIV-proof/proof/cryptol-specs/AES256.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/AES-GCM-SIV-proof/proof/asm/cryptol/X86.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/AES-GCM-SIV-proof/proof/asm/cryptol/X86
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/AES-GCM-SIV-proof/proof/asm/cryptol/X86.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/AES-GCM-SIV-proof/proof/asm/cryptol/X86
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/AES-GCM-SIV-proof/proof/asm/cryptol/X86.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Common/Field.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Common/Field
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Common/Field.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Common/Field
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Common/Field.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Common/mod_arith.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Common/mod_arith
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Common/mod_arith.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Common/mod_arith
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Common/mod_arith.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Common/ModDivZ.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Common/ModDivZ
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Common/ModDivZ.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Common/ModDivZ
# ❌ Error (1) on /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Common/ModDivZ.cry
# STDOUT:
#  Parsed 1 module(s).
#
# STDERR:
#  toy-cryptol-ast: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Common/ModDivZ/003_(%/).cry: withFile: does not exist (No such file or directory)
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Common/Set.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Common/Set
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Common/Set.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Common/Set
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Common/Set.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Common/Morphism.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Common/Morphism
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Common/Morphism.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Common/Morphism
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Common/Morphism.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Common/bv.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Common/bv
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Common/bv.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Common/bv
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Common/bv.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Common/utils.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Common/utils
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Common/utils.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Common/utils
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Common/utils.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/MEE_CBC.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/MEE_CBC
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/MEE_CBC.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/MEE_CBC
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/MEE_CBC.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/AES_256_GCM.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/AES_256_GCM
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/AES_256_GCM.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/AES_256_GCM
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/AES_256_GCM.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/AES_GCM.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/AES_GCM
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/AES_GCM.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/AES_GCM
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/AES_GCM.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/GCM.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/GCM
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/GCM.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/GCM
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/GCM.cry
# STDOUT:
#  Parsed 2 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Cipher.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Cipher
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Cipher.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Cipher
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Cipher.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES_parameterized.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES_parameterized
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES_parameterized.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES_parameterized
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES_parameterized.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AESKeyWrapPadded.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AESKeyWrapPadded
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AESKeyWrapPadded.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AESKeyWrapPadded
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AESKeyWrapPadded.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AESKeyWrap.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AESKeyWrap
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AESKeyWrap.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AESKeyWrap
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AESKeyWrap.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/TripleDES.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/TripleDES
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/TripleDES.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/TripleDES
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/TripleDES.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/TDES_CBC.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/TDES_CBC
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/TDES_CBC.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/TDES_CBC
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/TDES_CBC.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/CBC.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/CBC
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/CBC.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/CBC
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/CBC.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/CTR.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/CTR
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/CTR.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/CTR
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/CTR.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/TDES_CFB.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/TDES_CFB
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/TDES_CFB.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/TDES_CFB
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/TDES_CFB.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/CFB.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/CFB
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/CFB.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/CFB
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/CFB.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/GF28.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/GF28
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/GF28.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/GF28
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/GF28.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/Algorithm.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/Algorithm
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/Algorithm.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/Algorithm
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/Algorithm.cry
# STDOUT:
#  Parsed 2 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/SBox.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/SBox
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/SBox.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/SBox
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/SBox.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/ExpandKey.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/ExpandKey
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/ExpandKey.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/ExpandKey
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/ExpandKey.cry
# STDOUT:
#  Parsed 2 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/SubByteSBox.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/SubByteSBox
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/SubByteSBox.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/SubByteSBox
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/SubByteSBox.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/Round.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/Round
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/Round.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/Round
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/Round.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/SubBytePlain.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/SubBytePlain
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/SubBytePlain.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/SubBytePlain
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/SubBytePlain.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/TBox.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/TBox
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/TBox.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/TBox
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/TBox.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/State.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/State
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/State.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/State
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/State.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Keyless/Hash/FNV.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Keyless/Hash/FNV
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Keyless/Hash/FNV.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Keyless/Hash/FNV
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Keyless/Hash/FNV.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Keyless/Hash/SHA1.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Keyless/Hash/SHA1
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Keyless/Hash/SHA1.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Primitive/Keyless/Hash/SHA1
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Primitive/Keyless/Hash/SHA1.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Common/EC/ec_point_ops.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Common/EC/ec_point_ops
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Common/EC/ec_point_ops.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Common/EC/ec_point_ops
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Common/EC/ec_point_ops.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Common/EC/ref_ec_mul.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Common/EC/ref_ec_mul
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Common/EC/ref_ec_mul.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Common/EC/ref_ec_mul
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Common/EC/ref_ec_mul.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Common/EC/p384_ec_point_ops.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Common/EC/p384_ec_point_ops
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Common/EC/p384_ec_point_ops.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/Common/EC/p384_ec_point_ops
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/Common/EC/p384_ec_point_ops.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/McEliece_KEM/low-level/types.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/low-level/types
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/McEliece_KEM/low-level/types.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/low-level/types
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/McEliece_KEM/low-level/types.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/CM_Parameters.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/CM_Parameters
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/CM_Parameters.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/CM_Parameters
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/CM_Parameters.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/CM_696.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/CM_696
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/CM_696.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/CM_696
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/CM_696.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/Encapsulation.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/Encapsulation
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/Encapsulation.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/Encapsulation
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/Encapsulation.cry
# STDOUT:
#  Parsed 2 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/CM_819.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/CM_819
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/CM_819.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/CM_819
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/CM_819.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/Key_Generation.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/Key_Generation
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/Key_Generation.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/Key_Generation
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/McEliece_KEM/spec/Key_Generation.cry
# STDOUT:
#  Parsed 2 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/benes.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/benes
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/benes.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/benes
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/benes.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/decrypt_helpers.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/decrypt_helpers
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/decrypt_helpers.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/decrypt_helpers
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/decrypt_helpers.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/Types.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/Types
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/Types.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/Types
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/Types.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/util.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/util
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/util.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/util
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs/McEliece_KEM/high-level/util.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/SAW/spec/HASH/SHA384.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/SAW/spec/HASH/SHA384
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/SAW/spec/HASH/SHA384.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/SAW/spec/HASH/SHA384
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/SAW/spec/HASH/SHA384.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/SAW/spec/EC/EC_FIPS.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/SAW/spec/EC/EC_FIPS
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/SAW/spec/EC/EC_FIPS.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/SAW/spec/EC/EC_FIPS
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/SAW/spec/EC/EC_FIPS.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/SAW/spec/AES_KW/AES.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/SAW/spec/AES_KW/AES
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/SAW/spec/AES_KW/AES.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/SAW/spec/AES_KW/AES
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/SAW/spec/AES_KW/AES.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/SAW/spec/AES_KW/X86.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/SAW/spec/AES_KW/X86
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/SAW/spec/AES_KW/X86.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/SAW/spec/AES_KW/X86
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/SAW/spec/AES_KW/X86.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/NSym/spec/SHA384recEquiv.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/NSym/spec/SHA384recEquiv
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/NSym/spec/SHA384recEquiv.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/NSym/spec/SHA384recEquiv
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/NSym/spec/SHA384recEquiv.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/NSym/spec/SHA512recEquiv.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/NSym/spec/SHA512recEquiv
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/NSym/spec/SHA512recEquiv.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/NSym/spec/SHA512recEquiv
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/NSym/spec/SHA512recEquiv.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs-aes-gcm/Common/ntt.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Common/ntt
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs-aes-gcm/Common/ntt.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Common/ntt
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs-aes-gcm/Common/ntt.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs-aes-gcm/Common/LUP.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Common/LUP
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs-aes-gcm/Common/LUP.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Common/LUP
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs-aes-gcm/Common/LUP.cry
# STDOUT:
#  Parsed 2 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs-aes-gcm/Common/pick.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Common/pick
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs-aes-gcm/Common/pick.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Common/pick
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs-aes-gcm/Common/pick.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs-aes-gcm/Common/GF24.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Common/GF24
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs-aes-gcm/Common/GF24.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Common/GF24
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs-aes-gcm/Common/GF24.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs-aes-gcm/Primitive/Symmetric/MAC/HMAC.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Primitive/Symmetric/MAC/HMAC
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs-aes-gcm/Primitive/Symmetric/MAC/HMAC.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Primitive/Symmetric/MAC/HMAC
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs-aes-gcm/Primitive/Symmetric/MAC/HMAC.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs-aes-gcm/Primitive/Symmetric/Cipher/Block/Modes/TDES_CBC.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Primitive/Symmetric/Cipher/Block/Modes/TDES_CBC
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs-aes-gcm/Primitive/Symmetric/Cipher/Block/Modes/TDES_CBC.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/aws-lc-verification/cryptol-specs-aes-gcm/Primitive/Symmetric/Cipher/Block/Modes/TDES_CBC
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/aws-lc-verification/cryptol-specs-aes-gcm/Primitive/Symmetric/Cipher/Block/Modes/TDES_CBC.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# ...
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/intTests/test1703/test.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/intTests/test0052_smt_array_1/Test.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/saw-script/intTests/test0052_smt_array_1/Test
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/intTests/test0052_smt_array_1/Test.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/saw-script/intTests/test0052_smt_array_1/Test
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/intTests/test0052_smt_array_1/Test.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/intTests/test0037_popcount/spec.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/saw-script/intTests/test0037_popcount/spec
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/intTests/test0037_popcount/spec.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/saw-script/intTests/test0037_popcount/spec
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/intTests/test0037_popcount/spec.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/intTests/test_w4_unint_rme/Code.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/saw-script/intTests/test_w4_unint_rme/Code
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/intTests/test_w4_unint_rme/Code.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/saw-script/intTests/test_w4_unint_rme/Code
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/intTests/test_w4_unint_rme/Code.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/intTests/test_saw_submodule_access1/HWithPrivateSubmodules.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/saw-script/intTests/test_saw_submodule_access1/HWithPrivateSubmodules
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/intTests/test_saw_submodule_access1/HWithPrivateSubmodules.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/saw-script/intTests/test_saw_submodule_access1/HWithPrivateSubmodules
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/intTests/test_saw_submodule_access1/HWithPrivateSubmodules.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/intTests/test_saw_submodule_access1/HWithSubmodules.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/saw-script/intTests/test_saw_submodule_access1/HWithSubmodules
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/intTests/test_saw_submodule_access1/HWithSubmodules.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/saw-script/intTests/test_saw_submodule_access1/HWithSubmodules
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/intTests/test_saw_submodule_access1/HWithSubmodules.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/intTests/test_saw_submodule_access1/UseFunctors.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/saw-script/intTests/test_saw_submodule_access1/UseFunctors
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/intTests/test_saw_submodule_access1/UseFunctors.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/saw-script/intTests/test_saw_submodule_access1/UseFunctors
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/intTests/test_saw_submodule_access1/UseFunctors.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/intTests/test_saw_submodule_access1/HWithSubmodules2.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/saw-script/intTests/test_saw_submodule_access1/HWithSubmodules2
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/intTests/test_saw_submodule_access1/HWithSubmodules2.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/saw-script/intTests/test_saw_submodule_access1/HWithSubmodules2
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/intTests/test_saw_submodule_access1/HWithSubmodules2.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/intTests/test2674/Example.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/saw-script/intTests/test2674/Example
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/intTests/test2674/Example.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/saw-script/intTests/test2674/Example
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/intTests/test2674/Example.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/intTests/test_ffi_verify/test.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/saw-script/intTests/test_ffi_verify/test
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/intTests/test_ffi_verify/test.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/saw-script/intTests/test_ffi_verify/test
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/intTests/test_ffi_verify/test.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/intTests/test2337/test.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/saw-script/intTests/test2337/test
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/intTests/test2337/test.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/saw-script/intTests/test2337/test
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/intTests/test2337/test.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/crux-mir-comp/test/symb_eval/comp/crux_spec_for_array.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/saw-script/crux-mir-comp/test/symb_eval/comp/crux_spec_for_array
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/crux-mir-comp/test/symb_eval/comp/crux_spec_for_array.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/saw-script/crux-mir-comp/test/symb_eval/comp/crux_spec_for_array
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/crux-mir-comp/test/symb_eval/comp/crux_spec_for_array.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/crux-mir-comp/test/symb_eval/cryptol/uninterp.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/saw-script/crux-mir-comp/test/symb_eval/cryptol/uninterp
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/crux-mir-comp/test/symb_eval/cryptol/uninterp.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/saw-script/crux-mir-comp/test/symb_eval/cryptol/uninterp
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/crux-mir-comp/test/symb_eval/cryptol/uninterp.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/crux-mir-comp/test/symb_eval/cryptol/basic.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/saw-script/crux-mir-comp/test/symb_eval/cryptol/basic
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/crux-mir-comp/test/symb_eval/cryptol/basic.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/saw-script/crux-mir-comp/test/symb_eval/cryptol/basic
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/crux-mir-comp/test/symb_eval/cryptol/basic.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/crux-mir-comp/test/symb_eval/cryptol/size_poly_nested.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/saw-script/crux-mir-comp/test/symb_eval/cryptol/size_poly_nested
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/crux-mir-comp/test/symb_eval/cryptol/size_poly_nested.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/saw-script/crux-mir-comp/test/symb_eval/cryptol/size_poly_nested
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/crux-mir-comp/test/symb_eval/cryptol/size_poly_nested.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/crux-mir-comp/test/symb_eval/cryptol/SliceArg.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/saw-script/crux-mir-comp/test/symb_eval/cryptol/SliceArg
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/crux-mir-comp/test/symb_eval/cryptol/SliceArg.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/saw-script/crux-mir-comp/test/symb_eval/cryptol/SliceArg
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/crux-mir-comp/test/symb_eval/cryptol/SliceArg.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/exercises/sha512/SHA.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/saw-script/exercises/sha512/SHA
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/exercises/sha512/SHA.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/saw-script/exercises/sha512/SHA
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/exercises/sha512/SHA.cry
# STDOUT:
#  Parsed 2 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/exercises/functional-correctness/point/Point.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/saw-script/exercises/functional-correctness/point/Point
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/exercises/functional-correctness/point/Point.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/saw-script/exercises/functional-correctness/point/Point
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/exercises/functional-correctness/point/Point.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/exercises/functional-correctness/popcount/Popcount.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/saw-script/exercises/functional-correctness/popcount/Popcount
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/exercises/functional-correctness/popcount/Popcount.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/saw-script/exercises/functional-correctness/popcount/Popcount
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/exercises/functional-correctness/popcount/Popcount.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/exercises/functional-correctness/swap/solution/Swap.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/saw-script/exercises/functional-correctness/swap/solution/Swap
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/exercises/functional-correctness/swap/solution/Swap.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/saw-script/exercises/functional-correctness/swap/solution/Swap
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/exercises/functional-correctness/swap/solution/Swap.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/examples/sequential_aigs/StateMachine.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/saw-script/examples/sequential_aigs/StateMachine
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/examples/sequential_aigs/StateMachine.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/saw-script/examples/sequential_aigs/StateMachine
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/examples/sequential_aigs/StateMachine.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/examples/llvm/iterative_average/test.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/saw-script/examples/llvm/iterative_average/test
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/examples/llvm/iterative_average/test.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/saw-script/examples/llvm/iterative_average/test
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/examples/llvm/iterative_average/test.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/examples/llvm/union/test.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/saw-script/examples/llvm/union/test
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/examples/llvm/union/test.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/saw-script/examples/llvm/union/test
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/examples/llvm/union/test.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/doc/llvm-java-verification-with-saw/code/ffs.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/saw-script/doc/llvm-java-verification-with-saw/code/ffs
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/doc/llvm-java-verification-with-saw/code/ffs.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/saw-script/doc/llvm-java-verification-with-saw/code/ffs
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/doc/llvm-java-verification-with-saw/code/ffs.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/otherTests/saw-core-rocq/Simple.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/saw-script/otherTests/saw-core-rocq/Simple
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/otherTests/saw-core-rocq/Simple.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/saw-script/otherTests/saw-core-rocq/Simple
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/saw-script/otherTests/saw-core-rocq/Simple.cry
# STDOUT:
#  Parsed 1 module(s).
