# %% [markdown]
# # Cryptol slicer notebook
#
# This notebook calls the Haskell `toy-cryptol-ast` executable to slice Cryptol modules
# into per-definition files. It assumes:
#
# 1. You have the `toy-cryptol-ast` repo checked out.
# 2. You can run `cabal build` or `cabal run toy-cryptol-ast` successfully from that repo.
# 3. You have a local checkout of `cryptol-specs` (or any directory tree of `.cry` files).

# %%
from pathlib import Path 
import os, dotenv, yaml

with open("config.yaml", "r") as f:
    config = yaml.safe_load(f)

dotenv.load_dotenv()
os.chdir(Path(config["pythonpath"]).expanduser())

# %%
import subprocess
import pandas as pd

# --- CONFIG: EDIT THESE FOR YOUR MACHINE ---
VERSION = config["version"]
# Root of your repo/workspace that contains both the Cryptol specs and the file list
REPO_ROOT_DIR = Path(config["repo_root"]).expanduser()  # <-- adjust if needed

# Path to the file listing all .cry files (e.g., 0_long_files.txt)
all_sources_raw_df = pd.read_json(f"data/all_sources_raw_{VERSION}.jsonl", lines=True)
FILE_LIST = all_sources_raw_df["filename"].tolist()

# Root directory where all slice directories will be created
OUTPUT_ROOT = REPO_ROOT_DIR / "cryptol_slices"

# Directory containing the cabal project for toy-cryptol-ast
CABAL_PROJECT_ROOT = "toy-cryptol-ast"  # directory with toy-cryptol-ast.cabal

# %%
def run_haskell_slicer(cry_path: Path, out_dir: Path):
    """
    Call: cabal run toy-cryptol-ast -- <file> <OUTDIR>
    from within CABAL_PROJECT_ROOT.
    """
    out_dir.mkdir(parents=True, exist_ok=True)

    cmd = [
        "cabal",
        "run",
        "toy-cryptol-ast",
        "--",
        str(cry_path),
        str(out_dir),
    ]

    print("Running:", " ".join(cmd))
    result = subprocess.run(
        cmd,
        cwd=str(CABAL_PROJECT_ROOT),  # run inside the cabal project
        capture_output=True,
        text=True,
    )

    if result.returncode != 0:
        print(f"❌ Error ({result.returncode}) on {cry_path}")
        if result.stdout.strip():
            print("STDOUT:\n", result.stdout)
        if result.stderr.strip():
            print("STDERR:\n", result.stderr)
    else:
        print(f"✅ OK: {cry_path}")
        if result.stdout.strip():
            print("STDOUT:\n", result.stdout)

# %%
def iter_file_list(file_list: Path):
    """
    Yield each non-empty, non-comment line from FILE_LIST.
    Lines should be repo-relative paths like:
      cryptol-specs/Primitive/Symmetric/Cipher/Block/KATAN.cry
    """
    with file_list.open() as f:
        for raw in f:
            line = raw.strip()
            if not line:
                continue
            if line.startswith("#"):
                continue
            yield line


def cry_rel_to_paths(rel: str):
    """
    Given a relative .cry path from FILE_LIST, return:
      (absolute_input_path, absolute_output_dir_path)
    Output dir is:
      OUTPUT_ROOT / relative_path_without_.cry_suffix
    """
    cry_rel = Path(rel)
    cry_abs = REPO_ROOT_DIR / cry_rel

    # Example:
    #   rel: cryptol-specs/Primitive/Symmetric/Cipher/Block/KATAN.cry
    #   out: OUTPUT_ROOT/cryptol-specs/Primitive/Symmetric/Cipher/Block/KATAN/
    out_dir = OUTPUT_ROOT / cry_rel.with_suffix("")

    return cry_abs, out_dir


print(f"Reading list from: {FILE_LIST}")
print(f"Output root:       {OUTPUT_ROOT}")
OUTPUT_ROOT.mkdir(parents=True, exist_ok=True)

for rel in FILE_LIST:
    cry_path, out_dir = cry_rel_to_paths(rel)

    if not cry_path.is_file():
        print(f"⚠️  Skipping {cry_path} (file not found)")
        continue

    print("\n=== Slicing:", cry_path, "===")
    print("  → output dir:", out_dir)
    run_haskell_slicer(cry_path, out_dir)
# Out:
# Reading list from: ['cryptol/examples/AES.cry', 'cryptol/examples/width.cry', 'cryptol/examples/splitAt.cry', 'cryptol/examples/AE.cry', 'cryptol/examples/Cipher.cry', 'cryptol/examples/xor_cipher.cry', 'cryptol/examples/zero_weird.cry', 'cryptol/examples/DES.cry', 'cryptol/examples/builtin_lifting.cry', 'cryptol/examples/inflist.cry', 'cryptol/examples/Karatsuba.cry', 'cryptol/examples/comp.cry', 'cryptol/examples/DEStest.cry', 'cryptol/examples/mini.cry', 'cryptol/examples/Test.cry', 'cryptol/examples/OptionUtils.cry', 'cryptol/examples/builtins.cry', 'cryptol/examples/props.cry', 'cryptol/examples/demote.cry', 'cryptol/examples/append.cry', 'cryptol/examples/split.cry', 'cryptol/lib/Array.cry', 'cryptol/lib/SuiteB.cry', 'cryptol/lib/Float.cry', 'cryptol/lib/PrimeEC.cry', 'cryptol/lib/Cryptol.cry', 'cryptol/bench/data/AES.cry', 'cryptol/bench/data/BigSequenceHex.cry', 'cryptol/bench/data/BigSequence.cry', 'cryptol/bench/data/ZUC.cry', 'cryptol/bench/data/SHA512.cry', 'cryptol/rust/cry-ffi/Example.cry', 'cryptol/docs/ProgrammingCryptol/enigma/ticket141.cry', 'cryptol/docs/ProgrammingCryptol/enigma/Finite.cry', 'cryptol/docs/ProgrammingCryptol/enigma/Enigma.cry', 'cryptol/docs/ProgrammingCryptol/enigma/Simple.cry', 'cryptol/docs/ProgrammingCryptol/aes/AES.cry', 'cryptol/examples/funstuff/NQueens.cry', 'cryptol/examples/funstuff/FoxChickenCorn.cry', 'cryptol/examples/funstuff/Coins.cry', 'cryptol/examples/funstuff/marble.cry', 'cryptol/examples/SuiteB_FFI/perf-bench.cry', 'cryptol/examples/SuiteB_FFI/SuiteB_FFI.cry', 'cryptol/examples/contrib/mkrand.cry', 'cryptol/examples/contrib/EvenMansour.cry', 'cryptol/examples/contrib/CAST5.cry', 'cryptol/examples/contrib/A51.cry', 'cryptol/examples/contrib/RC4.cry', 'cryptol/examples/contrib/MISTY1.cry', 'cryptol/examples/MiniLock/Keys.cry', 'cryptol/examples/param_modules/AES.cry', 'cryptol/examples/param_modules/SHA256.cry', 'cryptol/examples/param_modules/AES_GCM_SIV_Test.cry', 'cryptol/examples/param_modules/GCM_AES_Tests.cry', 'cryptol/examples/param_modules/SHA.cry', 'cryptol/examples/maliciousSHA/malicious_SHA1.cry', 'cryptol/examples/SuiteB_FFI/tests/aes-vectors.cry', 'cryptol/examples/SuiteB_FFI/tests/aes-mct-ecb.cry', 'cryptol/examples/MiniLock/prim/SCrypt.cry', 'cryptol/examples/MiniLock/prim/SHA256.cry', 'cryptol/examples/MiniLock/prim/mod_arith.cry', 'cryptol/examples/MiniLock/prim/HMAC.cry', 'cryptol/examples/MiniLock/prim/Blake2s.cry', 'cryptol/examples/MiniLock/prim/TestHMAC.cry', 'cryptol/examples/MiniLock/prim/CryptoBox.cry', 'cryptol/examples/MiniLock/prim/Salsa20.cry', 'cryptol/examples/MiniLock/prim/PBKDF2.cry', 'cryptol/examples/MiniLock/prim/Base64.cry', 'cryptol/examples/MiniLock/prim/Base58.cry', 'cryptol/examples/MiniLock/prim/bv.cry', 'cryptol/examples/MiniLock/prim/LittleEndian.cry', 'cryptol/examples/param_modules/Common/AES_GCM_SIV.cry', 'cryptol/examples/param_modules/Common/SHA.cry', 'cryptol/examples/param_modules/Common/GCM.cry', 'cryptol/examples/param_modules/AES/GF28.cry', 'cryptol/examples/param_modules/AES/Algorithm.cry', 'cryptol/examples/param_modules/AES/SBox.cry', 'cryptol/examples/param_modules/AES/ExpandKey.cry', 'cryptol/examples/param_modules/AES/SubByteSBox.cry', 'cryptol/examples/param_modules/AES/Round.cry', 'cryptol/examples/param_modules/AES/SubBytePlain.cry', 'cryptol/examples/param_modules/AES/TBox.cry', 'cryptol/examples/param_modules/AES/State.cry', 'cryptol/lib/Cryptol/Reference.cry', 'cryptol/cryptol-remote-api/python/tests/cryptol_eval/test-files/M.cry', 'cryptol/cryptol-remote-api/python/tests/cryptol_eval/test-files/test-subdir/Bar.cry', 'cryptol/cryptol-remote-api/python/tests/cryptol/test-files/M.cry', 'cryptol/cryptol-remote-api/python/tests/cryptol/test-files/Names.cry', 'cryptol/cryptol-remote-api/python/tests/cryptol/test-files/Param.cry', 'cryptol/cryptol-remote-api/python/tests/cryptol/test-files/Modules.cry', 'cryptol/cryptol-remote-api/python/tests/cryptol/test-files/Id.cry', 'cryptol/cryptol-remote-api/python/tests/c ...
# Output root:       /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/AES.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/AES
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/AES.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/AES
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/AES.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/width.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/width
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/width.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/width
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/width.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/splitAt.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/splitAt
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/splitAt.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/splitAt
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/splitAt.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/AE.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/AE
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/AE.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/AE
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/AE.cry
# STDOUT:
#  Parsed 2 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/Cipher.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/Cipher
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/Cipher.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/Cipher
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/Cipher.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/xor_cipher.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/xor_cipher
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/xor_cipher.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/xor_cipher
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/xor_cipher.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/zero_weird.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/zero_weird
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/zero_weird.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/zero_weird
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/zero_weird.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/DES.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/DES
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/DES.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/DES
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/DES.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/builtin_lifting.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/builtin_lifting
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/builtin_lifting.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/builtin_lifting
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/builtin_lifting.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/inflist.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/inflist
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/inflist.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/inflist
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/inflist.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/Karatsuba.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/Karatsuba
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/Karatsuba.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/Karatsuba
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/Karatsuba.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/comp.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/comp
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/comp.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/comp
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/comp.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/DEStest.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/DEStest
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/DEStest.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/DEStest
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/DEStest.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/mini.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/mini
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/mini.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/mini
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/mini.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/Test.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/Test
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/Test.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/Test
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/Test.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/OptionUtils.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/OptionUtils
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/OptionUtils.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/OptionUtils
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/OptionUtils.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/builtins.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/builtins
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/builtins.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/builtins
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/builtins.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/props.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/props
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/props.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/props
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/props.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/demote.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/demote
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/demote.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/demote
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/demote.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/append.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/append
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/append.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/append
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/append.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/split.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/split
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/split.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/split
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/split.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/lib/Array.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/lib/Array
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/lib/Array.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/lib/Array
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/lib/Array.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/lib/SuiteB.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/lib/SuiteB
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/lib/SuiteB.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/lib/SuiteB
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/lib/SuiteB.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/lib/Float.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/lib/Float
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/lib/Float.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/lib/Float
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/lib/Float.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/lib/PrimeEC.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/lib/PrimeEC
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/lib/PrimeEC.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/lib/PrimeEC
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/lib/PrimeEC.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/lib/Cryptol.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/lib/Cryptol
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/lib/Cryptol.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/lib/Cryptol
# ❌ Error (1) on /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/lib/Cryptol.cry
# STDOUT:
#  Parsed 1 module(s).
#
# STDERR:
#  toy-cryptol-ast: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/lib/Cryptol/022_(/).cry: withFile: does not exist (No such file or directory)
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/bench/data/AES.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/bench/data/AES
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/bench/data/AES.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/bench/data/AES
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/bench/data/AES.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/bench/data/BigSequenceHex.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/bench/data/BigSequenceHex
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/bench/data/BigSequenceHex.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/bench/data/BigSequenceHex
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/bench/data/BigSequenceHex.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/bench/data/BigSequence.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/bench/data/BigSequence
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/bench/data/BigSequence.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/bench/data/BigSequence
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/bench/data/BigSequence.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/bench/data/ZUC.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/bench/data/ZUC
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/bench/data/ZUC.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/bench/data/ZUC
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/bench/data/ZUC.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/bench/data/SHA512.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/bench/data/SHA512
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/bench/data/SHA512.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/bench/data/SHA512
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/bench/data/SHA512.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/rust/cry-ffi/Example.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/rust/cry-ffi/Example
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/rust/cry-ffi/Example.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/rust/cry-ffi/Example
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/rust/cry-ffi/Example.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/docs/ProgrammingCryptol/enigma/ticket141.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/docs/ProgrammingCryptol/enigma/ticket141
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/docs/ProgrammingCryptol/enigma/ticket141.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/docs/ProgrammingCryptol/enigma/ticket141
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/docs/ProgrammingCryptol/enigma/ticket141.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/docs/ProgrammingCryptol/enigma/Finite.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/docs/ProgrammingCryptol/enigma/Finite
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/docs/ProgrammingCryptol/enigma/Finite.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/docs/ProgrammingCryptol/enigma/Finite
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/docs/ProgrammingCryptol/enigma/Finite.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/docs/ProgrammingCryptol/enigma/Enigma.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/docs/ProgrammingCryptol/enigma/Enigma
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/docs/ProgrammingCryptol/enigma/Enigma.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/docs/ProgrammingCryptol/enigma/Enigma
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/docs/ProgrammingCryptol/enigma/Enigma.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/docs/ProgrammingCryptol/enigma/Simple.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/docs/ProgrammingCryptol/enigma/Simple
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/docs/ProgrammingCryptol/enigma/Simple.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/docs/ProgrammingCryptol/enigma/Simple
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/docs/ProgrammingCryptol/enigma/Simple.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/docs/ProgrammingCryptol/aes/AES.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/docs/ProgrammingCryptol/aes/AES
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/docs/ProgrammingCryptol/aes/AES.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/docs/ProgrammingCryptol/aes/AES
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/docs/ProgrammingCryptol/aes/AES.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/funstuff/NQueens.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/funstuff/NQueens
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/funstuff/NQueens.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/funstuff/NQueens
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/funstuff/NQueens.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/funstuff/FoxChickenCorn.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/funstuff/FoxChickenCorn
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/funstuff/FoxChickenCorn.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/funstuff/FoxChickenCorn
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/funstuff/FoxChickenCorn.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/funstuff/Coins.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/funstuff/Coins
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/funstuff/Coins.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/funstuff/Coins
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/funstuff/Coins.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/funstuff/marble.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/funstuff/marble
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/funstuff/marble.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/funstuff/marble
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/funstuff/marble.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/SuiteB_FFI/perf-bench.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/SuiteB_FFI/perf-bench
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/SuiteB_FFI/perf-bench.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/SuiteB_FFI/perf-bench
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/SuiteB_FFI/perf-bench.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/SuiteB_FFI/SuiteB_FFI.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/SuiteB_FFI/SuiteB_FFI
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/SuiteB_FFI/SuiteB_FFI.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/SuiteB_FFI/SuiteB_FFI
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/SuiteB_FFI/SuiteB_FFI.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/contrib/mkrand.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/contrib/mkrand
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/contrib/mkrand.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/contrib/mkrand
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/contrib/mkrand.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/contrib/EvenMansour.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/contrib/EvenMansour
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/contrib/EvenMansour.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/contrib/EvenMansour
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/contrib/EvenMansour.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/contrib/CAST5.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/contrib/CAST5
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/contrib/CAST5.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/contrib/CAST5
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/contrib/CAST5.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/contrib/A51.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/contrib/A51
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/contrib/A51.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/contrib/A51
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/contrib/A51.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/contrib/RC4.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/contrib/RC4
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/contrib/RC4.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/contrib/RC4
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/contrib/RC4.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/contrib/MISTY1.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/contrib/MISTY1
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/contrib/MISTY1.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/contrib/MISTY1
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/contrib/MISTY1.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/MiniLock/Keys.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/MiniLock/Keys
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/MiniLock/Keys.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/MiniLock/Keys
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/MiniLock/Keys.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/param_modules/AES.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/param_modules/AES
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/param_modules/AES.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/param_modules/AES
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/param_modules/AES.cry
# STDOUT:
#  Parsed 2 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/param_modules/SHA256.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/param_modules/SHA256
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/param_modules/SHA256.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/param_modules/SHA256
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/param_modules/SHA256.cry
# STDOUT:
#  Parsed 2 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/param_modules/AES_GCM_SIV_Test.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/param_modules/AES_GCM_SIV_Test
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/param_modules/AES_GCM_SIV_Test.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/param_modules/AES_GCM_SIV_Test
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/param_modules/AES_GCM_SIV_Test.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/param_modules/GCM_AES_Tests.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/param_modules/GCM_AES_Tests
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/param_modules/GCM_AES_Tests.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/param_modules/GCM_AES_Tests
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/param_modules/GCM_AES_Tests.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/param_modules/SHA.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/param_modules/SHA
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/param_modules/SHA.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/param_modules/SHA
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/param_modules/SHA.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/maliciousSHA/malicious_SHA1.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/maliciousSHA/malicious_SHA1
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/maliciousSHA/malicious_SHA1.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/maliciousSHA/malicious_SHA1
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/maliciousSHA/malicious_SHA1.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/SuiteB_FFI/tests/aes-vectors.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/SuiteB_FFI/tests/aes-vectors
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/SuiteB_FFI/tests/aes-vectors.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/SuiteB_FFI/tests/aes-vectors
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/SuiteB_FFI/tests/aes-vectors.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/SuiteB_FFI/tests/aes-mct-ecb.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/SuiteB_FFI/tests/aes-mct-ecb
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/SuiteB_FFI/tests/aes-mct-ecb.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/SuiteB_FFI/tests/aes-mct-ecb
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/SuiteB_FFI/tests/aes-mct-ecb.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/MiniLock/prim/SCrypt.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/MiniLock/prim/SCrypt
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/MiniLock/prim/SCrypt.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/MiniLock/prim/SCrypt
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/MiniLock/prim/SCrypt.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/MiniLock/prim/SHA256.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/MiniLock/prim/SHA256
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/MiniLock/prim/SHA256.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/MiniLock/prim/SHA256
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/MiniLock/prim/SHA256.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/MiniLock/prim/mod_arith.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/MiniLock/prim/mod_arith
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/MiniLock/prim/mod_arith.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/MiniLock/prim/mod_arith
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/MiniLock/prim/mod_arith.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/MiniLock/prim/HMAC.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/MiniLock/prim/HMAC
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/MiniLock/prim/HMAC.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/MiniLock/prim/HMAC
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/MiniLock/prim/HMAC.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/MiniLock/prim/Blake2s.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/MiniLock/prim/Blake2s
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/MiniLock/prim/Blake2s.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/MiniLock/prim/Blake2s
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/MiniLock/prim/Blake2s.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/MiniLock/prim/TestHMAC.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/MiniLock/prim/TestHMAC
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/MiniLock/prim/TestHMAC.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/MiniLock/prim/TestHMAC
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/MiniLock/prim/TestHMAC.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/MiniLock/prim/CryptoBox.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/MiniLock/prim/CryptoBox
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/MiniLock/prim/CryptoBox.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/MiniLock/prim/CryptoBox
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/MiniLock/prim/CryptoBox.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/MiniLock/prim/Salsa20.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/MiniLock/prim/Salsa20
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/MiniLock/prim/Salsa20.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/MiniLock/prim/Salsa20
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/MiniLock/prim/Salsa20.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/MiniLock/prim/PBKDF2.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/MiniLock/prim/PBKDF2
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/MiniLock/prim/PBKDF2.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/MiniLock/prim/PBKDF2
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/MiniLock/prim/PBKDF2.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/MiniLock/prim/Base64.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/MiniLock/prim/Base64
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/MiniLock/prim/Base64.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/MiniLock/prim/Base64
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/MiniLock/prim/Base64.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/MiniLock/prim/Base58.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/MiniLock/prim/Base58
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/MiniLock/prim/Base58.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/MiniLock/prim/Base58
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/MiniLock/prim/Base58.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/MiniLock/prim/bv.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/MiniLock/prim/bv
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/MiniLock/prim/bv.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/MiniLock/prim/bv
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/MiniLock/prim/bv.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/MiniLock/prim/LittleEndian.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/MiniLock/prim/LittleEndian
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/MiniLock/prim/LittleEndian.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/MiniLock/prim/LittleEndian
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/MiniLock/prim/LittleEndian.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/param_modules/Common/AES_GCM_SIV.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/param_modules/Common/AES_GCM_SIV
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/param_modules/Common/AES_GCM_SIV.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/param_modules/Common/AES_GCM_SIV
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/param_modules/Common/AES_GCM_SIV.cry
# STDOUT:
#  Parsed 2 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/param_modules/Common/SHA.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/param_modules/Common/SHA
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/param_modules/Common/SHA.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/param_modules/Common/SHA
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/param_modules/Common/SHA.cry
# STDOUT:
#  Parsed 2 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/param_modules/Common/GCM.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/param_modules/Common/GCM
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/param_modules/Common/GCM.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/param_modules/Common/GCM
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/param_modules/Common/GCM.cry
# STDOUT:
#  Parsed 2 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/param_modules/AES/GF28.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/param_modules/AES/GF28
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/param_modules/AES/GF28.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/param_modules/AES/GF28
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/param_modules/AES/GF28.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/param_modules/AES/Algorithm.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/param_modules/AES/Algorithm
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/param_modules/AES/Algorithm.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/param_modules/AES/Algorithm
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/param_modules/AES/Algorithm.cry
# STDOUT:
#  Parsed 2 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/param_modules/AES/SBox.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/param_modules/AES/SBox
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/param_modules/AES/SBox.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/param_modules/AES/SBox
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/param_modules/AES/SBox.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/param_modules/AES/ExpandKey.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/param_modules/AES/ExpandKey
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/param_modules/AES/ExpandKey.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol/examples/param_modules/AES/ExpandKey
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol/examples/param_modules/AES/ExpandKey.cry
# ...
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Primitive/Asymmetric/KEM/ML_KEM/Instantiations/ML_KEM.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Primitive/Asymmetric/KEM/ML_KEM/Instantiations/ML_KEM1024.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol-specs/Primitive/Asymmetric/KEM/ML_KEM/Instantiations/ML_KEM1024
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Primitive/Asymmetric/KEM/ML_KEM/Instantiations/ML_KEM1024.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol-specs/Primitive/Asymmetric/KEM/ML_KEM/Instantiations/ML_KEM1024
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Primitive/Asymmetric/KEM/ML_KEM/Instantiations/ML_KEM1024.cry
# STDOUT:
#  Parsed 2 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Primitive/Asymmetric/KEM/ML_KEM/Instantiations/ML_KEM768.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol-specs/Primitive/Asymmetric/KEM/ML_KEM/Instantiations/ML_KEM768
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Primitive/Asymmetric/KEM/ML_KEM/Instantiations/ML_KEM768.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol-specs/Primitive/Asymmetric/KEM/ML_KEM/Instantiations/ML_KEM768
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Primitive/Asymmetric/KEM/ML_KEM/Instantiations/ML_KEM768.cry
# STDOUT:
#  Parsed 2 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Primitive/Asymmetric/KEM/ECDH/Tests/ECDH_P521.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol-specs/Primitive/Asymmetric/KEM/ECDH/Tests/ECDH_P521
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Primitive/Asymmetric/KEM/ECDH/Tests/ECDH_P521.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol-specs/Primitive/Asymmetric/KEM/ECDH/Tests/ECDH_P521
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Primitive/Asymmetric/KEM/ECDH/Tests/ECDH_P521.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Primitive/Asymmetric/KEM/ECDH/Tests/ECDH_P256.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol-specs/Primitive/Asymmetric/KEM/ECDH/Tests/ECDH_P256
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Primitive/Asymmetric/KEM/ECDH/Tests/ECDH_P256.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol-specs/Primitive/Asymmetric/KEM/ECDH/Tests/ECDH_P256
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Primitive/Asymmetric/KEM/ECDH/Tests/ECDH_P256.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Primitive/Asymmetric/KEM/ECDH/Tests/ECDH_P224.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol-specs/Primitive/Asymmetric/KEM/ECDH/Tests/ECDH_P224
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Primitive/Asymmetric/KEM/ECDH/Tests/ECDH_P224.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol-specs/Primitive/Asymmetric/KEM/ECDH/Tests/ECDH_P224
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Primitive/Asymmetric/KEM/ECDH/Tests/ECDH_P224.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Primitive/Asymmetric/KEM/ECDH/Tests/ECDH_P384.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol-specs/Primitive/Asymmetric/KEM/ECDH/Tests/ECDH_P384
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Primitive/Asymmetric/KEM/ECDH/Tests/ECDH_P384.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol-specs/Primitive/Asymmetric/KEM/ECDH/Tests/ECDH_P384
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Primitive/Asymmetric/KEM/ECDH/Tests/ECDH_P384.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Primitive/Asymmetric/KEM/ECDH/Instantiations/ECDH_P521.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol-specs/Primitive/Asymmetric/KEM/ECDH/Instantiations/ECDH_P521
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Primitive/Asymmetric/KEM/ECDH/Instantiations/ECDH_P521.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol-specs/Primitive/Asymmetric/KEM/ECDH/Instantiations/ECDH_P521
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Primitive/Asymmetric/KEM/ECDH/Instantiations/ECDH_P521.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Primitive/Asymmetric/KEM/ECDH/Instantiations/ECDH_P256.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol-specs/Primitive/Asymmetric/KEM/ECDH/Instantiations/ECDH_P256
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Primitive/Asymmetric/KEM/ECDH/Instantiations/ECDH_P256.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol-specs/Primitive/Asymmetric/KEM/ECDH/Instantiations/ECDH_P256
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Primitive/Asymmetric/KEM/ECDH/Instantiations/ECDH_P256.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Primitive/Asymmetric/KEM/ECDH/Instantiations/ECDH_P224.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol-specs/Primitive/Asymmetric/KEM/ECDH/Instantiations/ECDH_P224
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Primitive/Asymmetric/KEM/ECDH/Instantiations/ECDH_P224.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol-specs/Primitive/Asymmetric/KEM/ECDH/Instantiations/ECDH_P224
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Primitive/Asymmetric/KEM/ECDH/Instantiations/ECDH_P224.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Primitive/Asymmetric/KEM/ECDH/Instantiations/ECDH_P384.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol-specs/Primitive/Asymmetric/KEM/ECDH/Instantiations/ECDH_P384
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Primitive/Asymmetric/KEM/ECDH/Instantiations/ECDH_P384.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol-specs/Primitive/Asymmetric/KEM/ECDH/Instantiations/ECDH_P384
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Primitive/Asymmetric/KEM/ECDH/Instantiations/ECDH_P384.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Common/EC/ECInterface.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol-specs/Common/EC/ECInterface
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Common/EC/ECInterface.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol-specs/Common/EC/ECInterface
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Common/EC/ECInterface.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Common/EC/Curve25519.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol-specs/Common/EC/Curve25519
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Common/EC/Curve25519.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol-specs/Common/EC/Curve25519
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Common/EC/Curve25519.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Common/EC/PrimeField/PFEC.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol-specs/Common/EC/PrimeField/PFEC
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Common/EC/PrimeField/PFEC.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol-specs/Common/EC/PrimeField/PFEC
# ❌ Error (1) on /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Common/EC/PrimeField/PFEC.cry
# STDOUT:
#  Parsed 2 module(s).
#
# STDERR:
#  toy-cryptol-ast: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol-specs/Common/EC/PrimeField/PFEC/023_(%/).cry: withFile: does not exist (No such file or directory)
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Common/EC/PrimeField/Tests/P256.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol-specs/Common/EC/PrimeField/Tests/P256
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Common/EC/PrimeField/Tests/P256.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol-specs/Common/EC/PrimeField/Tests/P256
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Common/EC/PrimeField/Tests/P256.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Common/EC/PrimeField/Tests/P521.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol-specs/Common/EC/PrimeField/Tests/P521
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Common/EC/PrimeField/Tests/P521.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol-specs/Common/EC/PrimeField/Tests/P521
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Common/EC/PrimeField/Tests/P521.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Common/EC/PrimeField/Tests/P384.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol-specs/Common/EC/PrimeField/Tests/P384
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Common/EC/PrimeField/Tests/P384.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol-specs/Common/EC/PrimeField/Tests/P384
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Common/EC/PrimeField/Tests/P384.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Common/EC/PrimeField/Tests/P192.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol-specs/Common/EC/PrimeField/Tests/P192
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Common/EC/PrimeField/Tests/P192.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol-specs/Common/EC/PrimeField/Tests/P192
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Common/EC/PrimeField/Tests/P192.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Common/EC/PrimeField/Tests/P224.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol-specs/Common/EC/PrimeField/Tests/P224
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Common/EC/PrimeField/Tests/P224.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol-specs/Common/EC/PrimeField/Tests/P224
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Common/EC/PrimeField/Tests/P224.cry
# STDOUT:
#  Parsed 1 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Common/EC/PrimeField/Instantiations/P256.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol-specs/Common/EC/PrimeField/Instantiations/P256
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Common/EC/PrimeField/Instantiations/P256.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol-specs/Common/EC/PrimeField/Instantiations/P256
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Common/EC/PrimeField/Instantiations/P256.cry
# STDOUT:
#  Parsed 2 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Common/EC/PrimeField/Instantiations/P521.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol-specs/Common/EC/PrimeField/Instantiations/P521
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Common/EC/PrimeField/Instantiations/P521.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol-specs/Common/EC/PrimeField/Instantiations/P521
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Common/EC/PrimeField/Instantiations/P521.cry
# STDOUT:
#  Parsed 2 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Common/EC/PrimeField/Instantiations/P384.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol-specs/Common/EC/PrimeField/Instantiations/P384
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Common/EC/PrimeField/Instantiations/P384.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol-specs/Common/EC/PrimeField/Instantiations/P384
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Common/EC/PrimeField/Instantiations/P384.cry
# STDOUT:
#  Parsed 2 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Common/EC/PrimeField/Instantiations/P192.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol-specs/Common/EC/PrimeField/Instantiations/P192
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Common/EC/PrimeField/Instantiations/P192.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol-specs/Common/EC/PrimeField/Instantiations/P192
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Common/EC/PrimeField/Instantiations/P192.cry
# STDOUT:
#  Parsed 2 module(s).
#
#
# === Slicing: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Common/EC/PrimeField/Instantiations/P224.cry ===
#   → output dir: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol-specs/Common/EC/PrimeField/Instantiations/P224
# Running: cabal run toy-cryptol-ast -- /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Common/EC/PrimeField/Instantiations/P224.cry /Users/josh/Automated_Reasoning_for_Cryptography/cryptol_slices/cryptol-specs/Common/EC/PrimeField/Instantiations/P224
# ✅ OK: /Users/josh/Automated_Reasoning_for_Cryptography/cryptol-specs/Common/EC/PrimeField/Instantiations/P224.cry
# STDOUT:
#  Parsed 2 module(s).
