# %%
from pathlib import Path 
import datetime
import os, dotenv
dotenv.load_dotenv()
os.chdir(Path(os.getenv("PYTHONPATH")).expanduser())

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from dotenv import load_dotenv

# %%
VARIANT = "nomods"
VERSION = "v2-0"
preformat_data_df = pd.read_json(f"data/training_datasets/some_verified_{VARIANT}_{VERSION}.jsonl", lines=True)
preformat_data_df['set'] = 'supervised'
token_count_df = pd.read_csv(f"data/{VARIANT}_file_metrics_{VERSION}.csv")
preformat_data_df = preformat_data_df.merge(token_count_df[['filename', 'num_tokens_model']], on='filename', how='left')
preformat_data_df['filetype'] = preformat_data_df['filetype'].apply(
    lambda x: 'cryptol' if x == 'cry' else 'saw' if x == 'saw' else 'text'
    )
preformat_data_df = preformat_data_df[preformat_data_df["filetype"] != "text"].reset_index(drop=True)

preformat_data_df.head()
# Out:
#                                             filename filetype  \
# 0          cryptol/examples/MiniLock/prim/SHA256.cry  cryptol
# 1         cryptol/examples/MiniLock/prim/Blake2s.cry  cryptol
# 2        cryptol/examples/MiniLock/prim/TestHMAC.cry  cryptol
# 3              cryptol/examples/MiniLock/prim/bv.cry  cryptol
# 4  cryptol_slices/cryptol-specs/Primitive/Symmetr...  cryptol
#
#                                              content  n_imports_original  \
# 0  /*\n * Copyright (c) 2013-2016 Galois, Inc.\n ...                 NaN
# 1  /*\n * Copyright (c) 2013-2016 Galois, Inc.\n ...                 NaN
# 2  /*\n * Copyright (c) 2013-2016 Galois, Inc.\n ...                 NaN
# 3  /*\n * Copyright (c) 2013-2016 Galois, Inc.\n ...                 NaN
# 4  shift : {d} (fin d, d >= 1) => [d] -> Bit -> [...                 0.0
#
#    n_imports_final         set  num_tokens_model
# 0              NaN  supervised              2683
# 1              NaN  supervised             21842
# 2              NaN  supervised               254
# 3              NaN  supervised               605
# 4              0.0  supervised                56

# %%
from src.preprocessing.sft_instruct_preprocess import iter_call_openai_structured, alpaca_df_to_qwen_messages, build_prompt_call_openai_structured

out_path = Path(f"cache/alpaca_instruct_cache/SFT_{VARIANT}_source_code_{VERSION}.jsonl")
out_path.parent.mkdir(parents=True, exist_ok=True)  # create dirs if missing
file_cache_path = f"cache/alpaca_instruct_cache/SFT_{VARIANT}_source_code_{VERSION}.jsonl"

test_df = preformat_data_df.sample(1, random_state=42).reset_index(drop=True)
input_mode="full"

preformat_data_df = preformat_data_df[preformat_data_df["filetype"] == "cryptol"].reset_index(drop=True)


result = iter_call_openai_structured(preformat_data_df, "gpt-5.1", input_mode, file_cache_path)
result.head()
# Out:
# Key  not found in CRYPTOL_VECTOR_STORE_ID.
# Response:
#
# ParsedResponse[AlpacaRow](id='resp_09cecf61a8f92b280069483f2bd6c881a1a83baeca4d9f3871', created_at=1766342443.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-5.1-2025-11-13', object='response', output=[ParsedResponseOutputMessage[AlpacaRow](id='msg_09cecf61a8f92b280069483f2d5c7881a19f8a0834f52b5c0b', content=[ParsedResponseOutputText[AlpacaRow](annotations=[], text='{"instruction":"Define a Cryptol module implementing the SHA-256 hash function (including preprocessing, message schedule, compression, constants, and initial value) with top-level function `SHA256 : {a} (fin a, 64 >= width (8*a)) => [a][8] -> [256]` and a property `katsPass` that checks this implementation against standard SHA-256 known-answer test vectors.","input":"","output":""}', type='output_text', logprobs=[], parsed=AlpacaRow(instruction='Define a Cryptol module implementing the SHA-256 hash function (including preprocessing, message schedule, compression, constants, and initial value) with top-level function `SHA256 : {a} (fin a, 64 >= width (8*a)) => [a][8] -> [256]` and a property `katsPass` that checks this implementation against standard SHA-256 known-answer test vectors.', input='', output=''))], role='assistant', status='completed', type='message')], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[FileSearchTool(type='file_search', vector_store_ids=['vs_691cd78f3e088191a660732e83652938'], filters=None, max_num_results=3, ranking_options=RankingOptions(hybrid_search=None, ranker='auto', score_threshold=0.0))], top_p=1.0, background=False, conversation=None, max_output_tokens=None, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, prompt_cache_retention=None, reasoning=Reasoning(effort='none', generate_summary=None, summary=None), safety_identifier=None, service_tier='default', status='completed', text=ResponseTextConfig(format=ResponseFormatTextJSONSchemaConfig(name='AlpacaRow', schema_={'properties': {'instruction': {'title': 'Instruction', 'type': 'string'}, 'input': {'title': 'Input', 'type': 'string'}, 'output': {'title': 'Output', 'type': 'string'}}, 'required': ['instruction', 'input', 'output'], 'title': 'AlpacaRow', 'type': 'object', 'additionalProperties': False}, type='json_schema', description=None, strict=True), verbosity='medium'), top_logprobs=0, truncation='disabled', usage=ResponseUsage(input_tokens=4106, input_tokens_details=InputTokensDetails(cached_tokens=4096), output_tokens=108, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=4214), user=None, billing={'payer': 'developer'}, completed_at=1766342446, store=True)
# Response:
#
# ParsedResponse[AlpacaRow](id='resp_0b639930cd72af3c0069483f2ee454819582cfbed220b6a191', created_at=1766342447.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-5.1-2025-11-13', object='response', output=[ParsedResponseOutputMessage[AlpacaRow](id='msg_0b639930cd72af3c0069483f2f7c0c81959e28c58d95f7fc2e', content=[ParsedResponseOutputText[AlpacaRow](annotations=[], text='{"instruction":"Write a Cryptol module implementing the BLAKE2s hash function (including types Block, State, LocalState, BCounter, Context and functions G, F, blake2s, blake2sFinish, mkBlock, reverseBytes, updateVector) and define the property katsPass that checks blake2s against the given list of known-answer test vectors kats for all indices 0..255.","input":"","output":""}', type='output_text', logprobs=[], parsed=AlpacaRow(instruction='Write a Cryptol module implementing the BLAKE2s hash function (including types Block, State, LocalState, BCounter, Context and functions G, F, blake2s, blake2sFinish, mkBlock, reverseBytes, updateVector) and define the property katsPass that checks blake2s against the given list of known-answer test vectors kats for all indices 0..255.', input='', output=''))], role='assistant', status='completed', type='message')], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[FileSearchTool(type='file_search', vector_store_ids=['vs_691cd78f3e088191a660732e83652938'], filters=None, max_num_results=3, ranking_options=RankingOptions(hybrid_search=None, ranker='auto', score_threshold=0.0))], top_p=1.0, background=False, conversation=None, max_output_tokens=None, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, prompt_cache_retention=None, reasoning=Reasoning(effort='none', generate_summary=None, summary=None), safety_identifier=None, service_tier='default', status='completed', text=ResponseTextConfig(format=ResponseFormatTextJSONSchemaConfig(name='AlpacaRow', schema_={'properties': {'instruction': {'title': 'Instruction', 'type': 'string'}, 'input': {'title': 'Input', 'type': 'string'}, 'output': {'title': 'Output', 'type': 'string'}}, 'required': ['instruction', 'input', 'output'], 'title': 'AlpacaRow', 'type': 'object', 'additionalProperties': False}, type='json_schema', description=None, strict=True), verbosity='medium'), top_logprobs=0, truncation='disabled', usage=ResponseUsage(input_tokens=16852, input_tokens_details=InputTokensDetails(cached_tokens=16768), output_tokens=109, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=16961), user=None, billing={'payer': 'developer'}, completed_at=1766342448, store=True)
# Response:
#
# ParsedResponse[AlpacaRow](id='resp_0af99ac5d45c1bd80069483f30bdac8190aba5f03b6225ab79', created_at=1766342448.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-5.1-2025-11-13', object='response', output=[ParsedResponseOutputMessage[AlpacaRow](id='msg_0af99ac5d45c1bd80069483f3179788190bffb43a3b528e3c3', content=[ParsedResponseOutputText[AlpacaRow](annotations=[], text='{"instruction":"Write a Cryptol module `TestHMAC` that imports `HMAC` and `SHA256` and defines a property `pass` asserting that `hmacSHA256` passes two standard test vectors (one with key 0x0b repeated 20 times and message \\"Hi There\\", and one with key \\"Jefe\\" and message \\"what do ya want for nothing?\\") by matching known SHA-256 HMAC digests.","input":"","output":""}', type='output_text', logprobs=[], parsed=AlpacaRow(instruction='Write a Cryptol module `TestHMAC` that imports `HMAC` and `SHA256` and defines a property `pass` asserting that `hmacSHA256` passes two standard test vectors (one with key 0x0b repeated 20 times and message "Hi There", and one with key "Jefe" and message "what do ya want for nothing?") by matching known SHA-256 HMAC digests.', input='', output=''))], role='assistant', status='completed', type='message')], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[FileSearchTool(type='file_search', vector_store_ids=['vs_691cd78f3e088191a660732e83652938'], filters=None, max_num_results=3, ranking_options=RankingOptions(hybrid_search=None, ranker='auto', score_threshold=0.0))], top_p=1.0, background=False, conversation=None, max_output_tokens=None, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, prompt_cache_retention=None, reasoning=Reasoning(effort='none', generate_summary=None, summary=None), safety_identifier=None, service_tier='default', status='completed', text=ResponseTextConfig(format=ResponseFormatTextJSONSchemaConfig(name='AlpacaRow', schema_={'properties': {'instruction': {'title': 'Instruction', 'type': 'string'}, 'input': {'title': 'Input', 'type': 'string'}, 'output': {'title': 'Output', 'type': 'string'}}, 'required': ['instruction', 'input', 'output'], 'title': 'AlpacaRow', 'type': 'object', 'additionalProperties': False}, type='json_schema', description=None, strict=True), verbosity='medium'), top_logprobs=0, truncation='disabled', usage=ResponseUsage(input_tokens=2178, input_tokens_details=InputTokensDetails(cached_tokens=2176), output_tokens=115, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=2293), user=None, billing={'payer': 'developer'}, completed_at=1766342450, store=True)
# Response:
#
# ParsedResponse[AlpacaRow](id='resp_04e660d2b195978b0069483f32dfa88197a35e1062c5985089', created_at=1766342450.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-5.1-2025-11-13', object='response', output=[ParsedResponseOutputMessage[AlpacaRow](id='msg_04e660d2b195978b0069483f33a8f8819787043f5e51503422', content=[ParsedResponseOutputText[AlpacaRow](annotations=[], text='{"instruction":"Write a Cryptol specification for the `bv` module providing word-extension (`uext`, `iext`), safe arithmetic (`safe_add`, `safe_sub`, `safe_product`, `safe_mod`), normalization (`is_normal`), and add/subtract-with-carry/borrow (`adc`, `sbb`), and define properties that these functions implement standard unsigned/signed extension, arithmetic identities, and correct carry/borrow behavior for all finite word sizes.","input":"","output":""}', type='output_text', logprobs=[], parsed=AlpacaRow(instruction='Write a Cryptol specification for the `bv` module providing word-extension (`uext`, `iext`), safe arithmetic (`safe_add`, `safe_sub`, `safe_product`, `safe_mod`), normalization (`is_normal`), and add/subtract-with-carry/borrow (`adc`, `sbb`), and define properties that these functions implement standard unsigned/signed extension, arithmetic identities, and correct carry/borrow behavior for all finite word sizes.', input='', output=''))], role='assistant', status='completed', type='message')], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[FileSearchTool(type='file_search', vector_store_ids=['vs_691cd78f3e088191a660732e83652938'], filters=None, max_num_results=3, ranking_options=RankingOptions(hybrid_search=None, ranker='auto', score_threshold=0.0))], top_p=1.0, background=False, conversation=None, max_output_tokens=None, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, prompt_cache_retention=None, reasoning=Reasoning(effort='none', generate_summary=None, summary=None), safety_identifier=None, service_tier='default', status='completed', text=ResponseTextConfig(format=ResponseFormatTextJSONSchemaConfig(name='AlpacaRow', schema_={'properties': {'instruction': {'title': 'Instruction', 'type': 'string'}, 'input': {'title': 'Input', 'type': 'string'}, 'output': {'title': 'Output', 'type': 'string'}}, 'required': ['instruction', 'input', 'output'], 'title': 'AlpacaRow', 'type': 'object', 'additionalProperties': False}, type='json_schema', description=None, strict=True), verbosity='medium'), top_logprobs=0, truncation='disabled', usage=ResponseUsage(input_tokens=2506, input_tokens_details=InputTokensDetails(cached_tokens=2432), output_tokens=118, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=2624), user=None, billing={'payer': 'developer'}, completed_at=1766342452, store=True)
# Response:
#
# ParsedResponse[AlpacaRow](id='resp_0b87e42078cd719b0069483f350c288191b475cbec61e18e38', created_at=1766342453.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-5.1-2025-11-13', object='response', output=[ParsedResponseOutputMessage[AlpacaRow](id='msg_0b87e42078cd719b0069483f3612fc8191869764e6b062fbd2', content=[ParsedResponseOutputText[AlpacaRow](annotations=[], text='{"instruction":"Define the function `shift : {d} (fin d, d >= 1) => [d] -> Bit -> [d]` that prepends a given bit to a `d`-bit vector and right-shifts the vector by one bit, dropping the least significant bit, matching the specified behavior.","input":"","output":""}', type='output_text', logprobs=[], parsed=AlpacaRow(instruction='Define the function `shift : {d} (fin d, d >= 1) => [d] -> Bit -> [d]` that prepends a given bit to a `d`-bit vector and right-shifts the vector by one bit, dropping the least significant bit, matching the specified behavior.', input='', output=''))], role='assistant', status='completed', type='message')], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[FileSearchTool(type='file_search', vector_store_ids=['vs_691cd78f3e088191a660732e83652938'], filters=None, max_num_results=3, ranking_options=RankingOptions(hybrid_search=None, ranker='auto', score_threshold=0.0))], top_p=1.0, background=False, conversation=None, max_output_tokens=None, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, prompt_cache_retention=None, reasoning=Reasoning(effort='none', generate_summary=None, summary=None), safety_identifier=None, service_tier='default', status='completed', text=ResponseTextConfig(format=ResponseFormatTextJSONSchemaConfig(name='AlpacaRow', schema_={'properties': {'instruction': {'title': 'Instruction', 'type': 'string'}, 'input': {'title': 'Input', 'type': 'string'}, 'output': {'title': 'Output', 'type': 'string'}}, 'required': ['instruction', 'input', 'output'], 'title': 'AlpacaRow', 'type': 'object', 'additionalProperties': False}, type='json_schema', description=None, strict=True), verbosity='medium'), top_logprobs=0, truncation='disabled', usage=ResponseUsage(input_tokens=2063, input_tokens_details=InputTokensDetails(cached_tokens=2048), output_tokens=89, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=2152), user=None, billing={'payer': 'developer'}, completed_at=1766342455, store=True)
# Response:
#
# ParsedResponse[AlpacaRow](id='resp_05089cb7b2d486750069483f37fd3081a2a4fe8eec61bfdff1', created_at=1766342456.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-5.1-2025-11-13', object='response', output=[ParsedResponseOutputMessage[AlpacaRow](id='msg_05089cb7b2d486750069483f387a0481a2a6de3a02d8f49715', content=[ParsedResponseOutputText[AlpacaRow](annotations=[], text='{"instruction":"In Cryptol, write or complete a specification that defines the property `Bivium_alt_equivalent` asserting that for all initial register states `r : ([93],[84])`, the alternative Bivium stream cipher implementation `Bivium_alt r` produces exactly the same `N`-bit keystream as the reference implementation `Bivium r` and is suitable for formal equivalence checking.","input":"","output":""}', type='output_text', logprobs=[], parsed=AlpacaRow(instruction='In Cryptol, write or complete a specification that defines the property `Bivium_alt_equivalent` asserting that for all initial register states `r : ([93],[84])`, the alternative Bivium stream cipher implementation `Bivium_alt r` produces exactly the same `N`-bit keystream as the reference implementation `Bivium r` and is suitable for formal equivalence checking.', input='', output=''))], role='assistant', status='completed', type='message')], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[FileSearchTool(type='file_search', vector_store_ids=['vs_691cd78f3e088191a660732e83652938'], filters=None, max_num_results=3, ranking_options=RankingOptions(hybrid_search=None, ranker='auto', score_threshold=0.0))], top_p=1.0, background=False, conversation=None, max_output_tokens=None, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, prompt_cache_retention=None, reasoning=Reasoning(effort='none', generate_summary=None, summary=None), safety_identifier=None, service_tier='default', status='completed', text=ResponseTextConfig(format=ResponseFormatTextJSONSchemaConfig(name='AlpacaRow', schema_={'properties': {'instruction': {'title': 'Instruction', 'type': 'string'}, 'input': {'title': 'Input', 'type': 'string'}, 'output': {'title': 'Output', 'type': 'string'}}, 'required': ['instruction', 'input', 'output'], 'title': 'AlpacaRow', 'type': 'object', 'additionalProperties': False}, type='json_schema', description=None, strict=True), verbosity='medium'), top_logprobs=0, truncation='disabled', usage=ResponseUsage(input_tokens=2749, input_tokens_details=InputTokensDetails(cached_tokens=2688), output_tokens=108, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=2857), user=None, billing={'payer': 'developer'}, completed_at=1766342457, store=True)
# Response:
#
# ParsedResponse[AlpacaRow](id='resp_0332845313cf35aa0069483f39c1fc8196ac557bbd12d2153f', created_at=1766342457.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-5.1-2025-11-13', object='response', output=[ParsedResponseOutputMessage[AlpacaRow](id='msg_0332845313cf35aa0069483f3a490c8196a8e8329f44d899b7', content=[ParsedResponseOutputText[AlpacaRow](annotations=[], text='{"instruction":"Define a Cryptol property that verifies the iround : [64] -> [16][32] -> [16][32] function correctly produces, for each n, the nth intermediate ChaCha20 round state sequence where only word x12 is incremented by 1 in each step, matching the intended ChaCha20 intermediate round behavior for all valid inputs.","input":"","output":""}', type='output_text', logprobs=[], parsed=AlpacaRow(instruction='Define a Cryptol property that verifies the iround : [64] -> [16][32] -> [16][32] function correctly produces, for each n, the nth intermediate ChaCha20 round state sequence where only word x12 is incremented by 1 in each step, matching the intended ChaCha20 intermediate round behavior for all valid inputs.', input='', output=''))], role='assistant', status='completed', type='message')], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[FileSearchTool(type='file_search', vector_store_ids=['vs_691cd78f3e088191a660732e83652938'], filters=None, max_num_results=3, ranking_options=RankingOptions(hybrid_search=None, ranker='auto', score_threshold=0.0))], top_p=1.0, background=False, conversation=None, max_output_tokens=None, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, prompt_cache_retention=None, reasoning=Reasoning(effort='none', generate_summary=None, summary=None), safety_identifier=None, service_tier='default', status='completed', text=ResponseTextConfig(format=ResponseFormatTextJSONSchemaConfig(name='AlpacaRow', schema_={'properties': {'instruction': {'title': 'Instruction', 'type': 'string'}, 'input': {'title': 'Input', 'type': 'string'}, 'output': {'title': 'Output', 'type': 'string'}}, 'required': ['instruction', 'input', 'output'], 'title': 'AlpacaRow', 'type': 'object', 'additionalProperties': False}, type='json_schema', description=None, strict=True), verbosity='medium'), top_logprobs=0, truncation='disabled', usage=ResponseUsage(input_tokens=2225, input_tokens_details=InputTokensDetails(cached_tokens=2176), output_tokens=97, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=2322), user=None, billing={'payer': 'developer'}, completed_at=1766342459, store=True)
# Response:
#
# ParsedResponse[AlpacaRow](id='resp_06c57a54ef548d9b0069483f3b8ee481929ffd2bad1577c47e', created_at=1766342459.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-5.1-2025-11-13', object='response', output=[ParsedResponseOutputMessage[AlpacaRow](id='msg_06c57a54ef548d9b0069483f3bee108192902ab127ab7e48e9', content=[ParsedResponseOutputText[AlpacaRow](annotations=[], text='{"instruction":"In Cryptol, define the polymorphic infinite-stream function `iterate : {a} (a -> a) -> a -> [inf]a` that, given a function and an initial value, produces an infinite sequence starting with the seed followed by repeated applications of the function, matching the behavior described.","input":"","output":""}', type='output_text', logprobs=[], parsed=AlpacaRow(instruction='In Cryptol, define the polymorphic infinite-stream function `iterate : {a} (a -> a) -> a -> [inf]a` that, given a function and an initial value, produces an infinite sequence starting with the seed followed by repeated applications of the function, matching the behavior described.', input='', output=''))], role='assistant', status='completed', type='message')], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[FileSearchTool(type='file_search', vector_store_ids=['vs_691cd78f3e088191a660732e83652938'], filters=None, max_num_results=3, ranking_options=RankingOptions(hybrid_search=None, ranker='auto', score_threshold=0.0))], top_p=1.0, background=False, conversation=None, max_output_tokens=None, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, prompt_cache_retention=None, reasoning=Reasoning(effort='none', generate_summary=None, summary=None), safety_identifier=None, service_tier='default', status='completed', text=ResponseTextConfig(format=ResponseFormatTextJSONSchemaConfig(name='AlpacaRow', schema_={'properties': {'instruction': {'title': 'Instruction', 'type': 'string'}, 'input': {'title': 'Input', 'type': 'string'}, 'output': {'title': 'Output', 'type': 'string'}}, 'required': ['instruction', 'input', 'output'], 'title': 'AlpacaRow', 'type': 'object', 'additionalProperties': False}, type='json_schema', description=None, strict=True), verbosity='medium'), top_logprobs=0, truncation='disabled', usage=ResponseUsage(input_tokens=2066, input_tokens_details=InputTokensDetails(cached_tokens=2048), output_tokens=86, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=2152), user=None, billing={'payer': 'developer'}, completed_at=1766342460, store=True)
# Response:
#
# ParsedResponse[AlpacaRow](id='resp_0c9fde9762084dae0069483f3cf0dc819e9f9ab82b02af7f52', created_at=1766342460.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-5.1-2025-11-13', object='response', output=[ParsedResponseOutputMessage[AlpacaRow](id='msg_0c9fde9762084dae0069483f3d6630819e9e963cebf89bb57f', content=[ParsedResponseOutputText[AlpacaRow](annotations=[], text='{"instruction":"Define the function qround : [4][32] -> [4][32] implementing a single ChaCha20 quarter-round, and a property qround01 that asserts qround [0x11111111, 0x01020304, 0x9b8d6f43, 0x01234567] == [0xea2a92f4, 0xcb1cf8ce, 0x4581472e, 0x5881c4bb].","input":"","output":""}', type='output_text', logprobs=[], parsed=AlpacaRow(instruction='Define the function qround : [4][32] -> [4][32] implementing a single ChaCha20 quarter-round, and a property qround01 that asserts qround [0x11111111, 0x01020304, 0x9b8d6f43, 0x01234567] == [0xea2a92f4, 0xcb1cf8ce, 0x4581472e, 0x5881c4bb].', input='', output=''))], role='assistant', status='completed', type='message')], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[FileSearchTool(type='file_search', vector_store_ids=['vs_691cd78f3e088191a660732e83652938'], filters=None, max_num_results=3, ranking_options=RankingOptions(hybrid_search=None, ranker='auto', score_threshold=0.0))], top_p=1.0, background=False, conversation=None, max_output_tokens=None, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, prompt_cache_retention=None, reasoning=Reasoning(effort='none', generate_summary=None, summary=None), safety_identifier=None, service_tier='default', status='completed', text=ResponseTextConfig(format=ResponseFormatTextJSONSchemaConfig(name='AlpacaRow', schema_={'properties': {'instruction': {'title': 'Instruction', 'type': 'string'}, 'input': {'title': 'Input', 'type': 'string'}, 'output': {'title': 'Output', 'type': 'string'}}, 'required': ['instruction', 'input', 'output'], 'title': 'AlpacaRow', 'type': 'object', 'additionalProperties': False}, type='json_schema', description=None, strict=True), verbosity='medium'), top_logprobs=0, truncation='disabled', usage=ResponseUsage(input_tokens=2265, input_tokens_details=InputTokensDetails(cached_tokens=2176), output_tokens=129, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=2394), user=None, billing={'payer': 'developer'}, completed_at=1766342462, store=True)
# Response:
#
# ParsedResponse[AlpacaRow](id='resp_07c4d129df7660590069483f3eec908195a0c3f7381faae5d0', created_at=1766342463.0, error=None, incomplete_details=None, instructions=None, metadata={}, model='gpt-5.1-2025-11-13', object='response', output=[ParsedResponseOutputMessage[AlpacaRow](id='msg_07c4d129df7660590069483f4174208195b1363a7c0f24828d', content=[ParsedResponseOutputText[AlpacaRow](annotations=[], text='{"instruction":"In Cryptol, define the function `rjoin : {a, b, c} (fin a, fin c) => [c][a]b -> [a * c]b` that concatenates a sequence of `c` subvectors of length `a` into a single vector, with the outer sequence reversed before joining (i.e., `rjoin x = join (reverse x)`).","input":"","output":""}', type='output_text', logprobs=[], parsed=AlpacaRow(instruction='In Cryptol, define the function `rjoin : {a, b, c} (fin a, fin c) => [c][a]b -> [a * c]b` that concatenates a sequence of `c` subvectors of length `a` into a single vector, with the outer sequence reversed before joining (i.e., `rjoin x = join (reverse x)`).', input='', output=''))], role='assistant', status='completed', type='message')], parallel_tool_calls=True, temperature=1.0, tool_choice='auto', tools=[FileSearchTool(type='file_search', vector_store_ids=['vs_691cd78f3e088191a660732e83652938'], filters=None, max_num_results=3, ranking_options=RankingOptions(hybrid_search=None, ranker='auto', score_threshold=0.0))], top_p=1.0, background=False, conversation=None, max_output_tokens=None, max_tool_calls=None, previous_response_id=None, prompt=None, prompt_cache_key=None, prompt_cache_retention=None, reasoning=Reasoning(effort='none', generate_summary=None, summary=None), safety_identifier=None, service_tier='default', status='completed', text=ResponseTextConfig(format=ResponseFormatTextJSONSchemaConfig(name='AlpacaRow', schema_={'properties': {'instruction': {'title': 'Instruction', 'type': 'string'}, 'input': {'title': 'Input', 'type': 'string'}, 'output': {'title': 'Output', 'type': 'string'}}, 'required': ['instruction', 'input', 'output'], 'title': 'AlpacaRow', 'type': 'object', 'additionalProperties': False}, type='json_schema', description=None, strict=True), verbosity='medium'), top_logprobs=0, truncation='disabled', usage=ResponseUsage(input_tokens=2052, input_tokens_details=InputTokensDetails(cached_tokens=2048), output_tokens=109, output_tokens_details=OutputTokensDetails(reasoning_tokens=0), total_tokens=2161), user=None, billing={'payer': 'developer'}, completed_at=1766342473, store=True)
#                                             filename filetype         set  \
# 0          cryptol/examples/MiniLock/prim/SHA256.cry  cryptol  supervised
# 1         cryptol/examples/MiniLock/prim/Blake2s.cry  cryptol  supervised
# 2        cryptol/examples/MiniLock/prim/TestHMAC.cry  cryptol  supervised
# 3              cryptol/examples/MiniLock/prim/bv.cry  cryptol  supervised
# 4  cryptol_slices/cryptol-specs/Primitive/Symmetr...  cryptol  supervised
#
#                                          instruction input output  \
# 0  Define a Cryptol module implementing the SHA-2...
# 1  Write a Cryptol module implementing the BLAKE2...
# 2  Write a Cryptol module `TestHMAC` that imports...
# 3  Write a Cryptol specification for the `bv` mod...
# 4  Define the function `shift : {d} (fin d, d >= ...
#
#                                              content
# 0  /*\n * Copyright (c) 2013-2016 Galois, Inc.\n ...
# 1  /*\n * Copyright (c) 2013-2016 Galois, Inc.\n ...
# 2  /*\n * Copyright (c) 2013-2016 Galois, Inc.\n ...
# 3  /*\n * Copyright (c) 2013-2016 Galois, Inc.\n ...
# 4  shift : {d} (fin d, d >= 1) => [d] -> Bit -> [...

# %%
result = alpaca_df_to_qwen_messages(
    result, 
    output="content",
    #system_prompt="You are a meticulous assistant that writes formal specifications and verification code for Cryptol programs.",
    drop_input=True,
    include_filename_in_user=False
    )
    
result.head()
# Out:
#                                             messages  \
# 0  [{'role': 'system', 'content': 'Return exactly...
# 1  [{'role': 'system', 'content': 'Return exactly...
# 2  [{'role': 'system', 'content': 'Return exactly...
# 3  [{'role': 'system', 'content': 'Return exactly...
# 4  [{'role': 'system', 'content': 'Return exactly...
#
#                                             filename filetype         set
# 0          cryptol/examples/MiniLock/prim/SHA256.cry  cryptol  supervised
# 1         cryptol/examples/MiniLock/prim/Blake2s.cry  cryptol  supervised
# 2        cryptol/examples/MiniLock/prim/TestHMAC.cry  cryptol  supervised
# 3              cryptol/examples/MiniLock/prim/bv.cry  cryptol  supervised
# 4  cryptol_slices/cryptol-specs/Primitive/Symmetr...  cryptol  supervised

# %%
result = result.merge(
    preformat_data_df[["filename"]],
    on="filename",
    how="left"
)
reorder_df = result[["filename", "filetype", "set", "messages"]].copy()
reorder_df.head()
# Out:
#                                             filename filetype         set  \
# 0          cryptol/examples/MiniLock/prim/SHA256.cry  cryptol  supervised
# 1         cryptol/examples/MiniLock/prim/Blake2s.cry  cryptol  supervised
# 2        cryptol/examples/MiniLock/prim/TestHMAC.cry  cryptol  supervised
# 3              cryptol/examples/MiniLock/prim/bv.cry  cryptol  supervised
# 4  cryptol_slices/cryptol-specs/Primitive/Symmetr...  cryptol  supervised
#
#                                             messages
# 0  [{'role': 'system', 'content': 'Return exactly...
# 1  [{'role': 'system', 'content': 'Return exactly...
# 2  [{'role': 'system', 'content': 'Return exactly...
# 3  [{'role': 'system', 'content': 'Return exactly...
# 4  [{'role': 'system', 'content': 'Return exactly...

# %%
for idx, row in reorder_df.iterrows():
    print("Filename:")
    print(row['filename'])
    message = row['messages']
    print(f"System: {message[0]['content']}")
    print(f"User: \n{message[1]['content']}")
    print("Output:")
    print(row['output'])
    print("="*50)

# %%
reorder_df.to_json(f"data/training_datasets/SFT_message_format_{VARIANT}_{VERSION}.jsonl", orient="records", lines=True)

# %%
training_df = reorder_df[reorder_df["set"] != "holdout"].reset_index(drop=True)

training_df.drop(columns=['set'], inplace=True)
training_df.head()
# Out:
#                                             filename filetype  \
# 0          cryptol/examples/MiniLock/prim/SHA256.cry  cryptol
# 1         cryptol/examples/MiniLock/prim/Blake2s.cry  cryptol
# 2        cryptol/examples/MiniLock/prim/TestHMAC.cry  cryptol
# 3              cryptol/examples/MiniLock/prim/bv.cry  cryptol
# 4  cryptol_slices/cryptol-specs/Primitive/Symmetr...  cryptol
#
#                                             messages
# 0  [{'role': 'system', 'content': 'Return exactly...
# 1  [{'role': 'system', 'content': 'Return exactly...
# 2  [{'role': 'system', 'content': 'Return exactly...
# 3  [{'role': 'system', 'content': 'Return exactly...
# 4  [{'role': 'system', 'content': 'Return exactly...

# %%
training_df.to_json(f"data/training_datasets/{VARIANT}_message_format_{VERSION}.jsonl", orient="records", lines=True)
